# %%
# import ML
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
# ML.showAllVariables()
# %matplotlib inline

# from fastai.imports import *
# from fastai.structured import *
import matplotlib.pyplot as plt
# Input data files are available in the "../input/" directory.
# For example, running this (by clicking run or pressing Shift+Enter) will list the files in the input directory
import os
import time

# %%
# Any results you write to the current directory are saved as output.

bakery_data=pd.read_csv("BreadBasket_DMS.csv")

bakery_data['Date Time']=bakery_data['Date']+" "+bakery_data['Time']

bakery_data=bakery_data.drop(['Date','Time'],axis=1)

# bakery_data['TID'] = bakery_data.index
# bakery_data.set_index(bakery_data['TID'],inplace=True)

bakery_data = bakery_data.drop(['Date Time'],axis=1)
bakery_data.Item.count()
# Out:
# 21293

# %%
bakery_data = bakery_data[~bakery_data['Item'].str.contains('NONE')]
bakery_data
# Out:
#        Transaction                  Item
# 0                1                 Bread
# 1                2          Scandinavian
# 2                2          Scandinavian
# 3                3         Hot chocolate
# 4                3                   Jam
# 5                3               Cookies
# 6                4                Muffin
# 7                5                Coffee
# 8                5                Pastry
# 9                5                 Bread
# 10               6             Medialuna
# 11               6                Pastry
# 12               6                Muffin
# 13               7             Medialuna
# 14               7                Pastry
# 15               7                Coffee
# 16               7                   Tea
# 17               8                Pastry
# 18               8                 Bread
# 19               9                 Bread
# 20               9                Muffin
# 21              10          Scandinavian
# 22              10             Medialuna
# 23              11                 Bread
# 24              11             Medialuna
# 25              11                 Bread
# 27              12                   Jam
# 28              12                Coffee
# 29              12               Tartine
# 30              12                Pastry
# ...            ...                   ...
# 21262         9670            Farm House
# 21263         9671                 Bread
# 21264         9672                Coffee
# 21265         9672               Cookies
# 21267         9672  Extra Salami or Feta
# 21268         9673        Spanish Brunch
# 21269         9673                Coffee
# 21270         9673                 Bread
# 21271         9674                Coffee
# 21272         9676             Smoothies
# 21273         9676              Sandwich
# 21274         9677          Tacos/Fajita
# 21275         9677                  Coke
# 21276         9678                Coffee
# 21277         9678          Tacos/Fajita
# 21278         9678                 Toast
# 21279         9679                 Bread
# 21280         9679        Spanish Brunch
# 21281         9680                 Bread
# 21282         9681              Truffles
# 21283         9681                   Tea
# 21284         9681        Spanish Brunch
# 21285         9681      Christmas common
# 21286         9682                Muffin
# 21287         9682          Tacos/Fajita
# 21288         9682                Coffee
# 21289         9682                   Tea
# 21290         9683                Coffee
# 21291         9683                Pastry
# 21292         9684             Smoothies
#
# [20507 rows x 2 columns]

# %%
tdl = []
for i in range(1,bakery_data.Transaction.count()+1):
    tdf = bakery_data[bakery_data.Transaction == i]
    l = set()
    for j in range(0,tdf.Transaction.count()):
        l.add(tdf.Item.iloc[j])
    if len(l)>0:
        tdl.append(list(l))
    else:
        tdl.append(None)
        
col = ['items']
TDB = pd.DataFrame({"items":tdl},columns=col)
TDB = TDB.dropna()
TDB
# Out:
#                                                   items
# 0                                               [Bread]
# 1                                        [Scandinavian]
# 2                         [Hot chocolate, Cookies, Jam]
# 3                                              [Muffin]
# 4                               [Coffee, Pastry, Bread]
# 5                           [Muffin, Medialuna, Pastry]
# 6                      [Coffee, Medialuna, Tea, Pastry]
# 7                                       [Bread, Pastry]
# 8                                       [Muffin, Bread]
# 9                             [Medialuna, Scandinavian]
# 10                                   [Bread, Medialuna]
# 11                  [Coffee, Tea, Jam, Tartine, Pastry]
# 12                              [Bread, Coffee, Basket]
# 13                           [Bread, Medialuna, Pastry]
# 14                        [Mineral water, Scandinavian]
# 15                           [Bread, Medialuna, Coffee]
# 16                                      [Hot chocolate]
# 17                                         [Farm House]
# 18                                  [Bread, Farm House]
# 19                                   [Bread, Medialuna]
# 20                           [Coffee, Medialuna, Bread]
# 21                                                [Jam]
# 22                               [Muffin, Scandinavian]
# 23                                              [Bread]
# 24                                       [Scandinavian]
# 25                                              [Fudge]
# 26                                       [Scandinavian]
# 27                                      [Coffee, Bread]
# 28                                         [Bread, Jam]
# 29                                              [Bread]
# ...                                                 ...
# 9650                                   [Coffee, Pastry]
# 9651                                         [Baguette]
# 9652                                     [Coffee, Cake]
# 9653  [Half slice Monster , My-5 Fruit Shoot, Hot ch...
# 9654                                              [Tea]
# 9655                                    [Coffee, Toast]
# 9656                                           [Coffee]
# 9657     [Coffee, Spanish Brunch, Extra Salami or Feta]
# 9658                                 [Cake, Juice, Tea]
# 9659                                            [Bread]
# 9663                                    [Coffee, Bread]
# 9664                    [Coffee, Juice, Spanish Brunch]
# 9665                                           [Coffee]
# 9666                                  [Bread, Sandwich]
# 9667                                       [Bread, Tea]
# 9668                                       [Farm House]
# 9669                                       [Farm House]
# 9670                                            [Bread]
# 9671            [Coffee, Cookies, Extra Salami or Feta]
# 9672                    [Coffee, Spanish Brunch, Bread]
# 9673                                           [Coffee]
# 9675                              [Smoothies, Sandwich]
# 9676                               [Tacos/Fajita, Coke]
# 9677                      [Tacos/Fajita, Coffee, Toast]
# 9678                            [Bread, Spanish Brunch]
# 9679                                            [Bread]
# 9680  [Christmas common, Spanish Brunch, Truffles, Tea]
# 9681                [Muffin, Coffee, Tea, Tacos/Fajita]
# 9682                                   [Coffee, Pastry]
# 9683                                        [Smoothies]
#
# [9465 rows x 1 columns]

# %%
def loadDataSet(fn):   
    if fn== 'BreadBasket_DMS.csv': #Kaggle Data
        bakery_data=pd.read_csv("BreadBasket_DMS.csv")
        bakery_data['Date Time']=bakery_data['Date']+" "+bakery_data['Time']
        bakery_data=bakery_data.drop(['Date','Time'],axis=1)    
        bakery_data = bakery_data.drop(['Date Time'],axis=1)
        bakery_data = bakery_data[~bakery_data['Item'].str.contains('NONE')]

        tdl = []
        for i in range(1,bakery_data.Transaction.count()+1):
            tdf = bakery_data[bakery_data.Transaction == i]
            l = set()
            for j in range(0,tdf.Transaction.count()):
                l.add(tdf.Item.iloc[j])
            if len(l)>0:
                tdl.append(list(l))
            else:
                tdl.append(None)

        col = ['items']
        TDB = pd.DataFrame({"items":tdl},columns=col)
        TDB = TDB.dropna()
        return TDB['items'].tolist()
    else:
        # read data from txt file
        with open('Small_Data.txt') as f:
            content = f.readlines()

        content = [x.strip() for x in content]

        Transaction = []  # to store transaction
        Frequent_items_value = {}  # to store all frequent item sets

        # to fill values in transaction from txt file
        for i in range(0, len(content)):
            Transaction.append(content[i].split())
        return Transaction

# %%
def transfer2FrozenDataSet(dataSet):
    frozenDataSet = {}
    for elem in dataSet:
        frozenDataSet[frozenset(elem)] = 1
    return frozenDataSet


class TreeNode:
    def __init__(self, nodeName, count, nodeParent):
        self.nodeName = nodeName
        self.count = count
        self.nodeParent = nodeParent
        self.nextSimilarItem = None  # 指向下一個相同元素的指針nextSimilarItem
        self.children = {}

    def updateC(self, count):
        self.count += count


def createFPTree(frozenDataSet, minSupport):
    # scan dataset at the first time, filter out items which are less than minSupport
    frequenctNodeTable = {} # 紀錄每個item的出現數目,還有其parent Node
    for transactions in frozenDataSet:  # 依序取出每筆transactions
        for item in transactions:  # 在取出每項item
            frequenctNodeTable[item] = frequenctNodeTable.get(item, 0) + frozenDataSet[transactions] # 取出每項的count+1
            # count = frequenctNodeTable.get(item, default = 0) , 1 = frozenDataSet[transactions]
    frequenctNodeTable = {k: v for k, v in frequenctNodeTable.items() if v >= minSupport} #濾除掉不滿足minSupport的item
    frequentItemSet = set(frequenctNodeTable.keys()) # 紀錄滿足minSupport items的集合
    if len(frequentItemSet) == 0: return None, None

    for k in frequenctNodeTable:
        # 將frequenctNodeTable中的結構(item,count) -> (item,[count,ItemNode(default=None)])
        frequenctNodeTable[k] = [frequenctNodeTable[k], None]  # (初始化所有非root Node的所有資訊)
    fptree = TreeNode("null", 1, None) # 初始化FP-Tree Root Node
    # scan dataset at the second time, filter out items for each record
    for transactions, count in frozenDataSet.items(): #再次scanfrozenDataSet中的所有items
        frequentItemsInRecord = {}  # 紀錄transaction中的frequent items
        for item in transactions:
            if item in frequentItemSet:      # 利用frequentItemSet過濾出每筆transaction中的常見items
                frequentItemsInRecord[item] = frequenctNodeTable[item][0]
        if len(frequentItemsInRecord) > 0:
            # 將transaction中的items依照support大小作排序(大的在前)，形成一條FP path
            orderedFrequentItems = [v[0] for v in sorted(frequentItemsInRecord.items(), key=lambda v: v[1], reverse=True)] # sort by v[1] (support)降序
            updateFPTree(fptree, orderedFrequentItems, frequenctNodeTable, count)

    return fptree, frequenctNodeTable


def updateFPTree(fptree, orderedFrequentItems, frequenctNodeTable, count):
    # handle the first item
    firstOrderItem = orderedFrequentItems[0]  # scan FP-path 的第1個item
    if firstOrderItem in fptree.children: # 如果firstOrderItem是fptree 節點的子節點
        fptree.children[firstOrderItem].updateC(count)  # 增加該子節點的count數
    else:
        fptree.children[firstOrderItem] = TreeNode(firstOrderItem, count, fptree) #否則，需要新創建一個TreeNode 節點，然後將其賦給fptree 節點的子節點
        # update frequenctNodeTable
        if frequenctNodeTable[firstOrderItem][1] == None: # 如果frequenctNodeTable裡記錄的firstOrderItem Node為None
            frequenctNodeTable[firstOrderItem][1] = fptree.children[firstOrderItem] # 則更新frequenctNodeTable裡的firstOrderItem Node為自己本身
        else:
            updateFrequenctNodeTable(frequenctNodeTable[firstOrderItem][1], fptree.children[firstOrderItem])  #更新 firstOrderItem 下一個相似元素指標
    # handle other items except the first item
    if (len(orderedFrequentItems) > 1): # 假如 FP-path 的後面還有其他item
        updateFPTree(fptree.children[firstOrderItem], orderedFrequentItems[1:], frequenctNodeTable, count)
        # 以FP-path上的firstOrderItem node為新的root Node，處理後續的orderedFrequentItems


def updateFrequenctNodeTable(headFrequentNode, targetNode):
    while (headFrequentNode.nextSimilarItem != None):
        headFrequentNode = headFrequentNode.nextSimilarItem  # 不斷尋找相似元素指標為空的headFrequentNode
    headFrequentNode.nextSimilarItem = targetNode  # 將headFrequentNode 與 targetNode 以相似元素指標連接


def mining_FPTree(frequenctNodeTable, suffix, frequentPatterns, minSupport):
    # for each item in frequenctNodeTable, find conditional suffix path, create conditional fptree, then iterate until there is only one element in conditional fptree
    frequenctItems = [v[0] for v in sorted(frequenctNodeTable.items(), key=lambda v: v[1][0])] # 將frequenctNodeTable以升序排序，從low frequent開始mining
    if (len(frequenctItems) == 0): return

    for frequenctItem in frequenctItems:
        newSuffix = suffix.copy()  # 只拷貝父級目錄，子目錄不拷貝
        newSuffix.add(frequenctItem)  # 加入一個擁有最低出現次數的Suffix item作為newSuffix
        support = frequenctNodeTable[frequenctItem][0]  # 逐一取得Suffix item的support
        frequentPatterns[frozenset(newSuffix)] = support  # 逐一取得Suffix item的support，並將其一一加入到frequentPatterns

        suffixPath = getSuffixPath(frequenctNodeTable, frequenctItem) # Find suffix patterns to the frequenctItem
        if (suffixPath != {}):
            conditionalFPtree, conditionalFNodeTable = createFPTree(suffixPath, minSupport)
            # 根據suffixPath建立conditionalFPtree 和 conditional frequenctNode Table
            if conditionalFNodeTable != None: # 假如 conditional frequenctNode不為空
                mining_FPTree(conditionalFNodeTable, newSuffix, frequentPatterns, minSupport) #繼續挖掘剩餘的conditionalFPtree


def getSuffixPath(frequenctNodeTable, frequenctItem):
    suffixPath = {}
    beginNode = frequenctNodeTable[frequenctItem][1] # 指向當前frequenctItem 的 Tree Node
    suffixs = ascendNodeList(beginNode) # suffixs紀錄由beginNode往上層尋找的ascendTree (不包含beginNode)
    if ((suffixs != [])):
        suffixPath[frozenset(suffixs)] = beginNode.count  # 建立一條由suffix Node起始但不包含suffix Node的完整suffixPath，數量為beginNode的出現次數

    while (beginNode.nextSimilarItem != None):
        beginNode = beginNode.nextSimilarItem
        suffixs = ascendNodeList(beginNode)
        if (suffixs != []):
            suffixPath[frozenset(suffixs)] = beginNode.count

    return suffixPath # 回傳suffixPath


def ascendNodeList(treeNode):
    suffixs = []
    while ((treeNode.nodeParent != None) and (treeNode.nodeParent.nodeName != 'null')):
        treeNode = treeNode.nodeParent
        suffixs.append(treeNode.nodeName)
    return suffixs


def rulesGenerator(frequentPatterns, minConf, rules):
    for frequentset in frequentPatterns:
        if (len(frequentset) > 1): # 依序取得所有長度大於1的frequentset
            getRules(frequentset, frequentset, rules, frequentPatterns, minConf)
            # 透過frequentset自己本身去產生規則並輸出到rules內


def removeStr(set, str):
    tempSet = []
    for elem in set:
        if (elem != str):
            tempSet.append(elem)  # 將不等於frequentElem的項目篩選出來，並加入到tempSet中
    tempFrozenSet = frozenset(tempSet)
    return tempFrozenSet


def getRules(frequentset, currentset, rules, frequentPatterns, minConf): # 由大至小拆解各集合，以取得規則
    for frequentElem in currentset:
        subSet = removeStr(currentset, frequentElem)  # subSet為不包含frequentElem的子集合
        confidence = frequentPatterns[frequentset] / frequentPatterns[subSet]
        # confidence = sup(currentset) / sup(subSet)
        if (confidence >= minConf):
            flag = False
            for rule in rules:
                # rule[0] : 推演規則  # rule[1] : 衍伸規則
                if (rule[0] == subSet and rule[1] == frequentset - subSet):
                    flag = True
            if (flag == False):
                rules.append((subSet, frequentset - subSet, confidence))
                # rules.append (推演規則 -------> 衍伸規則 , confidence)

            if (len(subSet) >= 2): #  如果subSet中的frequent items數大於2
                getRules(frequentset, subSet, rules, frequentPatterns, minConf)
                # 以subSet為目標繼續挖掘其他的規則

def getpatterns(pattern):
    maxVal = max(pattern.items())[1]
    dictpattern = {}
    for i in range(1, maxVal + 10):
        dictpattern[str(i)] = []

    for key, value in pattern.items():
        dictpattern[str(len(key))].append([key, value])

    for i in range(1, maxVal + 10):
        patterns = dictpattern[str(i)]
        if len(patterns) > 0:
            print("{}-items set".format(str(i)))
            [print("items:{} , support:{} ".format(set(item[0]), item[1])) for item in patterns]
            print()

# %%
if __name__=='__main__':    
    def loadDataSet():
        return TDB['items'].tolist()
    
    starttime = time.time()
    dataSet = loadDataSet()
    frozenDataSet = transfer2FrozenDataSet(dataSet)  # 為transaction中所有曾經出現的item建立Node，並初始化support為1
    minSupport = 3
    fptree, frequenctNodeTable = createFPTree(frozenDataSet, minSupport)
    frequentPatterns = {}
    suffix = set([])
    mining_FPTree(frequenctNodeTable, suffix, frequentPatterns, minSupport)
    

    minConf = 0.6
    rules = []
    rulesGenerator(frequentPatterns, minConf, rules)
    endtime = time.time()
    print("fptree:")
    print("\nTime Taken is: {}\n".format((endtime - starttime) * 1000))
    
    print("frequent patterns:")
    getpatterns(frequentPatterns)
    
    print("association rules:")
    rules = [rule for rule in rules if rule != None]
    [print('Rules:{}-->{}, confidence:{}'.format(set(r[0]), set(r[1]), r[2])) for r in rules]
# Out:
# fptree:
#
# Time Taken is: 81.95257186889648
#
# frequent patterns:
# 1-items set
# items:{'Bread Pudding'} , support:3
# items:{'Caramel bites'} , support:3
# items:{'Brioche and salami'} , support:3
# items:{'Raspberry shortbread sandwich'} , support:3
# items:{'Cherry me Dried fruit'} , support:3
# items:{'Panatone'} , support:4
# items:{"Valentine's card"} , support:4
# items:{'Bare Popcorn'} , support:5
# items:{'Postcard'} , support:5
# items:{'Argentina Night'} , support:5
# items:{'Half slice Monster '} , support:5
# items:{'Basket'} , support:6
# items:{'Honey'} , support:6
# items:{'Lemon and coconut'} , support:6
# items:{'Crepes'} , support:6
# items:{'Muesli'} , support:6
# items:{'Coffee granules '} , support:6
# items:{'Christmas common'} , support:6
# items:{'Victorian Sponge'} , support:7
# items:{'Mighty Protein'} , support:7
# items:{'Empanadas'} , support:7
# items:{'Gingerbread syrup'} , support:7
# items:{'Vegan Feast'} , support:7
# items:{'Kids biscuit'} , support:8
# items:{'Nomad bag'} , support:8
# items:{'Drinking chocolate spoons '} , support:8
# items:{'Tshirt'} , support:9
# items:{'Chocolates'} , support:9
# items:{'Dulce de Leche'} , support:10
# items:{'Duck egg'} , support:10
# items:{'Tacos/Fajita'} , support:11
# items:{'Pick and Mix Bowls'} , support:12
# items:{'Crisps'} , support:13
# items:{'Afternoon with the baker'} , support:13
# items:{"Ella's Kitchen Pouches"} , support:16
# items:{'My-5 Fruit Shoot'} , support:17
# items:{'Eggs'} , support:17
# items:{'Granola'} , support:22
# items:{'Keeping It Local'} , support:26
# items:{'Tartine'} , support:32
# items:{'Focaccia'} , support:32
# items:{'Vegan mincepie'} , support:34
# items:{'Extra Salami or Feta'} , support:35
# items:{'Bakewell'} , support:36
# items:{'Art Tray'} , support:37
# items:{'The Nomad'} , support:41
# items:{'Baguette'} , support:51
# items:{'Frittata'} , support:57
# items:{'Smoothies'} , support:61
# items:{'Hearty & Seasonal'} , support:66
# items:{'Jam'} , support:69
# items:{'Fudge'} , support:69
# items:{'Salad'} , support:70
# items:{'Jammie Dodgers'} , support:79
# items:{'Chicken Stew'} , support:83
# items:{'Tiffin'} , support:90
# items:{'Scandinavian'} , support:92
# items:{'Farm House'} , support:92
# items:{'Mineral water'} , support:103
# items:{'Coke'} , support:104
# items:{'Spanish Brunch'} , support:114
# items:{'Toast'} , support:118
# items:{'Truffles'} , support:134
# items:{'Scone'} , support:143
# items:{'Muffin'} , support:170
# items:{'Soup'} , support:171
# items:{'Brownie'} , support:182
# items:{'Alfajores'} , support:189
# items:{'Medialuna'} , support:201
# items:{'Pastry'} , support:213
# items:{'Cookies'} , support:216
# items:{'Hot chocolate'} , support:248
# items:{'Juice'} , support:255
# items:{'Sandwich'} , support:285
# items:{'Cake'} , support:355
# items:{'Tea'} , support:470
# items:{'Bread'} , support:609
# items:{'Coffee'} , support:962
#
# 2-items set
# items:{'Coffee', 'Bread Pudding'} , support:3
# items:{'Coffee', 'Bare Popcorn'} , support:3
# items:{'Postcard', 'Tshirt'} , support:3
# items:{'Coffee', 'Basket'} , support:4
# items:{'Bread', 'Lemon and coconut'} , support:3
# items:{'Coffee', 'Lemon and coconut'} , support:4
# items:{'Bread', 'Muesli'} , support:3
# items:{'Coffee', 'Muesli'} , support:3
# items:{'Bread', 'Christmas common'} , support:3
# items:{'Victorian Sponge', 'Tea'} , support:4
# items:{'Mighty Protein', 'Tea'} , support:3
# items:{'Coffee', 'Mighty Protein'} , support:5
# items:{'Empanadas', 'Bread'} , support:3
# items:{'Empanadas', 'Coffee'} , support:4
# items:{'Coffee', 'Kids biscuit'} , support:3
# items:{'Muffin', 'Kids biscuit'} , support:3
# items:{'Coffee', 'Nomad bag'} , support:4
# items:{'Bread', 'Nomad bag'} , support:6
# items:{'Drinking chocolate spoons ', 'Coffee'} , support:5
# items:{'Drinking chocolate spoons ', 'Bread'} , support:5
# items:{'Chocolates', 'Tea'} , support:3
# items:{'Chocolates', 'Coke'} , support:3
# items:{'Chocolates', 'Juice'} , support:4
# items:{'Chocolates', 'Hot chocolate'} , support:4
# items:{'Chocolates', 'Coffee'} , support:5
# items:{'Dulce de Leche', 'Alfajores'} , support:3
# items:{'Dulce de Leche', 'Coffee'} , support:3
# items:{'Tea', 'Duck egg'} , support:5
# items:{'Spanish Brunch', 'Duck egg'} , support:5
# items:{'Coffee', 'Duck egg'} , support:6
# items:{'Tacos/Fajita', 'Cake'} , support:3
# items:{'Tacos/Fajita', 'Bread'} , support:3
# items:{'Tacos/Fajita', 'Juice'} , support:3
# items:{'Tacos/Fajita', 'Tea'} , support:3
# items:{'Tacos/Fajita', 'Coffee'} , support:5
# items:{'Hearty & Seasonal', 'Pick and Mix Bowls'} , support:3
# items:{'Pick and Mix Bowls', 'Tartine'} , support:3
# items:{'Mineral water', 'Pick and Mix Bowls'} , support:3
# items:{'Pick and Mix Bowls', 'Juice'} , support:4
# items:{'Coffee', 'Pick and Mix Bowls'} , support:6
# items:{'Hot chocolate', 'Crisps'} , support:3
# items:{'Truffles', 'Crisps'} , support:3
# items:{'Bread', 'Crisps'} , support:4
# items:{'Juice', 'Crisps'} , support:6
# items:{'Sandwich', 'Crisps'} , support:6
# items:{'Coffee', 'Crisps'} , support:8
# items:{'Bread', 'Afternoon with the baker'} , support:3
# items:{'Afternoon with the baker', 'Tea'} , support:3
# items:{'Coffee', 'Afternoon with the baker'} , support:4
# items:{'Cookies', "Ella's Kitchen Pouches"} , support:3
# items:{'Medialuna', "Ella's Kitchen Pouches"} , support:3
# items:{'Tea', "Ella's Kitchen Pouches"} , support:4
# items:{'Bread', "Ella's Kitchen Pouches"} , support:5
# items:{'Juice', "Ella's Kitchen Pouches"} , support:6
# items:{'Coffee', "Ella's Kitchen Pouches"} , support:6
# items:{'My-5 Fruit Shoot', 'Cake'} , support:3
# items:{'My-5 Fruit Shoot', 'Brownie'} , support:3
# items:{'My-5 Fruit Shoot', 'Hot chocolate'} , support:3
# items:{'Muffin', 'My-5 Fruit Shoot'} , support:3
# items:{'My-5 Fruit Shoot', 'Cookies'} , support:4
# items:{'Bread', 'My-5 Fruit Shoot'} , support:5
# items:{'Coffee', 'My-5 Fruit Shoot'} , support:6
# items:{'Eggs', 'Pastry'} , support:3
# items:{'Eggs', 'Juice'} , support:3
# items:{'Eggs', 'Cake'} , support:3
# items:{'Coffee', 'Eggs'} , support:7
# items:{'Bread', 'Eggs'} , support:9
# items:{'Granola', 'Cake'} , support:3
# items:{'Granola', 'Sandwich'} , support:3
# items:{'Granola', 'Pastry'} , support:4
# items:{'Granola', 'Tea'} , support:7
# items:{'Bread', 'Granola'} , support:8
# items:{'Coffee', 'Granola'} , support:12
# items:{'Keeping It Local', 'Cookies'} , support:3
# items:{'Keeping It Local', 'Pastry'} , support:3
# items:{'Keeping It Local', 'Bread'} , support:10
# items:{'Keeping It Local', 'Tea'} , support:11
# items:{'Keeping It Local', 'Coffee'} , support:20
# items:{'Tartine', 'Pastry'} , support:3
# items:{'Tartine', 'Jam'} , support:4
# items:{'Juice', 'Tartine'} , support:4
# items:{'Bread', 'Tartine'} , support:6
# items:{'Tartine', 'Tea'} , support:7
# items:{'Coffee', 'Tartine'} , support:20
# items:{'Farm House', 'Focaccia'} , support:3
# items:{'Alfajores', 'Focaccia'} , support:3
# items:{'Scandinavian', 'Focaccia'} , support:3
# items:{'Pastry', 'Focaccia'} , support:4
# items:{'Fudge', 'Focaccia'} , support:4
# items:{'Tea', 'Focaccia'} , support:5
# items:{'Medialuna', 'Focaccia'} , support:6
# items:{'Coffee', 'Focaccia'} , support:9
# items:{'Bread', 'Focaccia'} , support:10
# items:{'Vegan mincepie', 'Cookies'} , support:3
# items:{'Vegan mincepie', 'Juice'} , support:4
# items:{'Vegan mincepie', 'Jammie Dodgers'} , support:5
# items:{'Vegan mincepie', 'Tea'} , support:6
# items:{'Vegan mincepie', 'Hot chocolate'} , support:8
# items:{'Bread', 'Vegan mincepie'} , support:8
# items:{'Vegan mincepie', 'Cake'} , support:9
# items:{'Coffee', 'Vegan mincepie'} , support:20
# items:{'Brownie', 'Extra Salami or Feta'} , support:3
# items:{'Cookies', 'Extra Salami or Feta'} , support:3
# items:{'Juice', 'Extra Salami or Feta'} , support:4
# items:{'Tea', 'Extra Salami or Feta'} , support:6
# items:{'Sandwich', 'Extra Salami or Feta'} , support:6
# items:{'Extra Salami or Feta', 'Toast'} , support:6
# items:{'Cake', 'Extra Salami or Feta'} , support:7
# items:{'Spanish Brunch', 'Extra Salami or Feta'} , support:7
# items:{'Bread', 'Extra Salami or Feta'} , support:10
# items:{'Extra Salami or Feta', 'Salad'} , support:16
# items:{'Coffee', 'Extra Salami or Feta'} , support:28
# items:{'Bakewell', 'Pastry'} , support:3
# items:{'Bakewell', 'Toast'} , support:3
# items:{'Hot chocolate', 'Bakewell'} , support:3
# items:{'Cookies', 'Bakewell'} , support:4
# items:{'Bakewell', 'Sandwich'} , support:4
# items:{'Juice', 'Bakewell'} , support:5
# items:{'Bakewell', 'Cake'} , support:7
# items:{'Bakewell', 'Tea'} , support:10
# items:{'Bread', 'Bakewell'} , support:11
# items:{'Coffee', 'Bakewell'} , support:21
# items:{'Alfajores', 'Art Tray'} , support:3
# items:{'Muffin', 'Art Tray'} , support:3
# items:{'Salad', 'Art Tray'} , support:3
# items:{'Brownie', 'Art Tray'} , support:4
# items:{'Cookies', 'Art Tray'} , support:4
# items:{'Spanish Brunch', 'Art Tray'} , support:4
# items:{'Soup', 'Art Tray'} , support:6
# items:{'Bread', 'Art Tray'} , support:6
# items:{'Hot chocolate', 'Art Tray'} , support:6
# items:{'Sandwich', 'Art Tray'} , support:8
# items:{'Juice', 'Art Tray'} , support:8
# items:{'Tea', 'Art Tray'} , support:10
# items:{'Coffee', 'Art Tray'} , support:26
# items:{'Hot chocolate', 'The Nomad'} , support:3
# items:{'Sandwich', 'The Nomad'} , support:3
# items:{'Tiffin', 'The Nomad'} , support:3
# items:{'Cookies', 'The Nomad'} , support:3
# items:{'Scone', 'The Nomad'} , support:4
# items:{'Medialuna', 'The Nomad'} , support:4
# items:{'Pastry', 'The Nomad'} , support:4
# items:{'Truffles', 'The Nomad'} , support:4
# items:{'Juice', 'The Nomad'} , support:4
# items:{'Cake', 'The Nomad'} , support:6
# items:{'Spanish Brunch', 'The Nomad'} , support:8
# items:{'Tea', 'The Nomad'} , support:13
# items:{'Bread', 'The Nomad'} , support:15
# items:{'Coffee', 'The Nomad'} , support:22
# items:{'Baguette', 'Hot chocolate'} , support:3
# items:{'Baguette', 'Sandwich'} , support:3
# items:{'Baguette', 'Tea'} , support:3
# items:{'Baguette', 'Scone'} , support:3
# items:{'Baguette', 'Spanish Brunch'} , support:3
# items:{'Baguette', 'Juice'} , support:3
# items:{'Baguette', 'Truffles'} , support:3
# items:{'Muffin', 'Baguette'} , support:3
# items:{'Baguette', 'Cookies'} , support:4
# items:{'Baguette', 'Toast'} , support:4
# items:{'Baguette', 'Salad'} , support:4
# items:{'Baguette', 'Brownie'} , support:5
# items:{'Baguette', 'Medialuna'} , support:5
# items:{'Baguette', 'Alfajores'} , support:5
# items:{'Baguette', 'Scandinavian'} , support:6
# items:{'Baguette', 'Pastry'} , support:7
# items:{'Baguette', 'Cake'} , support:8
# items:{'Baguette', 'Bread'} , support:11
# items:{'Baguette', 'Coffee'} , support:19
# items:{'Frittata', 'Scandinavian'} , support:3
# items:{'Medialuna', 'Frittata'} , support:3
# items:{'Frittata', 'Brownie'} , support:4
# items:{'Frittata', 'Soup'} , support:4
# items:{'Juice', 'Frittata'} , support:4
# items:{'Frittata', 'Cookies'} , support:4
# items:{'Frittata', 'Truffles'} , support:5
# items:{'Frittata', 'Pastry'} , support:5
# items:{'Mineral water', 'Frittata'} , support:6
# items:{'Muffin', 'Frittata'} , support:6
# items:{'Frittata', 'Scone'} , support:7
# items:{'Frittata', 'Sandwich'} , support:8
# items:{'Frittata', 'Tea'} , support:11
# items:{'Bread', 'Frittata'} , support:19
# items:{'Coffee', 'Frittata'} , support:32
# items:{'Smoothies', 'Alfajores'} , support:3
# items:{'Smoothies', 'Pastry'} , support:4
# items:{'Smoothies', 'Brownie'} , support:4
# items:{'Jammie Dodgers', 'Smoothies'} , support:4
# items:{'Hearty & Seasonal', 'Smoothies'} , support:5
# items:{'Juice', 'Smoothies'} , support:5
# items:{'Smoothies', 'Cookies'} , support:5
# items:{'Smoothies', 'Soup'} , support:7
# items:{'Muffin', 'Smoothies'} , support:7
# items:{'Spanish Brunch', 'Smoothies'} , support:7
# items:{'Smoothies', 'Hot chocolate'} , support:8
# items:{'Smoothies', 'Tea'} , support:9
# items:{'Smoothies', 'Cake'} , support:12
# items:{'Smoothies', 'Sandwich'} , support:14
# items:{'Bread', 'Smoothies'} , support:18
# items:{'Coffee', 'Smoothies'} , support:32
# items:{'Hearty & Seasonal', 'Pastry'} , support:3
# items:{'Hearty & Seasonal', 'Medialuna'} , support:3
# items:{'Hearty & Seasonal', 'Truffles'} , support:3
# items:{'Hearty & Seasonal', 'Cookies'} , support:3
# items:{'Hearty & Seasonal', 'Alfajores'} , support:4
# items:{'Hearty & Seasonal', 'Juice'} , support:4
# items:{'Hearty & Seasonal', 'Muffin'} , support:6
# items:{'Hearty & Seasonal', 'Brownie'} , support:6
# items:{'Hearty & Seasonal', 'Cake'} , support:6
# items:{'Hearty & Seasonal', 'Hot chocolate'} , support:7
# items:{'Hearty & Seasonal', 'Mineral water'} , support:9
# items:{'Hearty & Seasonal', 'Soup'} , support:9
# items:{'Hearty & Seasonal', 'Sandwich'} , support:10
# items:{'Hearty & Seasonal', 'Tea'} , support:12
# items:{'Hearty & Seasonal', 'Bread'} , support:22
# items:{'Hearty & Seasonal', 'Coffee'} , support:37
# items:{'Sandwich', 'Jam'} , support:3
# items:{'Spanish Brunch', 'Jam'} , support:3
# items:{'Hot chocolate', 'Jam'} , support:4
# items:{'Muffin', 'Jam'} , support:4
# items:{'Medialuna', 'Jam'} , support:4
# items:{'Scandinavian', 'Jam'} , support:4
# items:{'Cookies', 'Jam'} , support:5
# items:{'Juice', 'Jam'} , support:5
# items:{'Soup', 'Jam'} , support:5
# items:{'Farm House', 'Jam'} , support:6
# items:{'Cake', 'Jam'} , support:6
# items:{'Pastry', 'Jam'} , support:8
# items:{'Tea', 'Jam'} , support:11
# items:{'Fudge', 'Jam'} , support:17
# items:{'Coffee', 'Jam'} , support:26
# items:{'Bread', 'Jam'} , support:31
# items:{'Fudge', 'Scandinavian'} , support:3
# items:{'Fudge', 'Farm House'} , support:3
# items:{'Muffin', 'Fudge'} , support:4
# items:{'Fudge', 'Hot chocolate'} , support:4
# items:{'Fudge', 'Brownie'} , support:5
# items:{'Fudge', 'Pastry'} , support:5
# items:{'Fudge', 'Cake'} , support:6
# items:{'Medialuna', 'Fudge'} , support:6
# items:{'Fudge', 'Alfajores'} , support:7
# items:{'Fudge', 'Tea'} , support:11
# items:{'Fudge', 'Sandwich'} , support:11
# items:{'Coffee', 'Fudge'} , support:23
# items:{'Bread', 'Fudge'} , support:24
# items:{'Alfajores', 'Salad'} , support:3
# items:{'Scandinavian', 'Salad'} , support:3
# items:{'Cookies', 'Salad'} , support:4
# items:{'Salad', 'Chicken Stew'} , support:4
# items:{'Salad', 'Toast'} , support:5
# items:{'Mineral water', 'Salad'} , support:6
# items:{'Coke', 'Salad'} , support:6
# items:{'Truffles', 'Salad'} , support:7
# items:{'Juice', 'Salad'} , support:10
# items:{'Salad', 'Soup'} , support:12
# items:{'Spanish Brunch', 'Salad'} , support:12
# items:{'Cake', 'Salad'} , support:12
# items:{'Sandwich', 'Salad'} , support:14
# items:{'Tea', 'Salad'} , support:17
# items:{'Bread', 'Salad'} , support:18
# items:{'Coffee', 'Salad'} , support:44
# items:{'Jammie Dodgers', 'Pastry'} , support:4
# items:{'Jammie Dodgers', 'Scone'} , support:4
# items:{'Jammie Dodgers', 'Brownie'} , support:4
# items:{'Jammie Dodgers', 'Alfajores'} , support:4
# items:{'Jammie Dodgers', 'Truffles'} , support:4
# items:{'Medialuna', 'Jammie Dodgers'} , support:6
# items:{'Jammie Dodgers', 'Sandwich'} , support:7
# items:{'Jammie Dodgers', 'Cookies'} , support:9
# items:{'Muffin', 'Jammie Dodgers'} , support:9
# items:{'Tiffin', 'Jammie Dodgers'} , support:10
# items:{'Jammie Dodgers', 'Hot chocolate'} , support:14
# items:{'Juice', 'Jammie Dodgers'} , support:16
# items:{'Jammie Dodgers', 'Tea'} , support:21
# items:{'Jammie Dodgers', 'Cake'} , support:21
# items:{'Bread', 'Jammie Dodgers'} , support:29
# items:{'Coffee', 'Jammie Dodgers'} , support:40
# items:{'Hot chocolate', 'Chicken Stew'} , support:3
# items:{'Alfajores', 'Chicken Stew'} , support:3
# items:{'Mineral water', 'Chicken Stew'} , support:3
# items:{'Cookies', 'Chicken Stew'} , support:4
# items:{'Brownie', 'Chicken Stew'} , support:4
# items:{'Tiffin', 'Chicken Stew'} , support:4
# items:{'Pastry', 'Chicken Stew'} , support:5
# items:{'Toast', 'Chicken Stew'} , support:5
# items:{'Medialuna', 'Chicken Stew'} , support:5
# items:{'Truffles', 'Chicken Stew'} , support:9
# items:{'Coke', 'Chicken Stew'} , support:10
# items:{'Spanish Brunch', 'Chicken Stew'} , support:11
# items:{'Soup', 'Chicken Stew'} , support:15
# items:{'Juice', 'Chicken Stew'} , support:15
# items:{'Cake', 'Chicken Stew'} , support:16
# items:{'Sandwich', 'Chicken Stew'} , support:19
# items:{'Tea', 'Chicken Stew'} , support:24
# items:{'Bread', 'Chicken Stew'} , support:24
# items:{'Coffee', 'Chicken Stew'} , support:36
# items:{'Tiffin', 'Farm House'} , support:3
# items:{'Tiffin', 'Coke'} , support:4
# items:{'Tiffin', 'Mineral water'} , support:4
# items:{'Tiffin', 'Truffles'} , support:5
# items:{'Tiffin', 'Toast'} , support:5
# items:{'Tiffin', 'Scone'} , support:6
# items:{'Muffin', 'Tiffin'} , support:6
# items:{'Tiffin', 'Brownie'} , support:6
# items:{'Tiffin', 'Pastry'} , support:7
# items:{'Tiffin', 'Medialuna'} , support:7
# items:{'Tiffin', 'Alfajores'} , support:8
# items:{'Tiffin', 'Sandwich'} , support:9
# items:{'Tiffin', 'Juice'} , support:9
# items:{'Tiffin', 'Cookies'} , support:11
# items:{'Tiffin', 'Hot chocolate'} , support:12
# items:{'Tiffin', 'Cake'} , support:17
# items:{'Tiffin', 'Tea'} , support:25
# items:{'Tiffin', 'Bread'} , support:31
# items:{'Tiffin', 'Coffee'} , support:49
# items:{'Mineral water', 'Scandinavian'} , support:3
# items:{'Scandinavian', 'Soup'} , support:3
# items:{'Scandinavian', 'Sandwich'} , support:3
# items:{'Scandinavian', 'Truffles'} , support:3
# items:{'Scandinavian', 'Toast'} , support:3
# items:{'Scandinavian', 'Scone'} , support:3
# items:{'Scandinavian', 'Brownie'} , support:5
# items:{'Scandinavian', 'Hot chocolate'} , support:5
# items:{'Scandinavian', 'Cookies'} , support:6
# items:{'Scandinavian', 'Tea'} , support:7
# items:{'Muffin', 'Scandinavian'} , support:8
# items:{'Medialuna', 'Scandinavian'} , support:10
# items:{'Scandinavian', 'Alfajores'} , support:10
# items:{'Scandinavian', 'Pastry'} , support:12
# items:{'Scandinavian', 'Cake'} , support:13
# items:{'Bread', 'Scandinavian'} , support:28
# items:{'Coffee', 'Scandinavian'} , support:38
# items:{'Coke', 'Farm House'} , support:3
# items:{'Alfajores', 'Farm House'} , support:4
# items:{'Farm House', 'Sandwich'} , support:4
# items:{'Farm House', 'Soup'} , support:4
# items:{'Spanish Brunch', 'Farm House'} , support:4
# items:{'Cookies', 'Farm House'} , support:5
# items:{'Hot chocolate', 'Farm House'} , support:5
# items:{'Juice', 'Farm House'} , support:5
# items:{'Muffin', 'Farm House'} , support:6
# items:{'Farm House', 'Toast'} , support:6
# items:{'Scandinavian', 'Farm House'} , support:8
# items:{'Farm House', 'Cake'} , support:8
# items:{'Farm House', 'Brownie'} , support:9
# items:{'Farm House', 'Tea'} , support:12
# items:{'Medialuna', 'Farm House'} , support:15
# items:{'Farm House', 'Pastry'} , support:16
# items:{'Bread', 'Farm House'} , support:27
# items:{'Coffee', 'Farm House'} , support:40
# items:{'Mineral water', 'Medialuna'} , support:3
# items:{'Mineral water', 'Toast'} , support:4
# items:{'Mineral water', 'Spanish Brunch'} , support:4
# items:{'Muffin', 'Mineral water'} , support:5
# items:{'Mineral water', 'Scone'} , support:7
# items:{'Mineral water', 'Brownie'} , support:8
# items:{'Mineral water', 'Hot chocolate'} , support:9
# items:{'Mineral water', 'Coke'} , support:11
# items:{'Mineral water', 'Truffles'} , support:11
# items:{'Mineral water', 'Alfajores'} , support:12
# items:{'Mineral water', 'Cookies'} , support:12
# items:{'Mineral water', 'Tea'} , support:12
# items:{'Mineral water', 'Cake'} , support:13
# items:{'Mineral water', 'Juice'} , support:16
# items:{'Mineral water', 'Soup'} , support:18
# items:{'Bread', 'Mineral water'} , support:25
# items:{'Mineral water', 'Sandwich'} , support:26
# items:{'Coffee', 'Mineral water'} , support:50
# items:{'Muffin', 'Coke'} , support:5
# items:{'Coke', 'Toast'} , support:5
# items:{'Coke', 'Scone'} , support:5
# items:{'Coke', 'Alfajores'} , support:6
# items:{'Coke', 'Hot chocolate'} , support:6
# items:{'Coke', 'Cookies'} , support:6
# items:{'Coke', 'Spanish Brunch'} , support:6
# items:{'Coke', 'Medialuna'} , support:7
# items:{'Coke', 'Pastry'} , support:7
# items:{'Coke', 'Brownie'} , support:11
# items:{'Coke', 'Truffles'} , support:12
# items:{'Coke', 'Soup'} , support:13
# items:{'Coke', 'Cake'} , support:15
# items:{'Bread', 'Coke'} , support:17
# items:{'Coke', 'Tea'} , support:18
# items:{'Coke', 'Juice'} , support:20
# items:{'Coke', 'Sandwich'} , support:30
# items:{'Coffee', 'Coke'} , support:50
# items:{'Spanish Brunch', 'Pastry'} , support:3
# items:{'Muffin', 'Spanish Brunch'} , support:3
# items:{'Spanish Brunch', 'Brownie'} , support:5
# items:{'Spanish Brunch', 'Scone'} , support:6
# items:{'Spanish Brunch', 'Cookies'} , support:7
# items:{'Medialuna', 'Spanish Brunch'} , support:7
# items:{'Spanish Brunch', 'Hot chocolate'} , support:8
# items:{'Spanish Brunch', 'Soup'} , support:8
# items:{'Spanish Brunch', 'Toast'} , support:9
# items:{'Spanish Brunch', 'Alfajores'} , support:10
# items:{'Spanish Brunch', 'Truffles'} , support:16
# items:{'Spanish Brunch', 'Sandwich'} , support:18
# items:{'Juice', 'Spanish Brunch'} , support:20
# items:{'Spanish Brunch', 'Cake'} , support:22
# items:{'Bread', 'Spanish Brunch'} , support:30
# items:{'Spanish Brunch', 'Tea'} , support:33
# items:{'Coffee', 'Spanish Brunch'} , support:65
# items:{'Truffles', 'Toast'} , support:3
# items:{'Soup', 'Toast'} , support:3
# items:{'Alfajores', 'Toast'} , support:5
# items:{'Muffin', 'Toast'} , support:6
# items:{'Scone', 'Toast'} , support:6
# items:{'Brownie', 'Toast'} , support:7
# items:{'Pastry', 'Toast'} , support:9
# items:{'Medialuna', 'Toast'} , support:11
# items:{'Cookies', 'Toast'} , support:16
# items:{'Sandwich', 'Toast'} , support:17
# items:{'Juice', 'Toast'} , support:19
# items:{'Cake', 'Toast'} , support:19
# items:{'Hot chocolate', 'Toast'} , support:23
# items:{'Tea', 'Toast'} , support:29
# items:{'Bread', 'Toast'} , support:32
# items:{'Coffee', 'Toast'} , support:75
# items:{'Muffin', 'Truffles'} , support:5
# items:{'Cookies', 'Truffles'} , support:7
# items:{'Hot chocolate', 'Truffles'} , support:8
# items:{'Scone', 'Truffles'} , support:8
# items:{'Truffles', 'Brownie'} , support:10
# items:{'Alfajores', 'Truffles'} , support:11
# items:{'Medialuna', 'Truffles'} , support:11
# items:{'Truffles', 'Soup'} , support:12
# items:{'Truffles', 'Pastry'} , support:15
# items:{'Juice', 'Truffles'} , support:18
# items:{'Truffles', 'Tea'} , support:20
# items:{'Truffles', 'Cake'} , support:23
# items:{'Truffles', 'Sandwich'} , support:28
# items:{'Bread', 'Truffles'} , support:36
# items:{'Coffee', 'Truffles'} , support:56
# items:{'Muffin', 'Scone'} , support:7
# items:{'Scone', 'Alfajores'} , support:10
# items:{'Scone', 'Soup'} , support:10
# items:{'Scone', 'Brownie'} , support:11
# items:{'Scone', 'Sandwich'} , support:13
# items:{'Medialuna', 'Scone'} , support:13
# items:{'Scone', 'Cookies'} , support:16
# items:{'Scone', 'Pastry'} , support:16
# items:{'Juice', 'Scone'} , support:18
# items:{'Scone', 'Hot chocolate'} , support:20
# items:{'Scone', 'Cake'} , support:30
# items:{'Scone', 'Tea'} , support:40
# items:{'Bread', 'Scone'} , support:47
# items:{'Coffee', 'Scone'} , support:69
# items:{'Muffin', 'Soup'} , support:10
# items:{'Muffin', 'Cookies'} , support:12
# items:{'Muffin', 'Alfajores'} , support:12
# items:{'Muffin', 'Medialuna'} , support:14
# items:{'Muffin', 'Brownie'} , support:14
# items:{'Muffin', 'Sandwich'} , support:17
# items:{'Muffin', 'Pastry'} , support:18
# items:{'Muffin', 'Juice'} , support:24
# items:{'Muffin', 'Hot chocolate'} , support:25
# items:{'Muffin', 'Cake'} , support:28
# items:{'Muffin', 'Tea'} , support:37
# items:{'Muffin', 'Bread'} , support:51
# items:{'Muffin', 'Coffee'} , support:78
# items:{'Alfajores', 'Soup'} , support:6
# items:{'Medialuna', 'Soup'} , support:7
# items:{'Hot chocolate', 'Soup'} , support:8
# items:{'Pastry', 'Soup'} , support:9
# items:{'Cookies', 'Soup'} , support:10
# items:{'Brownie', 'Soup'} , support:13
# items:{'Juice', 'Soup'} , support:17
# items:{'Cake', 'Soup'} , support:30
# items:{'Sandwich', 'Soup'} , support:38
# items:{'Bread', 'Soup'} , support:38
# items:{'Tea', 'Soup'} , support:51
# items:{'Coffee', 'Soup'} , support:83
# items:{'Brownie', 'Pastry'} , support:13
# items:{'Medialuna', 'Brownie'} , support:16
# items:{'Brownie', 'Sandwich'} , support:19
# items:{'Cookies', 'Brownie'} , support:19
# items:{'Juice', 'Brownie'} , support:23
# items:{'Alfajores', 'Brownie'} , support:25
# items:{'Brownie', 'Cake'} , support:27
# items:{'Hot chocolate', 'Brownie'} , support:28
# items:{'Brownie', 'Tea'} , support:44
# items:{'Bread', 'Brownie'} , support:52
# items:{'Coffee', 'Brownie'} , support:94
# items:{'Alfajores', 'Cookies'} , support:20
# items:{'Alfajores', 'Pastry'} , support:23
# items:{'Alfajores', 'Sandwich'} , support:24
# items:{'Medialuna', 'Alfajores'} , support:26
# items:{'Juice', 'Alfajores'} , support:28
# items:{'Alfajores', 'Cake'} , support:28
# items:{'Alfajores', 'Hot chocolate'} , support:30
# items:{'Alfajores', 'Tea'} , support:47
# items:{'Bread', 'Alfajores'} , support:59
# items:{'Coffee', 'Alfajores'} , support:96
# items:{'Medialuna', 'Cookies'} , support:17
# items:{'Medialuna', 'Sandwich'} , support:17
# items:{'Medialuna', 'Juice'} , support:20
# items:{'Medialuna', 'Hot chocolate'} , support:28
# items:{'Medialuna', 'Cake'} , support:28
# items:{'Medialuna', 'Pastry'} , support:31
# items:{'Medialuna', 'Tea'} , support:49
# items:{'Bread', 'Medialuna'} , support:61
# items:{'Coffee', 'Medialuna'} , support:112
# items:{'Sandwich', 'Pastry'} , support:9
# items:{'Juice', 'Pastry'} , support:13
# items:{'Cookies', 'Pastry'} , support:17
# items:{'Cake', 'Pastry'} , support:28
# items:{'Hot chocolate', 'Pastry'} , support:30
# items:{'Tea', 'Pastry'} , support:45
# items:{'Bread', 'Pastry'} , support:72
# items:{'Coffee', 'Pastry'} , support:112
# items:{'Cookies', 'Sandwich'} , support:23
# items:{'Cookies', 'Cake'} , support:35
# items:{'Juice', 'Cookies'} , support:42
# items:{'Hot chocolate', 'Cookies'} , support:43
# items:{'Cookies', 'Tea'} , support:55
# items:{'Bread', 'Cookies'} , support:66
# items:{'Coffee', 'Cookies'} , support:114
# items:{'Juice', 'Hot chocolate'} , support:20
# items:{'Hot chocolate', 'Sandwich'} , support:27
# items:{'Hot chocolate', 'Cake'} , support:51
# items:{'Hot chocolate', 'Tea'} , support:57
# items:{'Bread', 'Hot chocolate'} , support:74
# items:{'Coffee', 'Hot chocolate'} , support:130
# items:{'Juice', 'Sandwich'} , support:46
# items:{'Juice', 'Cake'} , support:47
# items:{'Juice', 'Tea'} , support:55
# items:{'Bread', 'Juice'} , support:56
# items:{'Coffee', 'Juice'} , support:132
# items:{'Cake', 'Sandwich'} , support:45
# items:{'Tea', 'Sandwich'} , support:64
# items:{'Bread', 'Sandwich'} , support:92
# items:{'Coffee', 'Sandwich'} , support:163
# items:{'Bread', 'Cake'} , support:103
# items:{'Tea', 'Cake'} , support:107
# items:{'Coffee', 'Cake'} , support:181
# items:{'Bread', 'Tea'} , support:133
# items:{'Coffee', 'Tea'} , support:185
# items:{'Bread', 'Coffee'} , support:260
#
# 3-items set
# items:{'Coffee', 'Nomad bag', 'Bread'} , support:3
# items:{'Drinking chocolate spoons ', 'Coffee', 'Bread'} , support:3
# items:{'Chocolates', 'Juice', 'Coffee'} , support:3
# items:{'Coffee', 'Pick and Mix Bowls', 'Tartine'} , support:3
# items:{'Mineral water', 'Pick and Mix Bowls', 'Juice'} , support:3
# items:{'Coffee', 'Hot chocolate', 'Crisps'} , support:3
# items:{'Bread', 'Coffee', 'Crisps'} , support:3
# items:{'Bread', 'Juice', 'Crisps'} , support:3
# items:{'Coffee', 'Juice', 'Crisps'} , support:5
# items:{'Coffee', 'Sandwich', 'Crisps'} , support:3
# items:{'Coffee', 'My-5 Fruit Shoot', 'Cookies'} , support:3
# items:{'Bread', 'Eggs', 'Cake'} , support:3
# items:{'Coffee', 'Eggs', 'Bread'} , support:3
# items:{'Coffee', 'Granola', 'Cake'} , support:3
# items:{'Bread', 'Granola', 'Pastry'} , support:3
# items:{'Coffee', 'Granola', 'Pastry'} , support:3
# items:{'Bread', 'Granola', 'Tea'} , support:3
# items:{'Bread', 'Granola', 'Coffee'} , support:4
# items:{'Keeping It Local', 'Coffee', 'Cookies'} , support:3
# items:{'Keeping It Local', 'Coffee', 'Pastry'} , support:3
# items:{'Keeping It Local', 'Bread', 'Coffee'} , support:5
# items:{'Keeping It Local', 'Bread', 'Tea'} , support:5
# items:{'Keeping It Local', 'Coffee', 'Tea'} , support:7
# items:{'Coffee', 'Tartine', 'Jam'} , support:3
# items:{'Coffee', 'Juice', 'Tartine'} , support:3
# items:{'Coffee', 'Tartine', 'Tea'} , support:3
# items:{'Coffee', 'Medialuna', 'Focaccia'} , support:3
# items:{'Bread', 'Medialuna', 'Focaccia'} , support:3
# items:{'Coffee', 'Bread', 'Focaccia'} , support:4
# items:{'Coffee', 'Vegan mincepie', 'Jammie Dodgers'} , support:3
# items:{'Bread', 'Vegan mincepie', 'Hot chocolate'} , support:3
# items:{'Coffee', 'Vegan mincepie', 'Hot chocolate'} , support:6
# items:{'Bread', 'Vegan mincepie', 'Coffee'} , support:5
# items:{'Coffee', 'Vegan mincepie', 'Cake'} , support:7
# items:{'Coffee', 'Cookies', 'Extra Salami or Feta'} , support:3
# items:{'Juice', 'Extra Salami or Feta', 'Salad'} , support:3
# items:{'Coffee', 'Juice', 'Extra Salami or Feta'} , support:4
# items:{'Bread', 'Tea', 'Extra Salami or Feta'} , support:3
# items:{'Coffee', 'Tea', 'Extra Salami or Feta'} , support:3
# items:{'Bread', 'Sandwich', 'Extra Salami or Feta'} , support:3
# items:{'Sandwich', 'Extra Salami or Feta', 'Salad'} , support:3
# items:{'Coffee', 'Sandwich', 'Extra Salami or Feta'} , support:5
# items:{'Coffee', 'Extra Salami or Feta', 'Toast'} , support:6
# items:{'Cake', 'Extra Salami or Feta', 'Bread'} , support:3
# items:{'Cake', 'Extra Salami or Feta', 'Salad'} , support:3
# items:{'Cake', 'Coffee', 'Extra Salami or Feta'} , support:6
# items:{'Spanish Brunch', 'Extra Salami or Feta', 'Salad'} , support:3
# items:{'Coffee', 'Spanish Brunch', 'Extra Salami or Feta'} , support:5
# items:{'Bread', 'Extra Salami or Feta', 'Salad'} , support:6
# items:{'Bread', 'Coffee', 'Extra Salami or Feta'} , support:7
# items:{'Coffee', 'Extra Salami or Feta', 'Salad'} , support:14
# items:{'Cookies', 'Coffee', 'Bakewell'} , support:4
# items:{'Coffee', 'Bakewell', 'Sandwich'} , support:3
# items:{'Coffee', 'Juice', 'Bakewell'} , support:4
# items:{'Tea', 'Bakewell', 'Cake'} , support:3
# items:{'Coffee', 'Bakewell', 'Cake'} , support:4
# items:{'Bread', 'Bakewell', 'Tea'} , support:3
# items:{'Coffee', 'Bakewell', 'Tea'} , support:4
# items:{'Bread', 'Coffee', 'Bakewell'} , support:7
# items:{'Coffee', 'Brownie', 'Art Tray'} , support:3
# items:{'Coffee', 'Cookies', 'Art Tray'} , support:3
# items:{'Coffee', 'Spanish Brunch', 'Art Tray'} , support:3
# items:{'Coffee', 'Soup', 'Art Tray'} , support:4
# items:{'Bread', 'Coffee', 'Art Tray'} , support:3
# items:{'Hot chocolate', 'Tea', 'Art Tray'} , support:3
# items:{'Coffee', 'Hot chocolate', 'Art Tray'} , support:3
# items:{'Juice', 'Hot chocolate', 'Art Tray'} , support:3
# items:{'Coffee', 'Sandwich', 'Art Tray'} , support:6
# items:{'Coffee', 'Juice', 'Art Tray'} , support:4
# items:{'Coffee', 'Tea', 'Art Tray'} , support:5
# items:{'Bread', 'Sandwich', 'The Nomad'} , support:3
# items:{'Coffee', 'Juice', 'The Nomad'} , support:3
# items:{'Spanish Brunch', 'Cake', 'The Nomad'} , support:3
# items:{'Spanish Brunch', 'Tea', 'The Nomad'} , support:3
# items:{'Coffee', 'Spanish Brunch', 'The Nomad'} , support:5
# items:{'Bread', 'Tea', 'The Nomad'} , support:4
# items:{'Coffee', 'Tea', 'The Nomad'} , support:5
# items:{'Bread', 'Coffee', 'The Nomad'} , support:4
# items:{'Baguette', 'Alfajores', 'Coffee'} , support:3
# items:{'Baguette', 'Coffee', 'Pastry'} , support:3
# items:{'Baguette', 'Coffee', 'Cake'} , support:3
# items:{'Baguette', 'Coffee', 'Bread'} , support:4
# items:{'Coffee', 'Frittata', 'Brownie'} , support:3
# items:{'Coffee', 'Juice', 'Frittata'} , support:3
# items:{'Bread', 'Frittata', 'Cookies'} , support:3
# items:{'Coffee', 'Mineral water', 'Frittata'} , support:3
# items:{'Muffin', 'Coffee', 'Frittata'} , support:4
# items:{'Bread', 'Frittata', 'Scone'} , support:3
# items:{'Coffee', 'Frittata', 'Scone'} , support:3
# items:{'Bread', 'Frittata', 'Sandwich'} , support:3
# items:{'Coffee', 'Frittata', 'Sandwich'} , support:4
# items:{'Bread', 'Frittata', 'Tea'} , support:4
# items:{'Coffee', 'Frittata', 'Tea'} , support:6
# items:{'Bread', 'Frittata', 'Coffee'} , support:12
# items:{'Coffee', 'Smoothies', 'Pastry'} , support:3
# items:{'Coffee', 'Smoothies', 'Brownie'} , support:3
# items:{'Hearty & Seasonal', 'Coffee', 'Smoothies'} , support:3
# items:{'Coffee', 'Juice', 'Smoothies'} , support:4
# items:{'Coffee', 'Smoothies', 'Cookies'} , support:3
# items:{'Coffee', 'Smoothies', 'Soup'} , support:3
# items:{'Smoothies', 'Sandwich', 'Soup'} , support:3
# items:{'Muffin', 'Coffee', 'Smoothies'} , support:3
# items:{'Coffee', 'Spanish Brunch', 'Smoothies'} , support:4
# items:{'Bread', 'Smoothies', 'Hot chocolate'} , support:3
# items:{'Cake', 'Smoothies', 'Tea'} , support:3
# items:{'Coffee', 'Smoothies', 'Tea'} , support:4
# items:{'Smoothies', 'Sandwich', 'Cake'} , support:4
# items:{'Bread', 'Smoothies', 'Cake'} , support:4
# items:{'Coffee', 'Smoothies', 'Cake'} , support:7
# items:{'Bread', 'Smoothies', 'Sandwich'} , support:6
# items:{'Coffee', 'Smoothies', 'Sandwich'} , support:7
# items:{'Bread', 'Smoothies', 'Coffee'} , support:8
# items:{'Hearty & Seasonal', 'Coffee', 'Medialuna'} , support:3
# items:{'Hearty & Seasonal', 'Hot chocolate', 'Cookies'} , support:3
# items:{'Hearty & Seasonal', 'Bread', 'Muffin'} , support:3
# items:{'Hearty & Seasonal', 'Coffee', 'Brownie'} , support:3
# items:{'Hearty & Seasonal', 'Coffee', 'Cake'} , support:6
# items:{'Hearty & Seasonal', 'Bread', 'Hot chocolate'} , support:3
# items:{'Hearty & Seasonal', 'Coffee', 'Hot chocolate'} , support:5
# items:{'Hearty & Seasonal', 'Bread', 'Mineral water'} , support:3
# items:{'Hearty & Seasonal', 'Coffee', 'Mineral water'} , support:3
# items:{'Hearty & Seasonal', 'Coffee', 'Soup'} , support:4
# items:{'Hearty & Seasonal', 'Bread', 'Sandwich'} , support:4
# items:{'Hearty & Seasonal', 'Coffee', 'Sandwich'} , support:8
# items:{'Hearty & Seasonal', 'Bread', 'Tea'} , support:3
# items:{'Hearty & Seasonal', 'Coffee', 'Tea'} , support:5
# items:{'Hearty & Seasonal', 'Bread', 'Coffee'} , support:12
# items:{'Bread', 'Medialuna', 'Jam'} , support:3
# items:{'Bread', 'Cookies', 'Jam'} , support:3
# items:{'Bread', 'Juice', 'Jam'} , support:3
# items:{'Coffee', 'Soup', 'Jam'} , support:3
# items:{'Bread', 'Farm House', 'Jam'} , support:4
# items:{'Coffee', 'Cake', 'Jam'} , support:3
# items:{'Bread', 'Pastry', 'Jam'} , support:3
# items:{'Coffee', 'Pastry', 'Jam'} , support:5
# items:{'Fudge', 'Tea', 'Jam'} , support:3
# items:{'Coffee', 'Tea', 'Jam'} , support:4
# items:{'Bread', 'Tea', 'Jam'} , support:6
# items:{'Bread', 'Fudge', 'Jam'} , support:4
# items:{'Coffee', 'Fudge', 'Jam'} , support:6
# items:{'Coffee', 'Bread', 'Jam'} , support:8
# items:{'Coffee', 'Fudge', 'Brownie'} , support:3
# items:{'Bread', 'Fudge', 'Pastry'} , support:3
# items:{'Coffee', 'Fudge', 'Cake'} , support:4
# items:{'Bread', 'Medialuna', 'Fudge'} , support:3
# items:{'Coffee', 'Fudge', 'Alfajores'} , support:3
# items:{'Bread', 'Fudge', 'Alfajores'} , support:4
# items:{'Coffee', 'Fudge', 'Tea'} , support:3
# items:{'Bread', 'Fudge', 'Tea'} , support:5
# items:{'Coffee', 'Fudge', 'Sandwich'} , support:5
# items:{'Bread', 'Fudge', 'Sandwich'} , support:5
# items:{'Coffee', 'Fudge', 'Bread'} , support:7
# items:{'Coffee', 'Alfajores', 'Salad'} , support:3
# items:{'Truffles', 'Salad', 'Chicken Stew'} , support:3
# items:{'Coffee', 'Salad', 'Chicken Stew'} , support:3
# items:{'Coffee', 'Salad', 'Toast'} , support:4
# items:{'Coffee', 'Mineral water', 'Salad'} , support:3
# items:{'Coffee', 'Coke', 'Salad'} , support:3
# items:{'Coffee', 'Truffles', 'Salad'} , support:4
# items:{'Juice', 'Sandwich', 'Salad'} , support:3
# items:{'Coffee', 'Juice', 'Salad'} , support:6
# items:{'Tea', 'Salad', 'Soup'} , support:3
# items:{'Bread', 'Salad', 'Soup'} , support:3
# items:{'Coffee', 'Salad', 'Soup'} , support:6
# items:{'Bread', 'Spanish Brunch', 'Salad'} , support:3
# items:{'Spanish Brunch', 'Tea', 'Salad'} , support:3
# items:{'Coffee', 'Spanish Brunch', 'Salad'} , support:8
# items:{'Cake', 'Tea', 'Salad'} , support:5
# items:{'Cake', 'Coffee', 'Salad'} , support:9
# items:{'Tea', 'Sandwich', 'Salad'} , support:3
# items:{'Bread', 'Sandwich', 'Salad'} , support:5
# items:{'Coffee', 'Sandwich', 'Salad'} , support:11
# items:{'Bread', 'Tea', 'Salad'} , support:4
# items:{'Coffee', 'Tea', 'Salad'} , support:8
# items:{'Bread', 'Coffee', 'Salad'} , support:10
# items:{'Bread', 'Jammie Dodgers', 'Brownie'} , support:3
# items:{'Bread', 'Jammie Dodgers', 'Truffles'} , support:3
# items:{'Jammie Dodgers', 'Truffles', 'Cake'} , support:3
# items:{'Medialuna', 'Jammie Dodgers', 'Tea'} , support:3
# items:{'Bread', 'Jammie Dodgers', 'Sandwich'} , support:4
# items:{'Coffee', 'Jammie Dodgers', 'Sandwich'} , support:5
# items:{'Coffee', 'Jammie Dodgers', 'Cookies'} , support:5
# items:{'Muffin', 'Juice', 'Jammie Dodgers'} , support:3
# items:{'Muffin', 'Bread', 'Jammie Dodgers'} , support:3
# items:{'Muffin', 'Jammie Dodgers', 'Tea'} , support:4
# items:{'Muffin', 'Coffee', 'Jammie Dodgers'} , support:5
# items:{'Tiffin', 'Jammie Dodgers', 'Cake'} , support:3
# items:{'Tiffin', 'Jammie Dodgers', 'Tea'} , support:3
# items:{'Tiffin', 'Jammie Dodgers', 'Bread'} , support:4
# items:{'Tiffin', 'Jammie Dodgers', 'Coffee'} , support:6
# items:{'Jammie Dodgers', 'Hot chocolate', 'Tea'} , support:4
# items:{'Jammie Dodgers', 'Hot chocolate', 'Cake'} , support:4
# items:{'Bread', 'Jammie Dodgers', 'Hot chocolate'} , support:6
# items:{'Coffee', 'Jammie Dodgers', 'Hot chocolate'} , support:8
# items:{'Juice', 'Jammie Dodgers', 'Tea'} , support:4
# items:{'Juice', 'Jammie Dodgers', 'Cake'} , support:4
# items:{'Bread', 'Juice', 'Jammie Dodgers'} , support:5
# items:{'Coffee', 'Juice', 'Jammie Dodgers'} , support:11
# items:{'Coffee', 'Jammie Dodgers', 'Tea'} , support:9
# items:{'Bread', 'Jammie Dodgers', 'Tea'} , support:9
# items:{'Jammie Dodgers', 'Tea', 'Cake'} , support:5
# items:{'Coffee', 'Jammie Dodgers', 'Cake'} , support:8
# items:{'Bread', 'Jammie Dodgers', 'Cake'} , support:11
# items:{'Bread', 'Jammie Dodgers', 'Coffee'} , support:11
# items:{'Tiffin', 'Bread', 'Chicken Stew'} , support:3
# items:{'Bread', 'Pastry', 'Chicken Stew'} , support:3
# items:{'Coffee', 'Pastry', 'Chicken Stew'} , support:4
# items:{'Coke', 'Truffles', 'Chicken Stew'} , support:3
# items:{'Truffles', 'Sandwich', 'Chicken Stew'} , support:3
# items:{'Truffles', 'Cake', 'Chicken Stew'} , support:3
# items:{'Coffee', 'Truffles', 'Chicken Stew'} , support:5
# items:{'Coke', 'Juice', 'Chicken Stew'} , support:4
# items:{'Coke', 'Sandwich', 'Chicken Stew'} , support:4
# items:{'Coffee', 'Coke', 'Chicken Stew'} , support:6
# items:{'Juice', 'Spanish Brunch', 'Chicken Stew'} , support:3
# items:{'Spanish Brunch', 'Tea', 'Chicken Stew'} , support:4
# items:{'Coffee', 'Spanish Brunch', 'Chicken Stew'} , support:4
# items:{'Cake', 'Soup', 'Chicken Stew'} , support:4
# items:{'Coffee', 'Soup', 'Chicken Stew'} , support:6
# items:{'Bread', 'Soup', 'Chicken Stew'} , support:7
# items:{'Tea', 'Soup', 'Chicken Stew'} , support:7
# items:{'Juice', 'Cake', 'Chicken Stew'} , support:3
# items:{'Juice', 'Tea', 'Chicken Stew'} , support:3
# items:{'Juice', 'Sandwich', 'Chicken Stew'} , support:4
# items:{'Coffee', 'Juice', 'Chicken Stew'} , support:7
# items:{'Bread', 'Cake', 'Chicken Stew'} , support:4
# items:{'Sandwich', 'Cake', 'Chicken Stew'} , support:4
# items:{'Tea', 'Cake', 'Chicken Stew'} , support:5
# items:{'Coffee', 'Cake', 'Chicken Stew'} , support:5
# items:{'Bread', 'Sandwich', 'Chicken Stew'} , support:5
# items:{'Tea', 'Sandwich', 'Chicken Stew'} , support:6
# items:{'Coffee', 'Sandwich', 'Chicken Stew'} , support:10
# items:{'Bread', 'Tea', 'Chicken Stew'} , support:4
# items:{'Coffee', 'Tea', 'Chicken Stew'} , support:9
# items:{'Bread', 'Coffee', 'Chicken Stew'} , support:9
# items:{'Tiffin', 'Mineral water', 'Coffee'} , support:3
# items:{'Tiffin', 'Coffee', 'Truffles'} , support:3
# items:{'Tiffin', 'Coffee', 'Toast'} , support:3
# items:{'Tiffin', 'Scone', 'Coffee'} , support:4
# items:{'Tiffin', 'Scone', 'Tea'} , support:4
# items:{'Tiffin', 'Coffee', 'Brownie'} , support:4
# items:{'Tiffin', 'Coffee', 'Pastry'} , support:3
# items:{'Tiffin', 'Tea', 'Pastry'} , support:5
# items:{'Tiffin', 'Medialuna', 'Coffee'} , support:6
# items:{'Tiffin', 'Alfajores', 'Tea'} , support:3
# items:{'Tiffin', 'Alfajores', 'Coffee'} , support:5
# items:{'Tiffin', 'Sandwich', 'Bread'} , support:4
# items:{'Tiffin', 'Coffee', 'Sandwich'} , support:6
# items:{'Tiffin', 'Juice', 'Tea'} , support:3
# items:{'Tiffin', 'Juice', 'Coffee'} , support:6
# items:{'Tiffin', 'Cookies', 'Tea'} , support:3
# items:{'Tiffin', 'Cookies', 'Bread'} , support:3
# items:{'Tiffin', 'Coffee', 'Cookies'} , support:6
# items:{'Tiffin', 'Hot chocolate', 'Tea'} , support:4
# items:{'Tiffin', 'Hot chocolate', 'Bread'} , support:5
# items:{'Tiffin', 'Hot chocolate', 'Coffee'} , support:7
# items:{'Tiffin', 'Cake', 'Bread'} , support:5
# items:{'Tiffin', 'Coffee', 'Cake'} , support:12
# items:{'Tiffin', 'Tea', 'Bread'} , support:11
# items:{'Tiffin', 'Coffee', 'Tea'} , support:13
# items:{'Tiffin', 'Coffee', 'Bread'} , support:15
# items:{'Coffee', 'Scandinavian', 'Soup'} , support:3
# items:{'Coffee', 'Scandinavian', 'Sandwich'} , support:3
# items:{'Coffee', 'Scandinavian', 'Toast'} , support:3
# items:{'Bread', 'Scandinavian', 'Hot chocolate'} , support:4
# items:{'Coffee', 'Scandinavian', 'Hot chocolate'} , support:4
# items:{'Coffee', 'Scandinavian', 'Cookies'} , support:3
# items:{'Coffee', 'Scandinavian', 'Tea'} , support:6
# items:{'Muffin', 'Coffee', 'Scandinavian'} , support:3
# items:{'Bread', 'Medialuna', 'Scandinavian'} , support:4
# items:{'Coffee', 'Medialuna', 'Scandinavian'} , support:5
# items:{'Coffee', 'Scandinavian', 'Alfajores'} , support:4
# items:{'Bread', 'Scandinavian', 'Pastry'} , support:3
# items:{'Coffee', 'Scandinavian', 'Pastry'} , support:5
# items:{'Bread', 'Scandinavian', 'Cake'} , support:3
# items:{'Coffee', 'Scandinavian', 'Cake'} , support:6
# items:{'Bread', 'Scandinavian', 'Coffee'} , support:12
# items:{'Coffee', 'Alfajores', 'Farm House'} , support:3
# items:{'Bread', 'Farm House', 'Sandwich'} , support:3
# items:{'Coffee', 'Spanish Brunch', 'Farm House'} , support:3
# items:{'Coffee', 'Hot chocolate', 'Farm House'} , support:4
# items:{'Coffee', 'Juice', 'Farm House'} , support:5
# items:{'Muffin', 'Bread', 'Farm House'} , support:3
# items:{'Coffee', 'Farm House', 'Toast'} , support:6
# items:{'Coffee', 'Scandinavian', 'Farm House'} , support:4
# items:{'Tea', 'Farm House', 'Cake'} , support:3
# items:{'Coffee', 'Farm House', 'Cake'} , support:4
# items:{'Coffee', 'Farm House', 'Brownie'} , support:5
# items:{'Medialuna', 'Farm House', 'Tea'} , support:4
# items:{'Coffee', 'Farm House', 'Tea'} , support:6
# items:{'Bread', 'Medialuna', 'Farm House'} , support:5
# items:{'Medialuna', 'Farm House', 'Pastry'} , support:6
# items:{'Coffee', 'Medialuna', 'Farm House'} , support:9
# items:{'Bread', 'Farm House', 'Pastry'} , support:5
# items:{'Coffee', 'Farm House', 'Pastry'} , support:8
# items:{'Bread', 'Coffee', 'Farm House'} , support:10
# items:{'Coffee', 'Mineral water', 'Medialuna'} , support:3
# items:{'Coffee', 'Mineral water', 'Toast'} , support:3
# items:{'Bread', 'Mineral water', 'Spanish Brunch'} , support:3
# items:{'Bread', 'Mineral water', 'Scone'} , support:4
# items:{'Mineral water', 'Scone', 'Truffles'} , support:4
# items:{'Bread', 'Mineral water', 'Brownie'} , support:3
# items:{'Coffee', 'Mineral water', 'Brownie'} , support:3
# items:{'Mineral water', 'Hot chocolate', 'Cookies'} , support:3
# items:{'Mineral water', 'Hot chocolate', 'Cake'} , support:3
# items:{'Coffee', 'Mineral water', 'Hot chocolate'} , support:6
# items:{'Bread', 'Mineral water', 'Coke'} , support:3
# items:{'Mineral water', 'Coke', 'Soup'} , support:3
# items:{'Coffee', 'Mineral water', 'Coke'} , support:5
# items:{'Mineral water', 'Sandwich', 'Coke'} , support:6
# items:{'Bread', 'Mineral water', 'Truffles'} , support:3
# items:{'Coffee', 'Mineral water', 'Truffles'} , support:3
# items:{'Mineral water', 'Truffles', 'Sandwich'} , support:4
# items:{'Mineral water', 'Alfajores', 'Cake'} , support:3
# items:{'Mineral water', 'Alfajores', 'Sandwich'} , support:3
# items:{'Coffee', 'Mineral water', 'Alfajores'} , support:9
# items:{'Mineral water', 'Alfajores', 'Cookies'} , support:3
# items:{'Coffee', 'Mineral water', 'Cookies'} , support:7
# items:{'Bread', 'Mineral water', 'Tea'} , support:3
# items:{'Mineral water', 'Tea', 'Soup'} , support:3
# items:{'Mineral water', 'Sandwich', 'Tea'} , support:3
# items:{'Coffee', 'Mineral water', 'Tea'} , support:6
# items:{'Coffee', 'Mineral water', 'Cake'} , support:6
# items:{'Mineral water', 'Soup', 'Juice'} , support:4
# items:{'Mineral water', 'Sandwich', 'Juice'} , support:6
# items:{'Coffee', 'Mineral water', 'Juice'} , support:9
# items:{'Mineral water', 'Sandwich', 'Soup'} , support:4
# items:{'Coffee', 'Mineral water', 'Soup'} , support:8
# items:{'Bread', 'Mineral water', 'Sandwich'} , support:6
# items:{'Bread', 'Mineral water', 'Coffee'} , support:13
# items:{'Coffee', 'Mineral water', 'Sandwich'} , support:13
# items:{'Muffin', 'Coffee', 'Coke'} , support:4
# items:{'Coffee', 'Coke', 'Toast'} , support:4
# items:{'Coffee', 'Coke', 'Scone'} , support:3
# items:{'Coffee', 'Coke', 'Alfajores'} , support:4
# items:{'Coffee', 'Coke', 'Cookies'} , support:4
# items:{'Coffee', 'Coke', 'Spanish Brunch'} , support:4
# items:{'Coffee', 'Coke', 'Medialuna'} , support:4
# items:{'Coke', 'Medialuna', 'Juice'} , support:4
# items:{'Coffee', 'Coke', 'Pastry'} , support:5
# items:{'Coke', 'Brownie', 'Tea'} , support:3
# items:{'Coffee', 'Coke', 'Brownie'} , support:4
# items:{'Coke', 'Truffles', 'Juice'} , support:3
# items:{'Coke', 'Truffles', 'Sandwich'} , support:4
# items:{'Coffee', 'Coke', 'Truffles'} , support:6
# items:{'Bread', 'Coke', 'Soup'} , support:4
# items:{'Coke', 'Sandwich', 'Soup'} , support:5
# items:{'Coffee', 'Coke', 'Soup'} , support:7
# items:{'Bread', 'Coke', 'Cake'} , support:3
# items:{'Coke', 'Tea', 'Cake'} , support:3
# items:{'Coke', 'Cake', 'Juice'} , support:3
# items:{'Coke', 'Sandwich', 'Cake'} , support:4
# items:{'Coffee', 'Coke', 'Cake'} , support:7
# items:{'Bread', 'Coke', 'Tea'} , support:4
# items:{'Bread', 'Coke', 'Coffee'} , support:7
# items:{'Bread', 'Coke', 'Sandwich'} , support:8
# items:{'Coke', 'Tea', 'Juice'} , support:3
# items:{'Coke', 'Sandwich', 'Tea'} , support:5
# items:{'Coffee', 'Coke', 'Tea'} , support:6
# items:{'Coke', 'Sandwich', 'Juice'} , support:9
# items:{'Coffee', 'Coke', 'Juice'} , support:10
# items:{'Coffee', 'Coke', 'Sandwich'} , support:15
# items:{'Coffee', 'Spanish Brunch', 'Pastry'} , support:3
# items:{'Coffee', 'Spanish Brunch', 'Brownie'} , support:3
# items:{'Coffee', 'Spanish Brunch', 'Scone'} , support:3
# items:{'Bread', 'Spanish Brunch', 'Scone'} , support:3
# items:{'Spanish Brunch', 'Cookies', 'Cake'} , support:3
# items:{'Coffee', 'Spanish Brunch', 'Cookies'} , support:4
# items:{'Medialuna', 'Spanish Brunch', 'Cake'} , support:4
# items:{'Coffee', 'Medialuna', 'Spanish Brunch'} , support:5
# items:{'Coffee', 'Spanish Brunch', 'Hot chocolate'} , support:3
# items:{'Spanish Brunch', 'Tea', 'Soup'} , support:4
# items:{'Coffee', 'Spanish Brunch', 'Soup'} , support:5
# items:{'Bread', 'Spanish Brunch', 'Toast'} , support:3
# items:{'Coffee', 'Spanish Brunch', 'Toast'} , support:6
# items:{'Juice', 'Spanish Brunch', 'Alfajores'} , support:3
# items:{'Coffee', 'Spanish Brunch', 'Alfajores'} , support:5
# items:{'Spanish Brunch', 'Alfajores', 'Tea'} , support:7
# items:{'Juice', 'Spanish Brunch', 'Truffles'} , support:3
# items:{'Spanish Brunch', 'Truffles', 'Cake'} , support:3
# items:{'Spanish Brunch', 'Truffles', 'Sandwich'} , support:5
# items:{'Coffee', 'Spanish Brunch', 'Truffles'} , support:7
# items:{'Juice', 'Spanish Brunch', 'Sandwich'} , support:5
# items:{'Bread', 'Spanish Brunch', 'Sandwich'} , support:5
# items:{'Spanish Brunch', 'Tea', 'Sandwich'} , support:6
# items:{'Coffee', 'Spanish Brunch', 'Sandwich'} , support:12
# items:{'Juice', 'Spanish Brunch', 'Cake'} , support:3
# items:{'Bread', 'Juice', 'Spanish Brunch'} , support:3
# ...
# Rules:{'Coffee', 'Tea', 'Jam'}-->{'Bread'}, confidence:0.75
# Rules:{'Fudge', 'Brownie'}-->{'Coffee'}, confidence:0.6
# Rules:{'Fudge', 'Pastry'}-->{'Bread'}, confidence:0.6
# Rules:{'Fudge', 'Cake'}-->{'Coffee'}, confidence:0.6666666666666666
# Rules:{'Alfajores', 'Salad'}-->{'Coffee'}, confidence:1.0
# Rules:{'Salad', 'Chicken Stew'}-->{'Truffles'}, confidence:0.75
# Rules:{'Salad', 'Chicken Stew'}-->{'Coffee'}, confidence:0.75
# Rules:{'Salad', 'Toast'}-->{'Coffee'}, confidence:0.8
# Rules:{'Juice', 'Salad'}-->{'Coffee'}, confidence:0.6
# Rules:{'Spanish Brunch', 'Salad'}-->{'Coffee'}, confidence:0.6666666666666666
# Rules:{'Tea', 'Cake', 'Salad'}-->{'Coffee'}, confidence:0.8
# Rules:{'Cake', 'Salad'}-->{'Coffee'}, confidence:0.75
# Rules:{'Bread', 'Sandwich', 'Salad'}-->{'Coffee'}, confidence:0.6
# Rules:{'Sandwich', 'Salad'}-->{'Coffee'}, confidence:0.7857142857142857
# Rules:{'Salad'}-->{'Coffee'}, confidence:0.6285714285714286
# Rules:{'Jammie Dodgers', 'Brownie'}-->{'Bread'}, confidence:0.75
# Rules:{'Jammie Dodgers', 'Truffles'}-->{'Bread'}, confidence:0.75
# Rules:{'Jammie Dodgers', 'Truffles'}-->{'Cake'}, confidence:0.75
# Rules:{'Coffee', 'Jammie Dodgers', 'Sandwich'}-->{'Bread'}, confidence:0.6
# Rules:{'Bread', 'Jammie Dodgers', 'Sandwich'}-->{'Coffee'}, confidence:0.75
# Rules:{'Jammie Dodgers', 'Sandwich'}-->{'Coffee'}, confidence:0.7142857142857143
# Rules:{'Muffin', 'Juice', 'Jammie Dodgers'}-->{'Coffee'}, confidence:1.0
# Rules:{'Muffin', 'Coffee', 'Jammie Dodgers'}-->{'Juice'}, confidence:0.6
# Rules:{'Tiffin', 'Jammie Dodgers', 'Bread'}-->{'Tea'}, confidence:0.75
# Rules:{'Tiffin', 'Jammie Dodgers', 'Tea'}-->{'Bread'}, confidence:1.0
# Rules:{'Tiffin', 'Jammie Dodgers', 'Bread'}-->{'Coffee'}, confidence:0.75
# Rules:{'Tiffin', 'Jammie Dodgers'}-->{'Coffee'}, confidence:0.6
# Rules:{'Jammie Dodgers', 'Hot chocolate', 'Cake'}-->{'Bread'}, confidence:0.75
# Rules:{'Juice', 'Jammie Dodgers', 'Tea'}-->{'Coffee'}, confidence:0.75
# Rules:{'Juice', 'Jammie Dodgers', 'Cake'}-->{'Bread'}, confidence:0.75
# Rules:{'Bread', 'Juice', 'Jammie Dodgers'}-->{'Cake'}, confidence:0.6
# Rules:{'Juice', 'Jammie Dodgers'}-->{'Coffee'}, confidence:0.6875
# Rules:{'Cake', 'Jammie Dodgers', 'Tea'}-->{'Bread'}, confidence:0.6
# Rules:{'Tiffin', 'Chicken Stew'}-->{'Bread'}, confidence:0.75
# Rules:{'Pastry', 'Chicken Stew'}-->{'Bread'}, confidence:0.6
# Rules:{'Pastry', 'Chicken Stew'}-->{'Coffee'}, confidence:0.8
# Rules:{'Coke', 'Truffles', 'Chicken Stew'}-->{'Coffee'}, confidence:1.0
# Rules:{'Coffee', 'Truffles', 'Chicken Stew'}-->{'Coke'}, confidence:0.6
# Rules:{'Coke', 'Chicken Stew', 'Juice'}-->{'Coffee'}, confidence:0.75
# Rules:{'Coke', 'Sandwich', 'Chicken Stew'}-->{'Coffee'}, confidence:1.0
# Rules:{'Coffee', 'Coke', 'Chicken Stew'}-->{'Sandwich'}, confidence:0.6666666666666666
# Rules:{'Coke', 'Chicken Stew'}-->{'Coffee'}, confidence:0.6
# Rules:{'Bread', 'Tea', 'Chicken Stew'}-->{'Soup'}, confidence:1.0
# Rules:{'Juice', 'Sandwich', 'Chicken Stew'}-->{'Coffee'}, confidence:0.75
# Rules:{'Bread', 'Sandwich', 'Chicken Stew'}-->{'Tea'}, confidence:0.6
# Rules:{'Bread', 'Tea', 'Chicken Stew'}-->{'Sandwich'}, confidence:0.75
# Rules:{'Bread', 'Tea', 'Chicken Stew'}-->{'Coffee'}, confidence:0.75
# Rules:{'Tiffin', 'Mineral water'}-->{'Coffee'}, confidence:0.75
# Rules:{'Tiffin', 'Truffles'}-->{'Coffee'}, confidence:0.6
# Rules:{'Tiffin', 'Toast'}-->{'Coffee'}, confidence:0.6
# Rules:{'Tiffin', 'Scone'}-->{'Coffee'}, confidence:0.6666666666666666
# Rules:{'Tiffin', 'Scone'}-->{'Tea'}, confidence:0.6666666666666666
# Rules:{'Tiffin', 'Brownie'}-->{'Coffee'}, confidence:0.6666666666666666
# Rules:{'Tiffin', 'Coffee', 'Pastry'}-->{'Tea'}, confidence:1.0
# Rules:{'Tiffin', 'Tea', 'Pastry'}-->{'Coffee'}, confidence:0.6
# Rules:{'Tiffin', 'Pastry'}-->{'Tea'}, confidence:0.7142857142857143
# Rules:{'Tiffin', 'Medialuna'}-->{'Coffee'}, confidence:0.8571428571428571
# Rules:{'Tiffin', 'Alfajores'}-->{'Coffee'}, confidence:0.625
# Rules:{'Tiffin', 'Sandwich', 'Bread'}-->{'Coffee'}, confidence:0.75
# Rules:{'Tiffin', 'Sandwich'}-->{'Coffee'}, confidence:0.6666666666666666
# Rules:{'Tiffin', 'Juice'}-->{'Coffee'}, confidence:0.6666666666666666
# Rules:{'Tiffin', 'Cookies', 'Tea'}-->{'Coffee'}, confidence:1.0
# Rules:{'Tiffin', 'Hot chocolate', 'Bread'}-->{'Coffee'}, confidence:0.6
# Rules:{'Tiffin', 'Cake', 'Bread'}-->{'Coffee'}, confidence:0.8
# Rules:{'Tiffin', 'Cake'}-->{'Coffee'}, confidence:0.7058823529411765
# Rules:{'Tiffin', 'Tea', 'Bread'}-->{'Coffee'}, confidence:0.6363636363636364
# Rules:{'Scandinavian', 'Soup'}-->{'Coffee'}, confidence:1.0
# Rules:{'Scandinavian', 'Sandwich'}-->{'Coffee'}, confidence:1.0
# Rules:{'Scandinavian', 'Toast'}-->{'Coffee'}, confidence:1.0
# Rules:{'Scandinavian', 'Hot chocolate'}-->{'Bread'}, confidence:0.8
# Rules:{'Scandinavian', 'Hot chocolate'}-->{'Coffee'}, confidence:0.8
# Rules:{'Bread', 'Scandinavian', 'Hot chocolate'}-->{'Coffee'}, confidence:0.75
# Rules:{'Scandinavian', 'Hot chocolate'}-->{'Coffee', 'Bread'}, confidence:0.6
# Rules:{'Coffee', 'Scandinavian', 'Hot chocolate'}-->{'Bread'}, confidence:0.75
# Rules:{'Scandinavian', 'Tea'}-->{'Coffee'}, confidence:0.8571428571428571
# Rules:{'Coffee', 'Medialuna', 'Scandinavian'}-->{'Bread'}, confidence:0.6
# Rules:{'Bread', 'Medialuna', 'Scandinavian'}-->{'Coffee'}, confidence:0.75
# Rules:{'Alfajores', 'Farm House'}-->{'Coffee'}, confidence:0.75
# Rules:{'Farm House', 'Sandwich'}-->{'Bread'}, confidence:0.75
# Rules:{'Spanish Brunch', 'Farm House'}-->{'Coffee'}, confidence:0.75
# Rules:{'Hot chocolate', 'Farm House'}-->{'Coffee'}, confidence:0.8
# Rules:{'Juice', 'Farm House'}-->{'Coffee'}, confidence:1.0
# Rules:{'Farm House', 'Toast'}-->{'Coffee'}, confidence:1.0
# Rules:{'Medialuna', 'Farm House', 'Tea'}-->{'Coffee'}, confidence:1.0
# Rules:{'Coffee', 'Farm House', 'Tea'}-->{'Medialuna'}, confidence:0.6666666666666666
# Rules:{'Medialuna', 'Farm House', 'Pastry'}-->{'Coffee'}, confidence:0.6666666666666666
# Rules:{'Medialuna', 'Farm House'}-->{'Coffee'}, confidence:0.6
# Rules:{'Mineral water', 'Medialuna'}-->{'Coffee'}, confidence:1.0
# Rules:{'Mineral water', 'Toast'}-->{'Coffee'}, confidence:0.75
# Rules:{'Mineral water', 'Spanish Brunch'}-->{'Bread'}, confidence:0.75
# Rules:{'Mineral water', 'Scone', 'Truffles'}-->{'Bread'}, confidence:0.75
# Rules:{'Bread', 'Scone', 'Truffles'}-->{'Mineral water'}, confidence:0.75
# Rules:{'Bread', 'Mineral water', 'Truffles'}-->{'Scone'}, confidence:1.0
# Rules:{'Bread', 'Mineral water', 'Scone'}-->{'Truffles'}, confidence:0.75
# Rules:{'Mineral water', 'Hot chocolate'}-->{'Coffee'}, confidence:0.6666666666666666
# Rules:{'Mineral water', 'Alfajores', 'Sandwich'}-->{'Coffee'}, confidence:1.0
# Rules:{'Mineral water', 'Alfajores'}-->{'Coffee'}, confidence:0.75
# Rules:{'Mineral water', 'Sandwich', 'Juice'}-->{'Coffee'}, confidence:0.6666666666666666
# Rules:{'Mineral water', 'Sandwich', 'Soup'}-->{'Coffee'}, confidence:0.75
# Rules:{'Muffin', 'Coke'}-->{'Coffee'}, confidence:0.8
# Rules:{'Coke', 'Toast'}-->{'Coffee'}, confidence:0.8
# Rules:{'Coke', 'Scone'}-->{'Coffee'}, confidence:0.6
# Rules:{'Coke', 'Alfajores'}-->{'Coffee'}, confidence:0.6666666666666666
# Rules:{'Coke', 'Cookies'}-->{'Coffee'}, confidence:0.6666666666666666
# Rules:{'Coke', 'Spanish Brunch'}-->{'Coffee'}, confidence:0.6666666666666666
# Rules:{'Coke', 'Pastry'}-->{'Coffee'}, confidence:0.7142857142857143
# Rules:{'Coke', 'Truffles', 'Juice'}-->{'Coffee'}, confidence:1.0
# Rules:{'Coke', 'Truffles', 'Sandwich'}-->{'Coffee'}, confidence:1.0
# Rules:{'Coffee', 'Coke', 'Truffles'}-->{'Sandwich'}, confidence:0.6666666666666666
# Rules:{'Bread', 'Coke', 'Soup'}-->{'Coffee'}, confidence:0.75
# Rules:{'Coke', 'Sandwich', 'Soup'}-->{'Coffee'}, confidence:0.6
# Rules:{'Spanish Brunch', 'Pastry'}-->{'Coffee'}, confidence:1.0
# Rules:{'Spanish Brunch', 'Brownie'}-->{'Coffee'}, confidence:0.6
# Rules:{'Medialuna', 'Spanish Brunch'}-->{'Coffee'}, confidence:0.7142857142857143
# Rules:{'Spanish Brunch', 'Soup'}-->{'Coffee'}, confidence:0.625
# Rules:{'Spanish Brunch', 'Toast'}-->{'Coffee'}, confidence:0.6666666666666666
# Rules:{'Spanish Brunch', 'Alfajores'}-->{'Tea'}, confidence:0.7
# Rules:{'Spanish Brunch', 'Truffles', 'Sandwich'}-->{'Coffee'}, confidence:0.8
# Rules:{'Bread', 'Spanish Brunch', 'Sandwich'}-->{'Coffee'}, confidence:1.0
# Rules:{'Spanish Brunch', 'Sandwich'}-->{'Coffee'}, confidence:0.6666666666666666
# Rules:{'Bread', 'Juice', 'Spanish Brunch'}-->{'Coffee'}, confidence:1.0
# Rules:{'Juice', 'Spanish Brunch'}-->{'Coffee'}, confidence:0.65
# Rules:{'Toast', 'Soup'}-->{'Coffee'}, confidence:1.0
# Rules:{'Alfajores', 'Toast'}-->{'Tea'}, confidence:0.6
# Rules:{'Alfajores', 'Toast'}-->{'Coffee'}, confidence:0.8
# Rules:{'Muffin', 'Toast'}-->{'Coffee'}, confidence:0.6666666666666666
# Rules:{'Scone', 'Toast'}-->{'Coffee'}, confidence:0.8333333333333334
# Rules:{'Brownie', 'Tea', 'Toast'}-->{'Bread'}, confidence:0.6
# Rules:{'Bread', 'Brownie', 'Toast'}-->{'Tea'}, confidence:1.0
# Rules:{'Brownie', 'Toast'}-->{'Tea'}, confidence:0.7142857142857143
# Rules:{'Pastry', 'Toast'}-->{'Coffee'}, confidence:0.7777777777777778
# Rules:{'Medialuna', 'Toast'}-->{'Coffee'}, confidence:0.7272727272727273
# Rules:{'Juice', 'Toast'}-->{'Coffee'}, confidence:0.631578947368421
# Rules:{'Hot chocolate', 'Cake', 'Toast'}-->{'Coffee'}, confidence:1.0
# Rules:{'Cake', 'Tea', 'Toast'}-->{'Bread'}, confidence:0.6666666666666666
# Rules:{'Bread', 'Cake', 'Toast'}-->{'Tea'}, confidence:0.8
# Rules:{'Cake', 'Toast'}-->{'Coffee'}, confidence:0.6842105263157895
# Rules:{'Bread', 'Hot chocolate', 'Toast'}-->{'Coffee'}, confidence:0.6
# Rules:{'Toast'}-->{'Coffee'}, confidence:0.635593220338983
# Rules:{'Truffles', 'Cookies', 'Bread'}-->{'Coffee'}, confidence:0.75
# Rules:{'Coffee', 'Cookies', 'Truffles'}-->{'Bread'}, confidence:1.0
# Rules:{'Medialuna', 'Truffles', 'Juice'}-->{'Coffee'}, confidence:0.75
# Rules:{'Coffee', 'Medialuna', 'Truffles'}-->{'Juice'}, confidence:0.75
# Rules:{'Truffles', 'Sandwich', 'Pastry'}-->{'Coffee'}, confidence:1.0
# Rules:{'Truffles', 'Pastry'}-->{'Coffee'}, confidence:0.6
# Rules:{'Bread', 'Juice', 'Truffles'}-->{'Coffee'}, confidence:0.6
# Rules:{'Juice', 'Truffles', 'Sandwich'}-->{'Coffee'}, confidence:0.8
# Rules:{'Juice', 'Truffles'}-->{'Coffee'}, confidence:0.6111111111111112
# Rules:{'Cake', 'Truffles', 'Sandwich'}-->{'Coffee'}, confidence:0.6
# Rules:{'Bread', 'Truffles', 'Sandwich'}-->{'Coffee'}, confidence:0.75
# Rules:{'Truffles', 'Sandwich'}-->{'Coffee'}, confidence:0.6785714285714286
# Rules:{'Medialuna', 'Scone', 'Tea'}-->{'Coffee'}, confidence:0.6
# Rules:{'Scone', 'Cookies', 'Cake'}-->{'Coffee'}, confidence:1.0
# Rules:{'Scone', 'Cookies', 'Hot chocolate'}-->{'Coffee'}, confidence:0.8
# Rules:{'Bread', 'Scone', 'Cookies'}-->{'Coffee'}, confidence:0.8
# Rules:{'Scone', 'Cookies'}-->{'Coffee'}, confidence:0.75
# Rules:{'Juice', 'Scone', 'Cake'}-->{'Coffee'}, confidence:0.7142857142857143
# Rules:{'Juice', 'Scone'}-->{'Coffee'}, confidence:0.6111111111111112
# Rules:{'Hot chocolate', 'Scone', 'Cake'}-->{'Coffee'}, confidence:1.0
# Rules:{'Bread', 'Scone', 'Hot chocolate'}-->{'Coffee'}, confidence:0.75
# Rules:{'Scone', 'Hot chocolate'}-->{'Coffee'}, confidence:0.65
# Rules:{'Muffin', 'Alfajores', 'Hot chocolate'}-->{'Coffee'}, confidence:0.75
# Rules:{'Muffin', 'Coffee', 'Medialuna'}-->{'Bread'}, confidence:0.625
# Rules:{'Muffin', 'Bread', 'Medialuna'}-->{'Coffee'}, confidence:1.0
# Rules:{'Muffin', 'Sandwich', 'Tea'}-->{'Coffee'}, confidence:0.6
# Rules:{'Muffin', 'Sandwich'}-->{'Coffee'}, confidence:0.6470588235294118
# Rules:{'Muffin', 'Tea', 'Pastry'}-->{'Coffee'}, confidence:0.75
# Rules:{'Muffin', 'Juice', 'Cake'}-->{'Coffee'}, confidence:0.6
# Rules:{'Medialuna', 'Soup'}-->{'Coffee'}, confidence:0.7142857142857143
# Rules:{'Bread', 'Sandwich', 'Soup'}-->{'Cake'}, confidence:1.0
# Rules:{'Cake', 'Sandwich', 'Soup'}-->{'Coffee'}, confidence:0.75
# Rules:{'Sandwich', 'Soup'}-->{'Coffee'}, confidence:0.631578947368421
# Rules:{'Cake', 'Cookies', 'Brownie'}-->{'Coffee'}, confidence:1.0
# Rules:{'Tea', 'Cookies', 'Brownie'}-->{'Coffee'}, confidence:0.6
# Rules:{'Bread', 'Cookies', 'Brownie'}-->{'Coffee'}, confidence:0.7142857142857143
# Rules:{'Cookies', 'Brownie'}-->{'Coffee'}, confidence:0.6842105263157895
# Rules:{'Juice', 'Alfajores', 'Brownie'}-->{'Coffee'}, confidence:0.6666666666666666
# Rules:{'Juice', 'Brownie'}-->{'Coffee'}, confidence:0.6086956521739131
# Rules:{'Alfajores', 'Brownie', 'Hot chocolate'}-->{'Tea'}, confidence:0.6
# Rules:{'Alfajores', 'Brownie', 'Tea'}-->{'Bread'}, confidence:0.6666666666666666
# Rules:{'Hot chocolate', 'Brownie'}-->{'Coffee'}, confidence:0.6428571428571429
# Rules:{'Alfajores', 'Cookies', 'Hot chocolate'}-->{'Coffee'}, confidence:1.0
# Rules:{'Alfajores', 'Cookies', 'Sandwich'}-->{'Coffee'}, confidence:0.75
# Rules:{'Alfajores', 'Cookies', 'Tea'}-->{'Juice'}, confidence:0.8
# Rules:{'Juice', 'Alfajores', 'Cookies', 'Tea'}-->{'Coffee'}, confidence:0.75
# Rules:{'Alfajores', 'Cookies', 'Tea'}-->{'Coffee', 'Juice'}, confidence:0.6
# Rules:{'Coffee', 'Alfajores', 'Cookies', 'Tea'}-->{'Juice'}, confidence:0.75
# Rules:{'Coffee', 'Juice', 'Alfajores', 'Tea'}-->{'Cookies'}, confidence:1.0
# Rules:{'Coffee', 'Juice', 'Cookies', 'Tea'}-->{'Alfajores'}, confidence:0.75
# Rules:{'Alfajores', 'Cookies', 'Tea'}-->{'Coffee'}, confidence:0.8
# Rules:{'Juice', 'Alfajores', 'Cookies'}-->{'Coffee'}, confidence:0.6
# Rules:{'Alfajores', 'Cookies'}-->{'Coffee'}, confidence:0.65
# Rules:{'Bread', 'Alfajores', 'Pastry'}-->{'Coffee'}, confidence:0.6
# Rules:{'Bread', 'Alfajores', 'Pastry'}-->{'Tea'}, confidence:0.6
# Rules:{'Hot chocolate', 'Alfajores', 'Sandwich'}-->{'Coffee'}, confidence:1.0
# Rules:{'Alfajores', 'Sandwich', 'Cake'}-->{'Coffee'}, confidence:1.0
# Rules:{'Medialuna', 'Alfajores', 'Tea'}-->{'Bread'}, confidence:0.6
# Rules:{'Bread', 'Medialuna', 'Sandwich', 'Tea'}-->{'Coffee'}, confidence:1.0
# Rules:{'Coffee', 'Sandwich', 'Tea', 'Bread'}-->{'Medialuna'}, confidence:0.6
# Rules:{'Coffee', 'Medialuna', 'Sandwich', 'Tea'}-->{'Bread'}, confidence:0.75
# Rules:{'Medialuna', 'Sandwich', 'Tea'}-->{'Coffee'}, confidence:0.6666666666666666
# Rules:{'Coffee', 'Medialuna', 'Sandwich'}-->{'Bread'}, confidence:0.6
# Rules:{'Bread', 'Medialuna', 'Sandwich'}-->{'Coffee'}, confidence:0.8571428571428571
# Rules:{'Medialuna', 'Hot chocolate', 'Pastry'}-->{'Coffee'}, confidence:0.8333333333333334
# Rules:{'Bread', 'Medialuna', 'Hot chocolate'}-->{'Coffee'}, confidence:0.625
# Rules:{'Medialuna', 'Hot chocolate'}-->{'Coffee'}, confidence:0.6071428571428571
# Rules:{'Bread', 'Medialuna', 'Cake'}-->{'Coffee'}, confidence:0.6666666666666666
# Rules:{'Cake', 'Medialuna', 'Tea'}-->{'Coffee'}, confidence:0.6363636363636364
# Rules:{'Medialuna', 'Cake'}-->{'Coffee'}, confidence:0.6071428571428571
# Rules:{'Medialuna', 'Tea', 'Pastry'}-->{'Coffee'}, confidence:0.75
# Rules:{'Bread', 'Medialuna'}-->{'Coffee'}, confidence:0.6065573770491803
# Rules:{'Sandwich', 'Pastry'}-->{'Coffee'}, confidence:0.7777777777777778
# Rules:{'Juice', 'Pastry'}-->{'Coffee'}, confidence:0.6923076923076923
# Rules:{'Hot chocolate', 'Cake', 'Pastry'}-->{'Coffee'}, confidence:0.6
# Rules:{'Hot chocolate', 'Cake', 'Pastry'}-->{'Tea'}, confidence:0.6
# Rules:{'Bread', 'Hot chocolate', 'Pastry'}-->{'Coffee'}, confidence:0.75
# Rules:{'Hot chocolate', 'Pastry'}-->{'Coffee'}, confidence:0.6333333333333333
# Rules:{'Sandwich', 'Cookies', 'Tea'}-->{'Coffee'}, confidence:0.6666666666666666
# Rules:{'Hot chocolate', 'Cookies', 'Sandwich'}-->{'Coffee'}, confidence:0.8571428571428571
# Rules:{'Cookies', 'Sandwich'}-->{'Coffee'}, confidence:0.6086956521739131
# Rules:{'Bread', 'Hot chocolate', 'Cookies'}-->{'Coffee'}, confidence:0.6666666666666666
# Rules:{'Bread', 'Hot chocolate', 'Sandwich'}-->{'Coffee'}, confidence:0.6
# Rules:{'Hot chocolate', 'Sandwich', 'Cake'}-->{'Coffee'}, confidence:0.8333333333333334
# Rules:{'Hot chocolate', 'Sandwich'}-->{'Coffee'}, confidence:0.6666666666666666
# Rules:{'Bread', 'Hot chocolate', 'Cake'}-->{'Coffee'}, confidence:0.6153846153846154
# Rules:{'Juice', 'Sandwich', 'Cake'}-->{'Coffee'}, confidence:0.6666666666666666
# Rules:{'Tea', 'Sandwich', 'Cake'}-->{'Coffee'}, confidence:0.7
# Rules:{'Sandwich', 'Cake'}-->{'Coffee'}, confidence:0.6444444444444445
