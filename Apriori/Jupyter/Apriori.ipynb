# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
# %matplotlib inline

# from fastai.imports import *
# from fastai.structured import *
import matplotlib.pyplot as plt
# Input data files are available in the "../input/" directory.
# For example, running this (by clicking run or pressing Shift+Enter) will list the files in the input directory
import os

# %%
# Any results you write to the current directory are saved as output.

bakery_data=pd.read_csv("BreadBasket_DMS.csv")

bakery_data['Date Time']=bakery_data['Date']+" "+bakery_data['Time']

bakery_data=bakery_data.drop(['Date','Time'],axis=1)

# bakery_data['TID'] = bakery_data.index
# bakery_data.set_index(bakery_data['TID'],inplace=True)

bakery_data = bakery_data.drop(['Date Time'],axis=1)
bakery_data.Item.count()
# Out:
# 21293

# %%
bakery_data = bakery_data[~bakery_data['Item'].str.contains('NONE')]
bakery_data
# Out:
#        Transaction                  Item
# 0                1                 Bread
# 1                2          Scandinavian
# 2                2          Scandinavian
# 3                3         Hot chocolate
# 4                3                   Jam
# 5                3               Cookies
# 6                4                Muffin
# 7                5                Coffee
# 8                5                Pastry
# 9                5                 Bread
# 10               6             Medialuna
# 11               6                Pastry
# 12               6                Muffin
# 13               7             Medialuna
# 14               7                Pastry
# 15               7                Coffee
# 16               7                   Tea
# 17               8                Pastry
# 18               8                 Bread
# 19               9                 Bread
# 20               9                Muffin
# 21              10          Scandinavian
# 22              10             Medialuna
# 23              11                 Bread
# 24              11             Medialuna
# 25              11                 Bread
# 27              12                   Jam
# 28              12                Coffee
# 29              12               Tartine
# 30              12                Pastry
# ...            ...                   ...
# 21262         9670            Farm House
# 21263         9671                 Bread
# 21264         9672                Coffee
# 21265         9672               Cookies
# 21267         9672  Extra Salami or Feta
# 21268         9673        Spanish Brunch
# 21269         9673                Coffee
# 21270         9673                 Bread
# 21271         9674                Coffee
# 21272         9676             Smoothies
# 21273         9676              Sandwich
# 21274         9677          Tacos/Fajita
# 21275         9677                  Coke
# 21276         9678                Coffee
# 21277         9678          Tacos/Fajita
# 21278         9678                 Toast
# 21279         9679                 Bread
# 21280         9679        Spanish Brunch
# 21281         9680                 Bread
# 21282         9681              Truffles
# 21283         9681                   Tea
# 21284         9681        Spanish Brunch
# 21285         9681      Christmas common
# 21286         9682                Muffin
# 21287         9682          Tacos/Fajita
# 21288         9682                Coffee
# 21289         9682                   Tea
# 21290         9683                Coffee
# 21291         9683                Pastry
# 21292         9684             Smoothies
#
# [20507 rows x 2 columns]

# %%
tdl = []
for i in range(1,bakery_data.Transaction.count()+1):
    tdf = bakery_data[bakery_data.Transaction == i]
    l = set()
    for j in range(0,tdf.Transaction.count()):
        l.add(tdf.Item.iloc[j])
    if len(l)>0:
        tdl.append(list(l))
    else:
        tdl.append(None)
        
col = ['items']
TDB = pd.DataFrame({"items":tdl},columns=col)
TDB = TDB.dropna()
TDB
# Out:
#                                                   items
# 0                                               [Bread]
# 1                                        [Scandinavian]
# 2                         [Jam, Cookies, Hot chocolate]
# 3                                              [Muffin]
# 4                               [Pastry, Bread, Coffee]
# 5                           [Pastry, Medialuna, Muffin]
# 6                      [Pastry, Tea, Coffee, Medialuna]
# 7                                       [Pastry, Bread]
# 8                                       [Bread, Muffin]
# 9                             [Medialuna, Scandinavian]
# 10                                   [Bread, Medialuna]
# 11                  [Tea, Tartine, Coffee, Pastry, Jam]
# 12                              [Bread, Basket, Coffee]
# 13                           [Bread, Medialuna, Pastry]
# 14                        [Mineral water, Scandinavian]
# 15                           [Bread, Coffee, Medialuna]
# 16                                      [Hot chocolate]
# 17                                         [Farm House]
# 18                                  [Bread, Farm House]
# 19                                   [Bread, Medialuna]
# 20                           [Bread, Coffee, Medialuna]
# 21                                                [Jam]
# 22                               [Muffin, Scandinavian]
# 23                                              [Bread]
# 24                                       [Scandinavian]
# 25                                              [Fudge]
# 26                                       [Scandinavian]
# 27                                      [Bread, Coffee]
# 28                                         [Bread, Jam]
# 29                                              [Bread]
# ...                                                 ...
# 9650                                   [Pastry, Coffee]
# 9651                                         [Baguette]
# 9652                                     [Cake, Coffee]
# 9653  [My-5 Fruit Shoot, Hot chocolate, Half slice M...
# 9654                                              [Tea]
# 9655                                    [Toast, Coffee]
# 9656                                           [Coffee]
# 9657     [Spanish Brunch, Extra Salami or Feta, Coffee]
# 9658                                 [Cake, Tea, Juice]
# 9659                                            [Bread]
# 9663                                    [Bread, Coffee]
# 9664                    [Spanish Brunch, Coffee, Juice]
# 9665                                           [Coffee]
# 9666                                  [Bread, Sandwich]
# 9667                                       [Bread, Tea]
# 9668                                       [Farm House]
# 9669                                       [Farm House]
# 9670                                            [Bread]
# 9671            [Extra Salami or Feta, Coffee, Cookies]
# 9672                    [Bread, Spanish Brunch, Coffee]
# 9673                                           [Coffee]
# 9675                              [Sandwich, Smoothies]
# 9676                               [Coke, Tacos/Fajita]
# 9677                      [Toast, Tacos/Fajita, Coffee]
# 9678                            [Bread, Spanish Brunch]
# 9679                                            [Bread]
# 9680  [Truffles, Spanish Brunch, Christmas common, Tea]
# 9681                [Tea, Tacos/Fajita, Coffee, Muffin]
# 9682                                   [Pastry, Coffee]
# 9683                                        [Smoothies]
#
# [9465 rows x 1 columns]

# %%
import copy
import time

class Item:
    elements = []
    supp = 0

    def __init__(self, elements, supp=0):
        self.elements = elements
        self.supp = supp

    def __str__(self):
        returnstr = '[ '
        for e in self.elements:
            returnstr += e + ','
        returnstr += ' ]' + ' (support :%d)\t' % (self.supp)
        return returnstr

    def getSubset(self, k, size):
        subset = []
        if k == 1:
            for i in range(size):
                subset.append([self.elements[i]])
            return subset
        else:
            i = size - 1
            while i >= k - 1:
                myset = self.getSubset(k - 1, i)
                j = 0
                while j < len(myset):
                    # Attention a+=b  a=a+b
                    myset[j] += [self.elements[i]]  # Why Elements change here?
                    j += 1
                subset += (myset)
                i -= 1
            return subset

    def lastDiff(self, items):
        length = len(self.elements)
        if length != len(items.elements):  # length should be the same
            return False  # 兩邊長度要一樣才能進行混種
        if self.elements == items:  # if all the same,return false
            return False  # 兩邊內容若完全一樣不行進行混種
        return self.elements[0:length - 1] == items.elements[0:length - 1]

    # 兩邊內容最後一個元素以外的元素必須完全相同才能進行混種

    def setSupport(self, supp):
        self.supp = supp

    def join(self, items):
        temp = copy.copy(self.elements)
        temp.insert(len(self.elements), items.elements[len(items.elements) - 1])
        it = Item(temp, 0.0)
        return it


class C:
    '''candidate '''
    elements = []
    k = 0  # order

    def __init__(self, elements, k):
        self.elements = elements
        self.k = k

    def isEmpty(self):
        if len(self.elements) == 0:
            return True
        return False

    # get the same order of itemsets whose support is at lease the threshold
    def getL(self, threshold):  # 計算L2~Lk的function
        items = []
        for item in self.elements:
            if item.supp >= threshold:
                items.append(copy.copy(item))
        if len(items) == 0:
            return L([], self.k)
        return L(copy.deepcopy(items), self.k)

    def __str__(self):
        returnstr = str(self.k) + '-itemset:' + str(len(self.elements)) + ' \r\n{ '
        for e in self.elements:
            if True == isinstance(e, Item):
                returnstr += e.__str__()
        returnstr += ' }'
        return returnstr


class L:
    '''store all the  1-itemsets,2-itemsets,...k-itemsets'''
    items = []  # all the item in order K
    k = 0

    def __init__(self, items, k):
        self.items = items
        self.k = k

    def has_inFrequentItemsets(self, item):
        #        return False
        #        #先不優化
        subs = item.getSubset(self.k, len(item.elements))  # 取出候選item的subsets集合 ex:{ABC} ->{AB,AC,BC}
        for each in subs:  # 依序取出每個subset
            flag = False  # 代表目前subset是否為FrequentItemset
            for i in self.items:  # 依序從Lk中取出每個items (Lk中都是FrequentItemset)
                if i.elements == each:
                    flag = True  # 是，則直接判斷下一個subset
                    break
            if flag == False:
                return True  # 發現有subset為inFrequentItemset，則該候選item為inFrequentItemset

        return False  # 全部的subset皆為FrequentItemset，候選item不在inFrequentItemset中

    def aprioriGen(self):  # Generate Ck
        length = len(self.items)
        result = []  # store Ck
        for i in range(length):
            for j in range(i + 1, length):
                if self.items[i].lastDiff(self.items[j]):  # 若符合混種條件
                    item = self.items[i].join(self.items[j])  # 將Lk中的items交配混種，得k階候選item
                    if False == self.has_inFrequentItemsets(item):
                        # 用Apriori性質：任一頻繁項集的所有非空子集也必須是頻繁的，
                        # 反之，如果某個候選的非空子集不是頻繁的，那麼該候選肯定不是頻繁的，從而可以將其從CK中刪除。
                        result.append(item)
        if (len(result) == 0):
            return C([], self.k + 1)
        return C(result, self.k + 1)  # 回傳提升一階後的k & Ck

    def __str__(self):
        returnstr = "\r\n" + str(self.k) + '-itemsets :' + str(len(self.items)) + "\r\n{"
        for item in self.items:
            returnstr += item.__str__()
        returnstr += '}'
        return returnstr


class LS:
    '''store from L1-itemset to Lk-itemset'''
    values = {}  # L1,L2,Lk

    def get(self, k):
        return self.values[k]

    def size(self):
        return len(self.values)

    def put(self, l, k):
        self.values[k] = l

    def isEmpty(self):
        return self.size() == 0

    def __str__(self):
        returnstr = '-----result--------\r\n'
        for l in self.values:
            returnstr += self.values[l].__str__()
        return returnstr


class Rule:
    confidence = .0
    str_rule = ''

    def __init__(self, confidence, str_rule):
        self.confidence = confidence
        self.str_rule = str_rule

    def __str__(self):
        return 'Rule:' + self.str_rule + '  confidence:' + str(self.confidence)


class Apriori:
    def __init__(self, data, min_supp=2, ):
        #         inputfile = open(datafile,"r")
        self.data = []
        self.size = 0
        self.min_supp = min_supp
        self.data = data
        self.size = len(self.data)

    def findFrequent1Itemsets(self):
        totalItemsets = []  # store all the item from transaction
        for temp in self.data:
            totalItemsets.extend(temp)
        items = []  # store the 1-itemset s

        while len(totalItemsets) > 0:
            item = totalItemsets[0]  # get unique item from itemset
            count = 0
            j = 0
            while j < len(totalItemsets):  # calc item count
                if (item == totalItemsets[j]):
                    count += 1
                    totalItemsets.remove(item)  # remove the first occurence
                else:
                    j += 1
                    #             t_supp = count / self.size  # calc unique item support
            t_supp = count  # calc unique item support

            if t_supp >= self.min_supp:
                items.append(Item([item], t_supp))  # 1-itemset ([item1,...,item_n],support)

        temp = L(copy.deepcopy(items), 1)  # show info from 1-itemset
        return temp

    def ralationRules(self, maxSequence, min_confidence):
        # maxSequence : Lk中的所有itemsets
        ruls = []  # 存放所有的關聯式規則
        for each in maxSequence:
            for i in range(len(each.elements) - 1):  # real subsets
                subsets = each.getSubset(i + 1, len(each.elements))  # 對於每一個itemset計算出 (2^k)-2 個subset ,ex:k=4 14個subset
                for subset in subsets:  # 從subsets集合中取出每一個subset
                    count = 0
                    for tran_item in self.data:
                        flag = False  # 標記subset中的每個元素都在源中出現
                        for ele in subset:  # 從每一個subset中取出元素ele判斷是否在來源transaction中出現過
                            if ele not in tran_item:
                                flag = True
                                break
                        if flag == False:
                            count += 1  # subset出現在原始資料集中，計數值+1
                    confidence = each.supp / count  # 計算當前Lk itemset的信心值
                    # confidence = (Lk itemset出現次數) / (subset出現次數)
                    if confidence >= min_confidence:  # confidence/the number of the frequent pattern
                        # 計算由Lk itemSet 所衍伸出來的關聯式規則
                        # set(each.elements) - set(subset) Lk itemset與subset的差集 (代表衍伸會購買的物品)
                        str_rule = str(set(subset)) + '-->' + str(set(each.elements) - set(subset))
                        rule = Rule(confidence, str_rule)
                        ruls.append(rule)  # 加入一條新的關聯規則
        return ruls

    def do(self):
        ls = LS()
        oneitemset = self.findFrequent1Itemsets()
        ls.put(oneitemset, 1)  # ls add L1 itemset
        k = 2
        while False == ls.isEmpty():  # if Lk itemset is not empty : do-loop
            cand = ls.get(k - 1).aprioriGen()  # pick L(k-1) to generate Ck
            if cand.isEmpty():
                break  # if Ck is empty : break
            for each in cand.elements:  # 針對Ck裡每個item，從原來的itemset中找出符合規則的item
                count = 0
                for each_src in self.data:  # 判斷原先data set中的關聯
                    if len(each_src) < len(each.elements):  # pass 掉原先資料長度不夠的itemset
                        pass
                    else:
                        # 不是必須連續 相等才滿足條件，只要元素都在裡面即可
                        flag = True
                        for just_one_e in each.elements:  # 針對Ck裡每個item，檢查是否存在於原先data set中
                            flag = just_one_e in each_src
                            if flag == False:  # 只要有一個不在，即退出
                                break
                        if flag == True:  # 當前候選事件都在的話，計數
                            count += 1

                supp = count  # 計算當前候選itemset的support
                each.setSupport(supp)
            ls.put(cand.getL(apriori.min_supp), k)  # 以當前候選itemset為參數，計算Lk，並放入Lk set
            k += 1
        return ls


def getFinalRule(apriori, ls, minConf):  # 列印最後規則
    final_Lk = ls.get(ls.size())  # 取出最後的Lk
    print(final_Lk)
    rules = apriori.ralationRules(final_Lk.items, min_confidence=minConf)
    for rule in rules:
        print(rule)


def getAllRule(apriori, ls, minConf):  # 列印全部規則
    for i in range(1, ls.size()):
        Lk = ls.get(i)
        rules = apriori.ralationRules(Lk.items, min_confidence=minConf)
        for rule in rules:
            print(rule)

def getPatterns(ls):
    new_ls = {}
    for i in range(2,ls.size()+1):
        fls = str(ls.get(i)).split('\t')
        tt_fls = fls[0].split('\r\n')
        title = tt_fls[1]
        tt_fls[2] = tt_fls[2].replace('{','')

        new_fl=[]
        new_fl.extend([tt_fls[2]])
        new_fl.extend(fls[1:])   
        new_fl = [l for l in new_fl if l != '}']
        new_ls[title] = new_fl

    for title,l in new_ls.items():
        print(title)
        [print("Items:{}".format(items)) for items in l]    
        print()

# %%
if __name__=='__main__':    
    
def loadDataSet():    
    return TDB['items'].tolist()

starttime = time.time()
data = loadDataSet()
apriori = Apriori(data,min_supp=2)
minConf = 0.6
ls = apriori.do()
endtime = time.time()
print("\nTime Taken is: {}\n".format((endtime - starttime) * 1000))
print()
getPatterns(ls)

print('List All Rules')
# getFinalRule(apriori,ls,minConf)
getAllRule(apriori,ls,minConf)
# Out:
# Time Taken is: 27645.23673057556
#
#
# 2-itemsets :714
# Items:[ Bread,Scandinavian, ] (support :62)
# Items:[ Bread,Jam, ] (support :48)
# Items:[ Bread,Cookies, ] (support :137)
# Items:[ Bread,Hot chocolate, ] (support :127)
# Items:[ Bread,Muffin, ] (support :77)
# Items:[ Bread,Pastry, ] (support :276)
# Items:[ Bread,Coffee, ] (support :852)
# Items:[ Bread,Medialuna, ] (support :160)
# Items:[ Bread,Tea, ] (support :266)
# Items:[ Bread,Tartine, ] (support :8)
# Items:[ Bread,Basket, ] (support :2)
# Items:[ Bread,Mineral water, ] (support :30)
# Items:[ Bread,Farm House, ] (support :47)
# Items:[ Bread,Fudge, ] (support :31)
# Items:[ Bread,Juice, ] (support :70)
# Items:[ Bread,Ella's Kitchen Pouches, ] (support :5)
# Items:[ Bread,Victorian Sponge, ] (support :2)
# Items:[ Bread,Hearty & Seasonal, ] (support :25)
# Items:[ Bread,Frittata, ] (support :25)
# Items:[ Bread,Soup, ] (support :62)
# Items:[ Bread,Smoothies, ] (support :23)
# Items:[ Bread,Cake, ] (support :221)
# Items:[ Bread,Coke, ] (support :18)
# Items:[ Bread,My-5 Fruit Shoot, ] (support :5)
# Items:[ Bread,Focaccia, ] (support :19)
# Items:[ Bread,Sandwich, ] (support :161)
# Items:[ Bread,Alfajores, ] (support :98)
# Items:[ Bread,Eggs, ] (support :14)
# Items:[ Bread,Brownie, ] (support :102)
# Items:[ Bread,Dulce de Leche, ] (support :2)
# Items:[ Bread,Honey, ] (support :2)
# Items:[ Bread,Granola, ] (support :9)
# Items:[ Bread,Empanadas, ] (support :3)
# Items:[ Bread,Keeping It Local, ] (support :21)
# Items:[ Bread,Art Tray, ] (support :6)
# Items:[ Bread,Truffles, ] (support :47)
# Items:[ Bread,Kids biscuit, ] (support :2)
# Items:[ Bread,Jammie Dodgers, ] (support :44)
# Items:[ Bread,Tiffin, ] (support :46)
# Items:[ Bread,The Nomad, ] (support :16)
# Items:[ Bread,Bakewell, ] (support :11)
# Items:[ Bread,Lemon and coconut, ] (support :3)
# Items:[ Bread,Toast, ] (support :74)
# Items:[ Bread,Scone, ] (support :86)
# Items:[ Bread,Vegan mincepie, ] (support :13)
# Items:[ Bread,Muesli, ] (support :3)
# Items:[ Bread,Crisps, ] (support :4)
# Items:[ Bread,Brioche and salami, ] (support :2)
# Items:[ Bread,Afternoon with the baker, ] (support :3)
# Items:[ Bread,Salad, ] (support :19)
# Items:[ Bread,Chicken Stew, ] (support :26)
# Items:[ Bread,Spanish Brunch, ] (support :45)
# Items:[ Bread,Extra Salami or Feta, ] (support :10)
# Items:[ Bread,Duck egg, ] (support :2)
# Items:[ Bread,Baguette, ] (support :26)
# Items:[ Bread,Nomad bag, ] (support :6)
# Items:[ Bread,Chocolates, ] (support :2)
# Items:[ Bread,Drinking chocolate spoons , ] (support :5)
# Items:[ Bread,Christmas common, ] (support :3)
# Items:[ Bread,Tacos/Fajita, ] (support :3)
# Items:[ Scandinavian,Jam, ] (support :4)
# Items:[ Scandinavian,Cookies, ] (support :8)
# Items:[ Scandinavian,Hot chocolate, ] (support :5)
# Items:[ Scandinavian,Muffin, ] (support :13)
# Items:[ Scandinavian,Pastry, ] (support :14)
# Items:[ Scandinavian,Coffee, ] (support :46)
# Items:[ Scandinavian,Medialuna, ] (support :12)
# Items:[ Scandinavian,Tea, ] (support :8)
# Items:[ Scandinavian,Mineral water, ] (support :3)
# Items:[ Scandinavian,Farm House, ] (support :16)
# Items:[ Scandinavian,Fudge, ] (support :4)
# Items:[ Scandinavian,Frittata, ] (support :3)
# Items:[ Scandinavian,Soup, ] (support :3)
# Items:[ Scandinavian,Cake, ] (support :14)
# Items:[ Scandinavian,Focaccia, ] (support :4)
# Items:[ Scandinavian,Sandwich, ] (support :3)
# Items:[ Scandinavian,Alfajores, ] (support :14)
# Items:[ Scandinavian,Eggs, ] (support :2)
# Items:[ Scandinavian,Brownie, ] (support :5)
# Items:[ Scandinavian,Granola, ] (support :2)
# Items:[ Scandinavian,Truffles, ] (support :3)
# Items:[ Scandinavian,Toast, ] (support :4)
# Items:[ Scandinavian,Scone, ] (support :4)
# Items:[ Scandinavian,Salad, ] (support :3)
# Items:[ Scandinavian,Extra Salami or Feta, ] (support :2)
# Items:[ Scandinavian,Baguette, ] (support :9)
# Items:[ Jam,Cookies, ] (support :5)
# Items:[ Jam,Hot chocolate, ] (support :4)
# Items:[ Jam,Muffin, ] (support :4)
# Items:[ Jam,Pastry, ] (support :12)
# Items:[ Jam,Coffee, ] (support :39)
# Items:[ Jam,Medialuna, ] (support :5)
# Items:[ Jam,Tea, ] (support :12)
# Items:[ Jam,Tartine, ] (support :4)
# Items:[ Jam,Farm House, ] (support :6)
# Items:[ Jam,Fudge, ] (support :24)
# Items:[ Jam,Juice, ] (support :5)
# Items:[ Jam,Ella's Kitchen Pouches, ] (support :2)
# Items:[ Jam,Frittata, ] (support :2)
# Items:[ Jam,Soup, ] (support :5)
# Items:[ Jam,Pick and Mix Bowls, ] (support :2)
# Items:[ Jam,Cake, ] (support :6)
# Items:[ Jam,Sandwich, ] (support :3)
# Items:[ Jam,Alfajores, ] (support :2)
# Items:[ Jam,Brownie, ] (support :3)
# Items:[ Jam,Keeping It Local, ] (support :2)
# Items:[ Jam,Scone, ] (support :2)
# Items:[ Jam,Salad, ] (support :2)
# Items:[ Jam,Spanish Brunch, ] (support :3)
# Items:[ Jam,Christmas common, ] (support :2)
# Items:[ Cookies,Hot chocolate, ] (support :57)
# Items:[ Cookies,Muffin, ] (support :16)
# Items:[ Cookies,Pastry, ] (support :28)
# Items:[ Cookies,Coffee, ] (support :267)
# Items:[ Cookies,Medialuna, ] (support :24)
# Items:[ Cookies,Tea, ] (support :93)
# Items:[ Cookies,Tartine, ] (support :2)
# Items:[ Cookies,Mineral water, ] (support :13)
# Items:[ Cookies,Farm House, ] (support :12)
# Items:[ Cookies,Fudge, ] (support :3)
# Items:[ Cookies,Juice, ] (support :58)
# Items:[ Cookies,Ella's Kitchen Pouches, ] (support :3)
# Items:[ Cookies,Hearty & Seasonal, ] (support :3)
# Items:[ Cookies,Frittata, ] (support :4)
# Items:[ Cookies,Soup, ] (support :12)
# Items:[ Cookies,Pick and Mix Bowls, ] (support :2)
# Items:[ Cookies,Smoothies, ] (support :5)
# Items:[ Cookies,Cake, ] (support :69)
# Items:[ Cookies,Coke, ] (support :6)
# Items:[ Cookies,My-5 Fruit Shoot, ] (support :4)
# Items:[ Cookies,Focaccia, ] (support :2)
# Items:[ Cookies,Sandwich, ] (support :27)
# Items:[ Cookies,Alfajores, ] (support :23)
# Items:[ Cookies,Brownie, ] (support :24)
# Items:[ Cookies,Keeping It Local, ] (support :3)
# Items:[ Cookies,Art Tray, ] (support :4)
# Items:[ Cookies,Truffles, ] (support :7)
# Items:[ Cookies,Jammie Dodgers, ] (support :10)
# Items:[ Cookies,Tiffin, ] (support :12)
# Items:[ Cookies,The Nomad, ] (support :3)
# Items:[ Cookies,Bakewell, ] (support :4)
# Items:[ Cookies,Toast, ] (support :21)
# Items:[ Cookies,Scone, ] (support :19)
# Items:[ Cookies,Vegan mincepie, ] (support :3)
# Items:[ Cookies,Bare Popcorn, ] (support :2)
# Items:[ Cookies,Crisps, ] (support :2)
# Items:[ Cookies,Salad, ] (support :4)
# Items:[ Cookies,Chicken Stew, ] (support :4)
# Items:[ Cookies,Spanish Brunch, ] (support :7)
# Items:[ Cookies,Extra Salami or Feta, ] (support :3)
# Items:[ Cookies,Duck egg, ] (support :2)
# Items:[ Cookies,Baguette, ] (support :7)
# Items:[ Cookies,Vegan Feast, ] (support :2)
# Items:[ Cookies,Chocolates, ] (support :2)
# Items:[ Hot chocolate,Muffin, ] (support :34)
# Items:[ Hot chocolate,Pastry, ] (support :54)
# Items:[ Hot chocolate,Coffee, ] (support :280)
# Items:[ Hot chocolate,Medialuna, ] (support :45)
# Items:[ Hot chocolate,Tea, ] (support :76)
# Items:[ Hot chocolate,Tartine, ] (support :2)
# Items:[ Hot chocolate,Basket, ] (support :2)
# Items:[ Hot chocolate,Mineral water, ] (support :9)
# Items:[ Hot chocolate,Farm House, ] (support :8)
# Items:[ Hot chocolate,Fudge, ] (support :5)
# Items:[ Hot chocolate,Juice, ] (support :21)
# Items:[ Hot chocolate,Hearty & Seasonal, ] (support :7)
# Items:[ Hot chocolate,Soup, ] (support :8)
# Items:[ Hot chocolate,Smoothies, ] (support :8)
# Items:[ Hot chocolate,Cake, ] (support :108)
# Items:[ Hot chocolate,Coke, ] (support :6)
# Items:[ Hot chocolate,My-5 Fruit Shoot, ] (support :3)
# Items:[ Hot chocolate,Sandwich, ] (support :42)
# Items:[ Hot chocolate,Alfajores, ] (support :34)
# Items:[ Hot chocolate,Eggs, ] (support :2)
# Items:[ Hot chocolate,Brownie, ] (support :39)
# Items:[ Hot chocolate,Granola, ] (support :2)
# Items:[ Hot chocolate,Keeping It Local, ] (support :2)
# Items:[ Hot chocolate,Art Tray, ] (support :6)
# Items:[ Hot chocolate,Truffles, ] (support :8)
# Items:[ Hot chocolate,Jammie Dodgers, ] (support :14)
# Items:[ Hot chocolate,Tiffin, ] (support :13)
# Items:[ Hot chocolate,The Nomad, ] (support :3)
# Items:[ Hot chocolate,Bakewell, ] (support :3)
# Items:[ Hot chocolate,Toast, ] (support :29)
# Items:[ Hot chocolate,Scone, ] (support :28)
# Items:[ Hot chocolate,Vegan mincepie, ] (support :9)
# Items:[ Hot chocolate,Crisps, ] (support :3)
# Items:[ Hot chocolate,Salad, ] (support :2)
# Items:[ Hot chocolate,Chicken Stew, ] (support :3)
# Items:[ Hot chocolate,Spanish Brunch, ] (support :8)
# Items:[ Hot chocolate,Extra Salami or Feta, ] (support :2)
# Items:[ Hot chocolate,Baguette, ] (support :4)
# Items:[ Hot chocolate,Chocolates, ] (support :4)
# Items:[ Hot chocolate,Drinking chocolate spoons , ] (support :2)
# Items:[ Muffin,Pastry, ] (support :24)
# Items:[ Muffin,Coffee, ] (support :178)
# Items:[ Muffin,Medialuna, ] (support :19)
# Items:[ Muffin,Tea, ] (support :62)
# Items:[ Muffin,Tartine, ] (support :2)
# Items:[ Muffin,Mineral water, ] (support :5)
# Items:[ Muffin,Farm House, ] (support :7)
# Items:[ Muffin,Fudge, ] (support :4)
# Items:[ Muffin,Juice, ] (support :26)
# Items:[ Muffin,Ella's Kitchen Pouches, ] (support :2)
# Items:[ Muffin,Hearty & Seasonal, ] (support :6)
# Items:[ Muffin,Frittata, ] (support :6)
# Items:[ Muffin,Soup, ] (support :12)
# Items:[ Muffin,Smoothies, ] (support :8)
# Items:[ Muffin,Cake, ] (support :46)
# Items:[ Muffin,Coke, ] (support :5)
# Items:[ Muffin,My-5 Fruit Shoot, ] (support :3)
# Items:[ Muffin,Sandwich, ] (support :20)
# Items:[ Muffin,Alfajores, ] (support :16)
# Items:[ Muffin,Brownie, ] (support :17)
# Items:[ Muffin,Art Tray, ] (support :3)
# Items:[ Muffin,Truffles, ] (support :5)
# Items:[ Muffin,Kids biscuit, ] (support :3)
# Items:[ Muffin,Jammie Dodgers, ] (support :9)
# Items:[ Muffin,Tiffin, ] (support :6)
# Items:[ Muffin,The Nomad, ] (support :2)
# Items:[ Muffin,Toast, ] (support :6)
# Items:[ Muffin,Scone, ] (support :7)
# Items:[ Muffin,Salad, ] (support :2)
# Items:[ Muffin,Spanish Brunch, ] (support :3)
# Items:[ Muffin,Baguette, ] (support :3)
# Items:[ Pastry,Coffee, ] (support :450)
# Items:[ Pastry,Medialuna, ] (support :87)
# Items:[ Pastry,Tea, ] (support :91)
# Items:[ Pastry,Tartine, ] (support :3)
# Items:[ Pastry,Mineral water, ] (support :2)
# Items:[ Pastry,Farm House, ] (support :26)
# Items:[ Pastry,Fudge, ] (support :5)
# Items:[ Pastry,Juice, ] (support :22)
# Items:[ Pastry,Ella's Kitchen Pouches, ] (support :2)
# Items:[ Pastry,Hearty & Seasonal, ] (support :3)
# Items:[ Pastry,Frittata, ] (support :5)
# Items:[ Pastry,Soup, ] (support :9)
# Items:[ Pastry,Smoothies, ] (support :4)
# Items:[ Pastry,Cake, ] (support :49)
# Items:[ Pastry,Coke, ] (support :8)
# Items:[ Pastry,Focaccia, ] (support :4)
# Items:[ Pastry,Sandwich, ] (support :11)
# Items:[ Pastry,Alfajores, ] (support :31)
# Items:[ Pastry,Eggs, ] (support :3)
# Items:[ Pastry,Brownie, ] (support :23)
# Items:[ Pastry,Dulce de Leche, ] (support :2)
# Items:[ Pastry,Granola, ] (support :4)
# Items:[ Pastry,Keeping It Local, ] (support :3)
# Items:[ Pastry,Art Tray, ] (support :2)
# Items:[ Pastry,Truffles, ] (support :16)
# Items:[ Pastry,Jammie Dodgers, ] (support :4)
# Items:[ Pastry,Tiffin, ] (support :7)
# Items:[ Pastry,The Nomad, ] (support :5)
# Items:[ Pastry,Bakewell, ] (support :3)
# Items:[ Pastry,Toast, ] (support :15)
# Items:[ Pastry,Scone, ] (support :23)
# Items:[ Pastry,Vegan mincepie, ] (support :3)
# Items:[ Pastry,Salad, ] (support :2)
# Items:[ Pastry,Chicken Stew, ] (support :5)
# Items:[ Pastry,Spanish Brunch, ] (support :4)
# Items:[ Pastry,Baguette, ] (support :8)
# Items:[ Coffee,Medialuna, ] (support :333)
# Items:[ Coffee,Tea, ] (support :472)
# Items:[ Coffee,Tartine, ] (support :29)
# Items:[ Coffee,Basket, ] (support :4)
# Items:[ Coffee,Mineral water, ] (support :53)
# Items:[ Coffee,Farm House, ] (support :63)
# Items:[ Coffee,Fudge, ] (support :31)
# Items:[ Coffee,Juice, ] (support :195)
# Items:[ Coffee,Ella's Kitchen Pouches, ] (support :6)
# Items:[ Coffee,Hearty & Seasonal, ] (support :54)
# Items:[ Coffee,Frittata, ] (support :43)
# Items:[ Coffee,Soup, ] (support :150)
# Items:[ Coffee,Pick and Mix Bowls, ] (support :6)
# Items:[ Coffee,Smoothies, ] (support :38)
# Items:[ Coffee,Cake, ] (support :518)
# Items:[ Coffee,Mighty Protein, ] (support :9)
# Items:[ Coffee,Coke, ] (support :61)
# Items:[ Coffee,My-5 Fruit Shoot, ] (support :7)
# Items:[ Coffee,Focaccia, ] (support :9)
# Items:[ Coffee,Sandwich, ] (support :362)
# Items:[ Coffee,Alfajores, ] (support :186)
# Items:[ Coffee,Eggs, ] (support :7)
# Items:[ Coffee,Brownie, ] (support :186)
# Items:[ Coffee,Dulce de Leche, ] (support :3)
# Items:[ Coffee,Honey, ] (support :2)
# Items:[ Coffee,Granola, ] (support :17)
# Items:[ Coffee,Empanadas, ] (support :4)
# Items:[ Coffee,Keeping It Local, ] (support :51)
# Items:[ Coffee,Art Tray, ] (support :26)
# Items:[ Coffee,Bowl Nic Pitt, ] (support :2)
# Items:[ Coffee,Bread Pudding, ] (support :4)
# Items:[ Coffee,Truffles, ] (support :71)
# Items:[ Coffee,Kids biscuit, ] (support :6)
# Items:[ Coffee,Caramel bites, ] (support :2)
# Items:[ Coffee,Jammie Dodgers, ] (support :63)
# Items:[ Coffee,Tiffin, ] (support :80)
# Items:[ Coffee,The Nomad, ] (support :31)
# Items:[ Coffee,Bakewell, ] (support :29)
# Items:[ Coffee,Lemon and coconut, ] (support :4)
# Items:[ Coffee,Toast, ] (support :224)
# Items:[ Coffee,Scone, ] (support :171)
# Items:[ Coffee,Crepes, ] (support :2)
# Items:[ Coffee,Vegan mincepie, ] (support :30)
# Items:[ Coffee,Bare Popcorn, ] (support :3)
# Items:[ Coffee,Muesli, ] (support :3)
# Items:[ Coffee,Crisps, ] (support :8)
# Items:[ Coffee,Gingerbread syrup, ] (support :2)
# Items:[ Coffee,Brioche and salami, ] (support :2)
# Items:[ Coffee,Afternoon with the baker, ] (support :4)
# Items:[ Coffee,Salad, ] (support :62)
# Items:[ Coffee,Chicken Stew, ] (support :49)
# Items:[ Coffee,Spanish Brunch, ] (support :103)
# Items:[ Coffee,Extra Salami or Feta, ] (support :31)
# Items:[ Coffee,Duck egg, ] (support :7)
# Items:[ Coffee,Baguette, ] (support :28)
# Items:[ Coffee,Vegan Feast, ] (support :2)
# Items:[ Coffee,Nomad bag, ] (support :4)
# Items:[ Coffee,Chocolates, ] (support :5)
# Items:[ Coffee,Coffee granules , ] (support :2)
# Items:[ Coffee,Drinking chocolate spoons , ] (support :5)
# Items:[ Coffee,Half slice Monster , ] (support :2)
# Items:[ Coffee,Cherry me Dried fruit, ] (support :2)
# Items:[ Coffee,Tacos/Fajita, ] (support :5)
# Items:[ Medialuna,Tea, ] (support :77)
# Items:[ Medialuna,Tartine, ] (support :2)
# Items:[ Medialuna,Mineral water, ] (support :3)
# Items:[ Medialuna,Farm House, ] (support :22)
# Items:[ Medialuna,Fudge, ] (support :7)
# Items:[ Medialuna,Juice, ] (support :20)
# Items:[ Medialuna,Ella's Kitchen Pouches, ] (support :3)
# Items:[ Medialuna,Hearty & Seasonal, ] (support :3)
# Items:[ Medialuna,Frittata, ] (support :3)
# Items:[ Medialuna,Soup, ] (support :7)
# Items:[ Medialuna,Smoothies, ] (support :2)
# Items:[ Medialuna,Cake, ] (support :35)
# Items:[ Medialuna,Coke, ] (support :7)
# Items:[ Medialuna,Focaccia, ] (support :6)
# Items:[ Medialuna,Sandwich, ] (support :20)
# Items:[ Medialuna,Alfajores, ] (support :30)
# Items:[ Medialuna,Eggs, ] (support :2)
# Items:[ Medialuna,Brownie, ] (support :19)
# Items:[ Medialuna,Dulce de Leche, ] (support :2)
# Items:[ Medialuna,Keeping It Local, ] (support :2)
# Items:[ Medialuna,Truffles, ] (support :12)
# Items:[ Medialuna,Jammie Dodgers, ] (support :7)
# Items:[ Medialuna,Tiffin, ] (support :7)
# Items:[ Medialuna,The Nomad, ] (support :4)
# Items:[ Medialuna,Bakewell, ] (support :2)
# Items:[ Medialuna,Toast, ] (support :18)
# Items:[ Medialuna,Scone, ] (support :14)
# Items:[ Medialuna,Crepes, ] (support :2)
# Items:[ Medialuna,Vegan mincepie, ] (support :2)
# Items:[ Medialuna,Crisps, ] (support :2)
# Items:[ Medialuna,Chicken Stew, ] (support :5)
# Items:[ Medialuna,Spanish Brunch, ] (support :7)
# Items:[ Medialuna,Baguette, ] (support :5)
# Items:[ Tea,Tartine, ] (support :9)
# Items:[ Tea,Mineral water, ] (support :12)
# Items:[ Tea,Farm House, ] (support :15)
# Items:[ Tea,Fudge, ] (support :11)
# Items:[ Tea,Juice, ] (support :68)
# Items:[ Tea,Ella's Kitchen Pouches, ] (support :4)
# Items:[ Tea,Victorian Sponge, ] (support :4)
# Items:[ Tea,Hearty & Seasonal, ] (support :19)
# Items:[ Tea,Frittata, ] (support :18)
# Items:[ Tea,Soup, ] (support :86)
# Items:[ Tea,Smoothies, ] (support :9)
# Items:[ Tea,Cake, ] (support :225)
# Items:[ Tea,Mighty Protein, ] (support :3)
# Items:[ Tea,Coke, ] (support :21)
# Items:[ Tea,Focaccia, ] (support :5)
# Items:[ Tea,Sandwich, ] (support :136)
# Items:[ Tea,Alfajores, ] (support :64)
# Items:[ Tea,Brownie, ] (support :64)
# Items:[ Tea,Honey, ] (support :2)
# Items:[ Tea,Granola, ] (support :7)
# Items:[ Tea,Empanadas, ] (support :2)
# Items:[ Tea,Keeping It Local, ] (support :17)
# Items:[ Tea,Art Tray, ] (support :11)
# Items:[ Tea,Truffles, ] (support :29)
# Items:[ Tea,Jammie Dodgers, ] (support :24)
# Items:[ Tea,Tiffin, ] (support :33)
# Items:[ Tea,The Nomad, ] (support :17)
# Items:[ Tea,Bakewell, ] (support :12)
# Items:[ Tea,Lemon and coconut, ] (support :2)
# Items:[ Tea,Toast, ] (support :61)
# Items:[ Tea,Scone, ] (support :79)
# Items:[ Tea,Vegan mincepie, ] (support :7)
# Items:[ Tea,Muesli, ] (support :2)
# Items:[ Tea,Afternoon with the baker, ] (support :3)
# Items:[ Tea,Salad, ] (support :19)
# Items:[ Tea,Chicken Stew, ] (support :30)
# Items:[ Tea,Spanish Brunch, ] (support :44)
# Items:[ Tea,Raspberry shortbread sandwich, ] (support :2)
# Items:[ Tea,Extra Salami or Feta, ] (support :6)
# Items:[ Tea,Duck egg, ] (support :6)
# Items:[ Tea,Baguette, ] (support :3)
# Items:[ Tea,Chocolates, ] (support :3)
# Items:[ Tea,Argentina Night, ] (support :2)
# Items:[ Tea,Tacos/Fajita, ] (support :3)
# Items:[ Tartine,Mineral water, ] (support :2)
# Items:[ Tartine,Juice, ] (support :4)
# Items:[ Tartine,Pick and Mix Bowls, ] (support :3)
# Items:[ Tartine,Sandwich, ] (support :2)
# Items:[ Tartine,Brownie, ] (support :2)
# Items:[ Mineral water,Juice, ] (support :16)
# Items:[ Mineral water,Hearty & Seasonal, ] (support :9)
# Items:[ Mineral water,Frittata, ] (support :6)
# Items:[ Mineral water,Soup, ] (support :18)
# Items:[ Mineral water,Pick and Mix Bowls, ] (support :3)
# Items:[ Mineral water,Smoothies, ] (support :2)
# Items:[ Mineral water,Cake, ] (support :13)
# Items:[ Mineral water,Coke, ] (support :11)
# Items:[ Mineral water,Sandwich, ] (support :31)
# Items:[ Mineral water,Alfajores, ] (support :12)
# Items:[ Mineral water,Brownie, ] (support :9)
# Items:[ Mineral water,Truffles, ] (support :11)
# Items:[ Mineral water,Tiffin, ] (support :4)
# Items:[ Mineral water,Toast, ] (support :4)
# Items:[ Mineral water,Scone, ] (support :7)
# Items:[ Mineral water,Vegan mincepie, ] (support :2)
# Items:[ Mineral water,Crisps, ] (support :2)
# Items:[ Mineral water,Salad, ] (support :6)
# Items:[ Mineral water,Chicken Stew, ] (support :3)
# Items:[ Mineral water,Spanish Brunch, ] (support :4)
# Items:[ Mineral water,Drinking chocolate spoons , ] (support :2)
# Items:[ Farm House,Fudge, ] (support :3)
# Items:[ Farm House,Juice, ] (support :5)
# Items:[ Farm House,Hearty & Seasonal, ] (support :2)
# Items:[ Farm House,Frittata, ] (support :2)
# Items:[ Farm House,Soup, ] (support :4)
# Items:[ Farm House,Cake, ] (support :14)
# Items:[ Farm House,Coke, ] (support :3)
# Items:[ Farm House,Focaccia, ] (support :4)
# Items:[ Farm House,Sandwich, ] (support :4)
# Items:[ Farm House,Alfajores, ] (support :4)
# Items:[ Farm House,Brownie, ] (support :11)
# Items:[ Farm House,Truffles, ] (support :2)
# Items:[ Farm House,Tiffin, ] (support :3)
# Items:[ Farm House,Toast, ] (support :6)
# Items:[ Farm House,Scone, ] (support :4)
# Items:[ Farm House,Salad, ] (support :2)
# Items:[ Farm House,Spanish Brunch, ] (support :4)
# Items:[ Farm House,Baguette, ] (support :6)
# Items:[ Fudge,Juice, ] (support :2)
# Items:[ Fudge,Frittata, ] (support :2)
# Items:[ Fudge,Cake, ] (support :6)
# Items:[ Fudge,Focaccia, ] (support :4)
# Items:[ Fudge,Sandwich, ] (support :14)
# Items:[ Fudge,Alfajores, ] (support :7)
# Items:[ Fudge,Eggs, ] (support :2)
# Items:[ Fudge,Brownie, ] (support :5)
# Items:[ Fudge,Dulce de Leche, ] (support :2)
# Items:[ Fudge,Truffles, ] (support :2)
# Items:[ Fudge,Toast, ] (support :2)
# Items:[ Fudge,Chicken Stew, ] (support :2)
# Items:[ Fudge,Spanish Brunch, ] (support :2)
# Items:[ Juice,Ella's Kitchen Pouches, ] (support :6)
# Items:[ Juice,Hearty & Seasonal, ] (support :4)
# Items:[ Juice,Frittata, ] (support :4)
# Items:[ Juice,Soup, ] (support :17)
# Items:[ Juice,Pick and Mix Bowls, ] (support :4)
# Items:[ Juice,Smoothies, ] (support :5)
# Items:[ Juice,Cake, ] (support :67)
# Items:[ Juice,Coke, ] (support :21)
# Items:[ Juice,My-5 Fruit Shoot, ] (support :2)
# Items:[ Juice,Sandwich, ] (support :55)
# Items:[ Juice,Alfajores, ] (support :29)
# Items:[ Juice,Eggs, ] (support :3)
# Items:[ Juice,Brownie, ] (support :24)
# Items:[ Juice,Granola, ] (support :2)
# Items:[ Juice,Art Tray, ] (support :8)
# Items:[ Juice,Truffles, ] (support :19)
# Items:[ Juice,Jammie Dodgers, ] (support :20)
# Items:[ Juice,Tiffin, ] (support :9)
# Items:[ Juice,The Nomad, ] (support :4)
# Items:[ Juice,Bakewell, ] (support :5)
# Items:[ Juice,Toast, ] (support :22)
# Items:[ Juice,Scone, ] (support :19)
# Items:[ Juice,Vegan mincepie, ] (support :4)
# Items:[ Juice,Bare Popcorn, ] (support :2)
# Items:[ Juice,Crisps, ] (support :6)
# Items:[ Juice,Afternoon with the baker, ] (support :2)
# Items:[ Juice,Salad, ] (support :10)
# Items:[ Juice,Chicken Stew, ] (support :16)
# Items:[ Juice,Spanish Brunch, ] (support :26)
# Items:[ Juice,Extra Salami or Feta, ] (support :4)
# Items:[ Juice,Baguette, ] (support :3)
# Items:[ Juice,Chocolates, ] (support :4)
# Items:[ Juice,Drinking chocolate spoons , ] (support :2)
# Items:[ Juice,Half slice Monster , ] (support :2)
# Items:[ Juice,Tacos/Fajita, ] (support :3)
# Items:[ Hearty & Seasonal,Frittata, ] (support :2)
# Items:[ Hearty & Seasonal,Soup, ] (support :12)
# Items:[ Hearty & Seasonal,Pick and Mix Bowls, ] (support :3)
# Items:[ Hearty & Seasonal,Smoothies, ] (support :5)
# Items:[ Hearty & Seasonal,Cake, ] (support :7)
# Items:[ Hearty & Seasonal,Mighty Protein, ] (support :2)
# Items:[ Hearty & Seasonal,Coke, ] (support :2)
# Items:[ Hearty & Seasonal,Focaccia, ] (support :2)
# Items:[ Hearty & Seasonal,Sandwich, ] (support :14)
# Items:[ Hearty & Seasonal,Alfajores, ] (support :4)
# Items:[ Hearty & Seasonal,Brownie, ] (support :6)
# Items:[ Hearty & Seasonal,Keeping It Local, ] (support :2)
# Items:[ Hearty & Seasonal,Art Tray, ] (support :2)
# Items:[ Hearty & Seasonal,Truffles, ] (support :3)
# Items:[ Hearty & Seasonal,Scone, ] (support :2)
# Items:[ Frittata,Soup, ] (support :4)
# Items:[ Frittata,Smoothies, ] (support :2)
# Items:[ Frittata,Cake, ] (support :3)
# Items:[ Frittata,Coke, ] (support :2)
# Items:[ Frittata,Sandwich, ] (support :8)
# Items:[ Frittata,Alfajores, ] (support :2)
# Items:[ Frittata,Brownie, ] (support :4)
# Items:[ Frittata,Art Tray, ] (support :2)
# Items:[ Frittata,Truffles, ] (support :5)
# Items:[ Frittata,Toast, ] (support :2)
# Items:[ Frittata,Scone, ] (support :7)
# Items:[ Frittata,Crisps, ] (support :2)
# Items:[ Frittata,Salad, ] (support :2)
# Items:[ Soup,Smoothies, ] (support :7)
# Items:[ Soup,Cake, ] (support :42)
# Items:[ Soup,Coke, ] (support :15)
# Items:[ Soup,Focaccia, ] (support :2)
# Items:[ Soup,Sandwich, ] (support :52)
# Items:[ Soup,Alfajores, ] (support :6)
# Items:[ Soup,Brownie, ] (support :14)
# Items:[ Soup,Art Tray, ] (support :6)
# Items:[ Soup,Truffles, ] (support :16)
# Items:[ Soup,Tiffin, ] (support :2)
# Items:[ Soup,Bakewell, ] (support :2)
# Items:[ Soup,Toast, ] (support :3)
# Items:[ Soup,Scone, ] (support :11)
# Items:[ Soup,Salad, ] (support :12)
# Items:[ Soup,Chicken Stew, ] (support :15)
# Items:[ Soup,Spanish Brunch, ] (support :10)
# Items:[ Soup,Extra Salami or Feta, ] (support :2)
# Items:[ Pick and Mix Bowls,Sandwich, ] (support :2)
# Items:[ Pick and Mix Bowls,Brownie, ] (support :2)
# Items:[ Smoothies,Cake, ] (support :15)
# Items:[ Smoothies,Coke, ] (support :2)
# Items:[ Smoothies,Sandwich, ] (support :17)
# Items:[ Smoothies,Alfajores, ] (support :3)
# Items:[ Smoothies,Brownie, ] (support :4)
# Items:[ Smoothies,Jammie Dodgers, ] (support :4)
# Items:[ Smoothies,Tiffin, ] (support :2)
# Items:[ Smoothies,The Nomad, ] (support :2)
# Items:[ Smoothies,Toast, ] (support :4)
# Items:[ Smoothies,Scone, ] (support :2)
# Items:[ Smoothies,Salad, ] (support :2)
# Items:[ Smoothies,Chicken Stew, ] (support :2)
# Items:[ Smoothies,Spanish Brunch, ] (support :9)
# Items:[ Cake,Coke, ] (support :17)
# Items:[ Cake,My-5 Fruit Shoot, ] (support :3)
# Items:[ Cake,Focaccia, ] (support :2)
# Items:[ Cake,Sandwich, ] (support :65)
# Items:[ Cake,Alfajores, ] (support :39)
# Items:[ Cake,Eggs, ] (support :3)
# Items:[ Cake,Brownie, ] (support :42)
# Items:[ Cake,Dulce de Leche, ] (support :2)
# Items:[ Cake,Granola, ] (support :3)
# Items:[ Cake,Art Tray, ] (support :2)
# Items:[ Cake,Truffles, ] (support :25)
# Items:[ Cake,Jammie Dodgers, ] (support :29)
# Items:[ Cake,Tiffin, ] (support :22)
# Items:[ Cake,The Nomad, ] (support :7)
# Items:[ Cake,Bakewell, ] (support :8)
# Items:[ Cake,Lemon and coconut, ] (support :2)
# Items:[ Cake,Toast, ] (support :21)
# Items:[ Cake,Scone, ] (support :45)
# Items:[ Cake,Vegan mincepie, ] (support :12)
# Items:[ Cake,Salad, ] (support :13)
# Items:[ Cake,Chicken Stew, ] (support :16)
# Items:[ Cake,Spanish Brunch, ] (support :22)
# Items:[ Cake,Extra Salami or Feta, ] (support :7)
# Items:[ Cake,Duck egg, ] (support :2)
# Items:[ Cake,Baguette, ] (support :9)
# Items:[ Cake,Vegan Feast, ] (support :2)
# Items:[ Cake,Tacos/Fajita, ] (support :3)
# Items:[ Coke,Sandwich, ] (support :49)
# Items:[ Coke,Alfajores, ] (support :6)
# Items:[ Coke,Brownie, ] (support :11)
# Items:[ Coke,Truffles, ] (support :12)
# Items:[ Coke,Tiffin, ] (support :4)
# Items:[ Coke,Toast, ] (support :5)
# Items:[ Coke,Scone, ] (support :5)
# Items:[ Coke,Crisps, ] (support :2)
# Items:[ Coke,Salad, ] (support :7)
# Items:[ Coke,Chicken Stew, ] (support :10)
# Items:[ Coke,Spanish Brunch, ] (support :6)
# Items:[ Coke,Chocolates, ] (support :3)
# Items:[ Coke,Tacos/Fajita, ] (support :2)
# Items:[ My-5 Fruit Shoot,Alfajores, ] (support :2)
# Items:[ My-5 Fruit Shoot,Brownie, ] (support :4)
# Items:[ My-5 Fruit Shoot,Art Tray, ] (support :2)
# Items:[ Focaccia,Sandwich, ] (support :2)
# Items:[ Focaccia,Alfajores, ] (support :3)
# Items:[ Focaccia,Brownie, ] (support :2)
# Items:[ Focaccia,Scone, ] (support :2)
# Items:[ Sandwich,Alfajores, ] (support :25)
# Items:[ Sandwich,Brownie, ] (support :22)
# Items:[ Sandwich,Granola, ] (support :3)
# Items:[ Sandwich,Art Tray, ] (support :8)
# Items:[ Sandwich,Truffles, ] (support :36)
# Items:[ Sandwich,Jammie Dodgers, ] (support :7)
# Items:[ Sandwich,Tiffin, ] (support :9)
# Items:[ Sandwich,The Nomad, ] (support :3)
# Items:[ Sandwich,Bakewell, ] (support :4)
# Items:[ Sandwich,Lemon and coconut, ] (support :2)
# Items:[ Sandwich,Toast, ] (support :18)
# Items:[ Sandwich,Scone, ] (support :17)
# Items:[ Sandwich,Vegan mincepie, ] (support :2)
# Items:[ Sandwich,Crisps, ] (support :6)
# Items:[ Sandwich,Salad, ] (support :18)
# Items:[ Sandwich,Chicken Stew, ] (support :19)
# Items:[ Sandwich,Spanish Brunch, ] (support :18)
# Items:[ Sandwich,Extra Salami or Feta, ] (support :6)
# Items:[ Sandwich,Baguette, ] (support :3)
# Items:[ Sandwich,Drinking chocolate spoons , ] (support :2)
# Items:[ Alfajores,Brownie, ] (support :27)
# Items:[ Alfajores,Dulce de Leche, ] (support :3)
# Items:[ Alfajores,Art Tray, ] (support :3)
# Items:[ Alfajores,Truffles, ] (support :11)
# Items:[ Alfajores,Jammie Dodgers, ] (support :4)
# Items:[ Alfajores,Tiffin, ] (support :8)
# Items:[ Alfajores,Bakewell, ] (support :2)
# Items:[ Alfajores,Toast, ] (support :5)
# Items:[ Alfajores,Scone, ] (support :13)
# Items:[ Alfajores,Crepes, ] (support :2)
# Items:[ Alfajores,Vegan mincepie, ] (support :2)
# Items:[ Alfajores,Salad, ] (support :3)
# Items:[ Alfajores,Chicken Stew, ] (support :3)
# Items:[ Alfajores,Spanish Brunch, ] (support :10)
# Items:[ Alfajores,Baguette, ] (support :5)
# Items:[ Brownie,Art Tray, ] (support :4)
# Items:[ Brownie,Truffles, ] (support :11)
# Items:[ Brownie,Jammie Dodgers, ] (support :4)
# Items:[ Brownie,Tiffin, ] (support :6)
# Items:[ Brownie,The Nomad, ] (support :2)
# Items:[ Brownie,Bakewell, ] (support :2)
# Items:[ Brownie,Toast, ] (support :7)
# Items:[ Brownie,Scone, ] (support :12)
# Items:[ Brownie,Vegan mincepie, ] (support :2)
# Items:[ Brownie,Afternoon with the baker, ] (support :2)
# Items:[ Brownie,Chicken Stew, ] (support :4)
# Items:[ Brownie,Spanish Brunch, ] (support :5)
# Items:[ Brownie,Extra Salami or Feta, ] (support :3)
# Items:[ Brownie,Baguette, ] (support :6)
# Items:[ Granola,Toast, ] (support :3)
# Items:[ Granola,Chicken Stew, ] (support :2)
# Items:[ Granola,Spanish Brunch, ] (support :2)
# Items:[ Art Tray,Truffles, ] (support :2)
# Items:[ Art Tray,Hack the stack, ] (support :2)
# Items:[ Art Tray,Toast, ] (support :2)
# Items:[ Art Tray,Salad, ] (support :3)
# Items:[ Art Tray,Chicken Stew, ] (support :2)
# Items:[ Art Tray,Spanish Brunch, ] (support :4)
# Items:[ Truffles,Jammie Dodgers, ] (support :4)
# Items:[ Truffles,Tiffin, ] (support :5)
# Items:[ Truffles,The Nomad, ] (support :4)
# Items:[ Truffles,Toast, ] (support :3)
# Items:[ Truffles,Scone, ] (support :8)
# Items:[ Truffles,Crisps, ] (support :3)
# Items:[ Truffles,Salad, ] (support :7)
# Items:[ Truffles,Chicken Stew, ] (support :10)
# Items:[ Truffles,Spanish Brunch, ] (support :17)
# Items:[ Truffles,Extra Salami or Feta, ] (support :2)
# Items:[ Truffles,Duck egg, ] (support :2)
# Items:[ Truffles,Baguette, ] (support :3)
# Items:[ Truffles,Tacos/Fajita, ] (support :2)
# Items:[ Jammie Dodgers,Tiffin, ] (support :11)
# Items:[ Jammie Dodgers,Bakewell, ] (support :2)
# Items:[ Jammie Dodgers,Scone, ] (support :4)
# Items:[ Jammie Dodgers,Vegan mincepie, ] (support :5)
# Items:[ Jammie Dodgers,Chicken Stew, ] (support :2)
# Items:[ Jammie Dodgers,Spanish Brunch, ] (support :2)
# Items:[ Tiffin,The Nomad, ] (support :3)
# Items:[ Tiffin,Toast, ] (support :6)
# Items:[ Tiffin,Scone, ] (support :7)
# Items:[ Tiffin,Vegan mincepie, ] (support :2)
# Items:[ Tiffin,Salad, ] (support :2)
# Items:[ Tiffin,Chicken Stew, ] (support :4)
# Items:[ Tiffin,Spanish Brunch, ] (support :2)
# Items:[ The Nomad,Scone, ] (support :4)
# Items:[ The Nomad,Chicken Stew, ] (support :2)
# Items:[ The Nomad,Spanish Brunch, ] (support :9)
# Items:[ Bakewell,Toast, ] (support :3)
# Items:[ Bakewell,Baguette, ] (support :2)
# Items:[ Toast,Scone, ] (support :7)
# Items:[ Toast,Vegan mincepie, ] (support :2)
# Items:[ Toast,Salad, ] (support :5)
# Items:[ Toast,Chicken Stew, ] (support :5)
# Items:[ Toast,Spanish Brunch, ] (support :10)
# Items:[ Toast,Extra Salami or Feta, ] (support :6)
# Items:[ Toast,Baguette, ] (support :4)
# Items:[ Scone,Salad, ] (support :2)
# Items:[ Scone,Chicken Stew, ] (support :2)
# Items:[ Scone,Spanish Brunch, ] (support :6)
# Items:[ Scone,Baguette, ] (support :4)
# Items:[ Afternoon with the baker,Spanish Brunch, ] (support :2)
# Items:[ Afternoon with the baker,Argentina Night, ] (support :2)
# Items:[ Salad,Chicken Stew, ] (support :4)
# Items:[ Salad,Spanish Brunch, ] (support :12)
# Items:[ Salad,Extra Salami or Feta, ] (support :16)
# Items:[ Salad,Baguette, ] (support :4)
# Items:[ Chicken Stew,Spanish Brunch, ] (support :11)
# Items:[ Chicken Stew,Extra Salami or Feta, ] (support :2)
# Items:[ Spanish Brunch,Extra Salami or Feta, ] (support :8)
# Items:[ Spanish Brunch,Duck egg, ] (support :6)
# Items:[ Spanish Brunch,Baguette, ] (support :3)
# Items:[ Extra Salami or Feta,Duck egg, ] (support :2)
# Items:[ Valentine's card,Tshirt, ] (support :2)
# Items:[ Tshirt,Postcard, ] (support :6)
# 3-itemsets :1274
# Items:[ Bread,Scandinavian,Jam, ] (support :2)
# Items:[ Bread,Scandinavian,Cookies, ] (support :2)
# Items:[ Bread,Scandinavian,Hot chocolate, ] (support :4)
# Items:[ Bread,Scandinavian,Muffin, ] (support :2)
# Items:[ Bread,Scandinavian,Pastry, ] (support :3)
# Items:[ Bread,Scandinavian,Coffee, ] (support :12)
# Items:[ Bread,Scandinavian,Medialuna, ] (support :4)
# Items:[ Bread,Scandinavian,Fudge, ] (support :2)
# Items:[ Bread,Scandinavian,Cake, ] (support :3)
# Items:[ Bread,Scandinavian,Alfajores, ] (support :2)
# Items:[ Bread,Scandinavian,Brownie, ] (support :2)
# Items:[ Bread,Scandinavian,Truffles, ] (support :2)
# Items:[ Bread,Scandinavian,Salad, ] (support :2)
# Items:[ Bread,Scandinavian,Extra Salami or Feta, ] (support :2)
# Items:[ Bread,Jam,Cookies, ] (support :3)
# Items:[ Bread,Jam,Pastry, ] (support :6)
# Items:[ Bread,Jam,Coffee, ] (support :11)
# Items:[ Bread,Jam,Medialuna, ] (support :4)
# Items:[ Bread,Jam,Tea, ] (support :6)
# Items:[ Bread,Jam,Farm House, ] (support :4)
# Items:[ Bread,Jam,Fudge, ] (support :4)
# Items:[ Bread,Jam,Juice, ] (support :3)
# Items:[ Bread,Jam,Sandwich, ] (support :2)
# Items:[ Bread,Jam,Alfajores, ] (support :2)
# Items:[ Bread,Jam,Scone, ] (support :2)
# Items:[ Bread,Jam,Salad, ] (support :2)
# Items:[ Bread,Jam,Christmas common, ] (support :2)
# Items:[ Bread,Cookies,Hot chocolate, ] (support :14)
# Items:[ Bread,Cookies,Muffin, ] (support :6)
# Items:[ Bread,Cookies,Pastry, ] (support :5)
# Items:[ Bread,Cookies,Coffee, ] (support :50)
# Items:[ Bread,Cookies,Medialuna, ] (support :4)
# Items:[ Bread,Cookies,Tea, ] (support :13)
# Items:[ Bread,Cookies,Mineral water, ] (support :2)
# Items:[ Bread,Cookies,Farm House, ] (support :2)
# Items:[ Bread,Cookies,Fudge, ] (support :2)
# Items:[ Bread,Cookies,Juice, ] (support :13)
# Items:[ Bread,Cookies,Hearty & Seasonal, ] (support :2)
# Items:[ Bread,Cookies,Frittata, ] (support :3)
# Items:[ Bread,Cookies,Soup, ] (support :3)
# Items:[ Bread,Cookies,Smoothies, ] (support :2)
# Items:[ Bread,Cookies,Cake, ] (support :15)
# Items:[ Bread,Cookies,Sandwich, ] (support :6)
# Items:[ Bread,Cookies,Alfajores, ] (support :8)
# Items:[ Bread,Cookies,Brownie, ] (support :8)
# Items:[ Bread,Cookies,Truffles, ] (support :4)
# Items:[ Bread,Cookies,Jammie Dodgers, ] (support :2)
# Items:[ Bread,Cookies,Tiffin, ] (support :4)
# Items:[ Bread,Cookies,Toast, ] (support :7)
# Items:[ Bread,Cookies,Scone, ] (support :5)
# Items:[ Bread,Cookies,Salad, ] (support :2)
# Items:[ Bread,Cookies,Chicken Stew, ] (support :2)
# Items:[ Bread,Hot chocolate,Muffin, ] (support :10)
# Items:[ Bread,Hot chocolate,Pastry, ] (support :15)
# Items:[ Bread,Hot chocolate,Coffee, ] (support :58)
# Items:[ Bread,Hot chocolate,Medialuna, ] (support :11)
# Items:[ Bread,Hot chocolate,Tea, ] (support :14)
# Items:[ Bread,Hot chocolate,Fudge, ] (support :2)
# Items:[ Bread,Hot chocolate,Juice, ] (support :3)
# Items:[ Bread,Hot chocolate,Hearty & Seasonal, ] (support :3)
# Items:[ Bread,Hot chocolate,Smoothies, ] (support :3)
# Items:[ Bread,Hot chocolate,Cake, ] (support :17)
# Items:[ Bread,Hot chocolate,Sandwich, ] (support :8)
# Items:[ Bread,Hot chocolate,Alfajores, ] (support :8)
# Items:[ Bread,Hot chocolate,Brownie, ] (support :9)
# Items:[ Bread,Hot chocolate,Jammie Dodgers, ] (support :6)
# Items:[ Bread,Hot chocolate,Tiffin, ] (support :5)
# Items:[ Bread,Hot chocolate,Toast, ] (support :7)
# Items:[ Bread,Hot chocolate,Scone, ] (support :11)
# Items:[ Bread,Hot chocolate,Vegan mincepie, ] (support :3)
# Items:[ Bread,Hot chocolate,Chocolates, ] (support :2)
# Items:[ Bread,Muffin,Pastry, ] (support :7)
# Items:[ Bread,Muffin,Coffee, ] (support :23)
# Items:[ Bread,Muffin,Medialuna, ] (support :5)
# Items:[ Bread,Muffin,Tea, ] (support :9)
# Items:[ Bread,Muffin,Farm House, ] (support :3)
# Items:[ Bread,Muffin,Juice, ] (support :4)
# Items:[ Bread,Muffin,Ella's Kitchen Pouches, ] (support :2)
# Items:[ Bread,Muffin,Hearty & Seasonal, ] (support :3)
# Items:[ Bread,Muffin,Frittata, ] (support :2)
# Items:[ Bread,Muffin,Soup, ] (support :4)
# Items:[ Bread,Muffin,Smoothies, ] (support :2)
# Items:[ Bread,Muffin,Cake, ] (support :9)
# Items:[ Bread,Muffin,My-5 Fruit Shoot, ] (support :2)
# Items:[ Bread,Muffin,Sandwich, ] (support :9)
# Items:[ Bread,Muffin,Alfajores, ] (support :2)
# Items:[ Bread,Muffin,Brownie, ] (support :4)
# Items:[ Bread,Muffin,Truffles, ] (support :2)
# Items:[ Bread,Muffin,Jammie Dodgers, ] (support :3)
# Items:[ Bread,Pastry,Coffee, ] (support :106)
# Items:[ Bread,Pastry,Medialuna, ] (support :23)
# Items:[ Bread,Pastry,Tea, ] (support :23)
# Items:[ Bread,Pastry,Farm House, ] (support :6)
# Items:[ Bread,Pastry,Fudge, ] (support :3)
# Items:[ Bread,Pastry,Juice, ] (support :2)
# Items:[ Bread,Pastry,Soup, ] (support :2)
# Items:[ Bread,Pastry,Cake, ] (support :15)
# Items:[ Bread,Pastry,Sandwich, ] (support :2)
# Items:[ Bread,Pastry,Alfajores, ] (support :7)
# Items:[ Bread,Pastry,Eggs, ] (support :2)
# Items:[ Bread,Pastry,Brownie, ] (support :9)
# Items:[ Bread,Pastry,Granola, ] (support :3)
# Items:[ Bread,Pastry,Truffles, ] (support :7)
# Items:[ Bread,Pastry,Tiffin, ] (support :2)
# Items:[ Bread,Pastry,The Nomad, ] (support :2)
# Items:[ Bread,Pastry,Toast, ] (support :4)
# Items:[ Bread,Pastry,Scone, ] (support :6)
# Items:[ Bread,Pastry,Chicken Stew, ] (support :3)
# Items:[ Bread,Pastry,Spanish Brunch, ] (support :2)
# Items:[ Bread,Coffee,Medialuna, ] (support :64)
# Items:[ Bread,Coffee,Tea, ] (support :70)
# Items:[ Bread,Coffee,Tartine, ] (support :3)
# Items:[ Bread,Coffee,Mineral water, ] (support :13)
# Items:[ Bread,Coffee,Farm House, ] (support :14)
# Items:[ Bread,Coffee,Fudge, ] (support :8)
# Items:[ Bread,Coffee,Juice, ] (support :28)
# Items:[ Bread,Coffee,Hearty & Seasonal, ] (support :12)
# Items:[ Bread,Coffee,Frittata, ] (support :13)
# Items:[ Bread,Coffee,Soup, ] (support :21)
# Items:[ Bread,Coffee,Smoothies, ] (support :12)
# Items:[ Bread,Coffee,Cake, ] (support :95)
# Items:[ Bread,Coffee,Coke, ] (support :7)
# Items:[ Bread,Coffee,Focaccia, ] (support :4)
# Items:[ Bread,Coffee,Sandwich, ] (support :68)
# Items:[ Bread,Coffee,Alfajores, ] (support :41)
# Items:[ Bread,Coffee,Eggs, ] (support :3)
# Items:[ Bread,Coffee,Brownie, ] (support :36)
# Items:[ Bread,Coffee,Dulce de Leche, ] (support :2)
# Items:[ Bread,Coffee,Granola, ] (support :5)
# Items:[ Bread,Coffee,Keeping It Local, ] (support :12)
# Items:[ Bread,Coffee,Art Tray, ] (support :3)
# Items:[ Bread,Coffee,Truffles, ] (support :17)
# Items:[ Bread,Coffee,Jammie Dodgers, ] (support :15)
# Items:[ Bread,Coffee,Tiffin, ] (support :22)
# Items:[ Bread,Coffee,The Nomad, ] (support :4)
# Items:[ Bread,Coffee,Bakewell, ] (support :7)
# Items:[ Bread,Coffee,Lemon and coconut, ] (support :2)
# Items:[ Bread,Coffee,Toast, ] (support :35)
# Items:[ Bread,Coffee,Scone, ] (support :33)
# Items:[ Bread,Coffee,Vegan mincepie, ] (support :5)
# Items:[ Bread,Coffee,Crisps, ] (support :3)
# Items:[ Bread,Coffee,Salad, ] (support :10)
# Items:[ Bread,Coffee,Chicken Stew, ] (support :9)
# Items:[ Bread,Coffee,Spanish Brunch, ] (support :23)
# Items:[ Bread,Coffee,Extra Salami or Feta, ] (support :7)
# Items:[ Bread,Coffee,Baguette, ] (support :4)
# Items:[ Bread,Coffee,Nomad bag, ] (support :3)
# Items:[ Bread,Coffee,Drinking chocolate spoons , ] (support :3)
# Items:[ Bread,Medialuna,Tea, ] (support :20)
# Items:[ Bread,Medialuna,Farm House, ] (support :9)
# Items:[ Bread,Medialuna,Fudge, ] (support :3)
# Items:[ Bread,Medialuna,Juice, ] (support :2)
# Items:[ Bread,Medialuna,Frittata, ] (support :2)
# Items:[ Bread,Medialuna,Cake, ] (support :6)
# Items:[ Bread,Medialuna,Focaccia, ] (support :3)
# Items:[ Bread,Medialuna,Sandwich, ] (support :7)
# Items:[ Bread,Medialuna,Alfajores, ] (support :11)
# Items:[ Bread,Medialuna,Eggs, ] (support :2)
# Items:[ Bread,Medialuna,Brownie, ] (support :3)
# Items:[ Bread,Medialuna,Truffles, ] (support :2)
# Items:[ Bread,Medialuna,Tiffin, ] (support :2)
# Items:[ Bread,Medialuna,Toast, ] (support :8)
# Items:[ Bread,Medialuna,Spanish Brunch, ] (support :2)
# Items:[ Bread,Tea,Mineral water, ] (support :3)
# Items:[ Bread,Tea,Fudge, ] (support :5)
# Items:[ Bread,Tea,Juice, ] (support :9)
# Items:[ Bread,Tea,Hearty & Seasonal, ] (support :3)
# Items:[ Bread,Tea,Frittata, ] (support :6)
# Items:[ Bread,Tea,Soup, ] (support :15)
# Items:[ Bread,Tea,Cake, ] (support :46)
# Items:[ Bread,Tea,Coke, ] (support :4)
# Items:[ Bread,Tea,Focaccia, ] (support :2)
# Items:[ Bread,Tea,Sandwich, ] (support :26)
# Items:[ Bread,Tea,Alfajores, ] (support :16)
# Items:[ Bread,Tea,Brownie, ] (support :16)
# Items:[ Bread,Tea,Granola, ] (support :3)
# Items:[ Bread,Tea,Keeping It Local, ] (support :5)
# Items:[ Bread,Tea,Truffles, ] (support :5)
# Items:[ Bread,Tea,Jammie Dodgers, ] (support :10)
# Items:[ Bread,Tea,Tiffin, ] (support :12)
# Items:[ Bread,Tea,The Nomad, ] (support :4)
# Items:[ Bread,Tea,Bakewell, ] (support :3)
# Items:[ Bread,Tea,Toast, ] (support :10)
# Items:[ Bread,Tea,Scone, ] (support :14)
# Items:[ Bread,Tea,Salad, ] (support :4)
# Items:[ Bread,Tea,Chicken Stew, ] (support :9)
# Items:[ Bread,Tea,Spanish Brunch, ] (support :8)
# Items:[ Bread,Tea,Extra Salami or Feta, ] (support :3)
# Items:[ Bread,Tea,Duck egg, ] (support :2)
# Items:[ Bread,Mineral water,Hearty & Seasonal, ] (support :3)
# Items:[ Bread,Mineral water,Frittata, ] (support :2)
# Items:[ Bread,Mineral water,Soup, ] (support :2)
# Items:[ Bread,Mineral water,Cake, ] (support :2)
# Items:[ Bread,Mineral water,Coke, ] (support :3)
# Items:[ Bread,Mineral water,Sandwich, ] (support :6)
# Items:[ Bread,Mineral water,Alfajores, ] (support :2)
# Items:[ Bread,Mineral water,Brownie, ] (support :3)
# Items:[ Bread,Mineral water,Truffles, ] (support :3)
# Items:[ Bread,Mineral water,Scone, ] (support :4)
# Items:[ Bread,Mineral water,Salad, ] (support :2)
# Items:[ Bread,Mineral water,Spanish Brunch, ] (support :3)
# Items:[ Bread,Farm House,Coke, ] (support :2)
# Items:[ Bread,Farm House,Sandwich, ] (support :3)
# Items:[ Bread,Farm House,Truffles, ] (support :2)
# Items:[ Bread,Fudge,Cake, ] (support :2)
# Items:[ Bread,Fudge,Sandwich, ] (support :5)
# Items:[ Bread,Fudge,Alfajores, ] (support :4)
# Items:[ Bread,Juice,Frittata, ] (support :2)
# Items:[ Bread,Juice,Cake, ] (support :17)
# Items:[ Bread,Juice,Sandwich, ] (support :11)
# Items:[ Bread,Juice,Alfajores, ] (support :5)
# Items:[ Bread,Juice,Eggs, ] (support :2)
# Items:[ Bread,Juice,Brownie, ] (support :5)
# Items:[ Bread,Juice,Truffles, ] (support :5)
# Items:[ Bread,Juice,Jammie Dodgers, ] (support :6)
# Items:[ Bread,Juice,Toast, ] (support :5)
# Items:[ Bread,Juice,Scone, ] (support :6)
# Items:[ Bread,Juice,Crisps, ] (support :3)
# Items:[ Bread,Juice,Afternoon with the baker, ] (support :2)
# Items:[ Bread,Juice,Salad, ] (support :2)
# Items:[ Bread,Juice,Spanish Brunch, ] (support :4)
# Items:[ Bread,Hearty & Seasonal,Soup, ] (support :2)
# Items:[ Bread,Hearty & Seasonal,Cake, ] (support :2)
# Items:[ Bread,Hearty & Seasonal,Sandwich, ] (support :4)
# Items:[ Bread,Hearty & Seasonal,Brownie, ] (support :2)
# Items:[ Bread,Hearty & Seasonal,Scone, ] (support :2)
# Items:[ Bread,Frittata,Sandwich, ] (support :3)
# Items:[ Bread,Frittata,Scone, ] (support :3)
# Items:[ Bread,Frittata,Salad, ] (support :2)
# Items:[ Bread,Soup,Cake, ] (support :10)
# Items:[ Bread,Soup,Coke, ] (support :4)
# Items:[ Bread,Soup,Sandwich, ] (support :10)
# Items:[ Bread,Soup,Alfajores, ] (support :2)
# Items:[ Bread,Soup,Truffles, ] (support :4)
# Items:[ Bread,Soup,Tiffin, ] (support :2)
# Items:[ Bread,Soup,Scone, ] (support :3)
# Items:[ Bread,Soup,Salad, ] (support :3)
# Items:[ Bread,Soup,Chicken Stew, ] (support :7)
# Items:[ Bread,Soup,Spanish Brunch, ] (support :2)
# Items:[ Bread,Smoothies,Cake, ] (support :7)
# Items:[ Bread,Smoothies,Sandwich, ] (support :6)
# Items:[ Bread,Smoothies,Alfajores, ] (support :2)
# Items:[ Bread,Smoothies,Brownie, ] (support :2)
# Items:[ Bread,Smoothies,Spanish Brunch, ] (support :2)
# Items:[ Bread,Cake,Coke, ] (support :3)
# Items:[ Bread,Cake,Sandwich, ] (support :16)
# Items:[ Bread,Cake,Alfajores, ] (support :9)
# Items:[ Bread,Cake,Eggs, ] (support :3)
# Items:[ Bread,Cake,Brownie, ] (support :8)
# Items:[ Bread,Cake,Truffles, ] (support :6)
# Items:[ Bread,Cake,Jammie Dodgers, ] (support :15)
# Items:[ Bread,Cake,Tiffin, ] (support :6)
# Items:[ Bread,Cake,Bakewell, ] (support :2)
# Items:[ Bread,Cake,Lemon and coconut, ] (support :2)
# Items:[ Bread,Cake,Toast, ] (support :5)
# Items:[ Bread,Cake,Scone, ] (support :7)
# Items:[ Bread,Cake,Vegan mincepie, ] (support :2)
# Items:[ Bread,Cake,Salad, ] (support :2)
# Items:[ Bread,Cake,Chicken Stew, ] (support :5)
# Items:[ Bread,Cake,Spanish Brunch, ] (support :6)
# Items:[ Bread,Cake,Extra Salami or Feta, ] (support :3)
# Items:[ Bread,Cake,Baguette, ] (support :2)
# Items:[ Bread,Coke,Sandwich, ] (support :8)
# Items:[ Bread,Coke,Brownie, ] (support :2)
# Items:[ Bread,Coke,Truffles, ] (support :2)
# Items:[ Bread,Coke,Chicken Stew, ] (support :2)
# Items:[ Bread,Sandwich,Alfajores, ] (support :9)
# Items:[ Bread,Sandwich,Brownie, ] (support :5)
# Items:[ Bread,Sandwich,Truffles, ] (support :5)
# Items:[ Bread,Sandwich,Jammie Dodgers, ] (support :4)
# Items:[ Bread,Sandwich,Tiffin, ] (support :4)
# Items:[ Bread,Sandwich,The Nomad, ] (support :3)
# Items:[ Bread,Sandwich,Toast, ] (support :3)
# Items:[ Bread,Sandwich,Scone, ] (support :4)
# Items:[ Bread,Sandwich,Salad, ] (support :5)
# Items:[ Bread,Sandwich,Chicken Stew, ] (support :5)
# Items:[ Bread,Sandwich,Spanish Brunch, ] (support :5)
# Items:[ Bread,Sandwich,Extra Salami or Feta, ] (support :3)
# Items:[ Bread,Alfajores,Brownie, ] (support :10)
# Items:[ Bread,Alfajores,Jammie Dodgers, ] (support :2)
# Items:[ Bread,Alfajores,Tiffin, ] (support :2)
# Items:[ Bread,Alfajores,Bakewell, ] (support :2)
# Items:[ Bread,Alfajores,Toast, ] (support :2)
# Items:[ Bread,Alfajores,Scone, ] (support :3)
# Items:[ Bread,Brownie,Truffles, ] (support :2)
# Items:[ Bread,Brownie,Jammie Dodgers, ] (support :3)
# Items:[ Bread,Brownie,Tiffin, ] (support :2)
# Items:[ Bread,Brownie,Bakewell, ] (support :2)
# Items:[ Bread,Brownie,Toast, ] (support :3)
# Items:[ Bread,Brownie,Scone, ] (support :4)
# Items:[ Bread,Brownie,Chicken Stew, ] (support :2)
# Items:[ Bread,Brownie,Spanish Brunch, ] (support :2)
# Items:[ Bread,Truffles,Jammie Dodgers, ] (support :3)
# Items:[ Bread,Truffles,Tiffin, ] (support :2)
# Items:[ Bread,Truffles,Scone, ] (support :4)
# Items:[ Bread,Truffles,Crisps, ] (support :2)
# Items:[ Bread,Truffles,Salad, ] (support :2)
# Items:[ Bread,Truffles,Chicken Stew, ] (support :2)
# Items:[ Bread,Truffles,Spanish Brunch, ] (support :2)
# Items:[ Bread,Truffles,Tacos/Fajita, ] (support :2)
# Items:[ Bread,Jammie Dodgers,Tiffin, ] (support :4)
# Items:[ Bread,Jammie Dodgers,Spanish Brunch, ] (support :2)
# Items:[ Bread,Tiffin,The Nomad, ] (support :2)
# Items:[ Bread,Tiffin,Toast, ] (support :2)
# Items:[ Bread,Tiffin,Scone, ] (support :2)
# Items:[ Bread,Tiffin,Chicken Stew, ] (support :3)
# Items:[ Bread,The Nomad,Scone, ] (support :2)
# Items:[ Bread,Bakewell,Toast, ] (support :2)
# Items:[ Bread,Toast,Spanish Brunch, ] (support :3)
# Items:[ Bread,Scone,Spanish Brunch, ] (support :3)
# Items:[ Bread,Scone,Baguette, ] (support :2)
# Items:[ Bread,Salad,Spanish Brunch, ] (support :3)
# Items:[ Bread,Salad,Extra Salami or Feta, ] (support :6)
# Items:[ Scandinavian,Cookies,Hot chocolate, ] (support :2)
# Items:[ Scandinavian,Cookies,Coffee, ] (support :3)
# Items:[ Scandinavian,Hot chocolate,Coffee, ] (support :4)
# Items:[ Scandinavian,Muffin,Pastry, ] (support :2)
# Items:[ Scandinavian,Muffin,Coffee, ] (support :3)
# Items:[ Scandinavian,Pastry,Coffee, ] (support :5)
# Items:[ Scandinavian,Pastry,Farm House, ] (support :2)
# Items:[ Scandinavian,Coffee,Medialuna, ] (support :6)
# Items:[ Scandinavian,Coffee,Tea, ] (support :6)
# Items:[ Scandinavian,Coffee,Farm House, ] (support :4)
# Items:[ Scandinavian,Coffee,Fudge, ] (support :2)
# Items:[ Scandinavian,Coffee,Frittata, ] (support :2)
# Items:[ Scandinavian,Coffee,Soup, ] (support :3)
# Items:[ Scandinavian,Coffee,Cake, ] (support :6)
# Items:[ Scandinavian,Coffee,Sandwich, ] (support :3)
# Items:[ Scandinavian,Coffee,Alfajores, ] (support :4)
# Items:[ Scandinavian,Coffee,Brownie, ] (support :2)
# Items:[ Scandinavian,Coffee,Truffles, ] (support :2)
# Items:[ Scandinavian,Coffee,Toast, ] (support :4)
# Items:[ Scandinavian,Coffee,Salad, ] (support :2)
# Items:[ Scandinavian,Medialuna,Alfajores, ] (support :2)
# Items:[ Scandinavian,Tea,Cake, ] (support :2)
# Items:[ Scandinavian,Farm House,Cake, ] (support :2)
# Items:[ Scandinavian,Farm House,Alfajores, ] (support :2)
# Items:[ Scandinavian,Farm House,Toast, ] (support :2)
# Items:[ Scandinavian,Cake,Scone, ] (support :2)
# Items:[ Scandinavian,Cake,Baguette, ] (support :2)
# Items:[ Scandinavian,Salad,Extra Salami or Feta, ] (support :2)
# Items:[ Jam,Cookies,Tea, ] (support :2)
# Items:[ Jam,Hot chocolate,Coffee, ] (support :2)
# Items:[ Jam,Pastry,Coffee, ] (support :6)
# Items:[ Jam,Pastry,Tea, ] (support :2)
# Items:[ Jam,Coffee,Medialuna, ] (support :3)
# Items:[ Jam,Coffee,Tea, ] (support :4)
# Items:[ Jam,Coffee,Tartine, ] (support :3)
# Items:[ Jam,Coffee,Farm House, ] (support :2)
# Items:[ Jam,Coffee,Fudge, ] (support :6)
# Items:[ Jam,Coffee,Soup, ] (support :3)
# Items:[ Jam,Coffee,Cake, ] (support :3)
# Items:[ Jam,Coffee,Brownie, ] (support :2)
# Items:[ Jam,Coffee,Keeping It Local, ] (support :2)
# Items:[ Jam,Medialuna,Tea, ] (support :2)
# Items:[ Jam,Medialuna,Alfajores, ] (support :2)
# Items:[ Jam,Tea,Fudge, ] (support :3)
# Items:[ Jam,Tea,Juice, ] (support :2)
# ...
# Rule:{'Bread', 'Alfajores', 'Jam'}-->{'Tea', 'Medialuna'}  confidence:1.0
# Rule:{'Jam', 'Tea', 'Medialuna'}-->{'Bread', 'Alfajores'}  confidence:1.0
# Rule:{'Bread', 'Alfajores', 'Tea', 'Medialuna'}-->{'Jam'}  confidence:0.6666666666666666
# Rule:{'Alfajores', 'Jam', 'Tea', 'Medialuna'}-->{'Bread'}  confidence:1.0
# Rule:{'Bread', 'Alfajores', 'Jam', 'Tea'}-->{'Medialuna'}  confidence:1.0
# Rule:{'Bread', 'Alfajores', 'Jam', 'Medialuna'}-->{'Tea'}  confidence:1.0
# Rule:{'Bread', 'Jam', 'Tea', 'Medialuna'}-->{'Alfajores'}  confidence:1.0
# Rule:{'Bread', 'Scone', 'Cookies', 'Hot chocolate'}-->{'Coffee'}  confidence:1.0
# Rule:{'Bread', 'Truffles', 'Salad'}-->{'Soup', 'Cookies'}  confidence:1.0
# Rule:{'Truffles', 'Salad', 'Cookies'}-->{'Bread', 'Soup'}  confidence:1.0
# Rule:{'Truffles', 'Salad', 'Soup'}-->{'Bread', 'Cookies'}  confidence:1.0
# Rule:{'Bread', 'Salad', 'Soup'}-->{'Truffles', 'Cookies'}  confidence:0.6666666666666666
# Rule:{'Salad', 'Soup', 'Cookies'}-->{'Bread', 'Truffles'}  confidence:1.0
# Rule:{'Bread', 'Salad', 'Cookies'}-->{'Truffles', 'Soup'}  confidence:1.0
# Rule:{'Truffles', 'Soup', 'Cookies'}-->{'Bread', 'Salad'}  confidence:0.6666666666666666
# Rule:{'Bread', 'Soup', 'Cookies'}-->{'Truffles', 'Salad'}  confidence:0.6666666666666666
# Rule:{'Bread', 'Truffles', 'Salad', 'Soup'}-->{'Cookies'}  confidence:1.0
# Rule:{'Truffles', 'Salad', 'Soup', 'Cookies'}-->{'Bread'}  confidence:1.0
# Rule:{'Bread', 'Truffles', 'Salad', 'Cookies'}-->{'Soup'}  confidence:1.0
# Rule:{'Bread', 'Salad', 'Soup', 'Cookies'}-->{'Truffles'}  confidence:1.0
# Rule:{'Bread', 'Truffles', 'Soup', 'Cookies'}-->{'Salad'}  confidence:1.0
# Rule:{'Bread', 'Alfajores', 'Tea', 'Hot chocolate'}-->{'Coffee'}  confidence:0.6666666666666666
# Rule:{'Bread', 'Alfajores', 'Coffee', 'Hot chocolate'}-->{'Tea'}  confidence:0.6666666666666666
# Rule:{'Bread', 'Cake', 'Sandwich', 'Hot chocolate'}-->{'Coffee'}  confidence:1.0
# Rule:{'Bread', 'Sandwich', 'Coffee', 'Hot chocolate'}-->{'Cake'}  confidence:0.6666666666666666
# Rule:{'Bread', 'Cake', 'Scone', 'Coffee'}-->{'Hot chocolate'}  confidence:1.0
# Rule:{'Bread', 'Cake', 'Scone', 'Hot chocolate'}-->{'Coffee'}  confidence:1.0
# Rule:{'Alfajores', 'Brownie', 'Tea', 'Hot chocolate'}-->{'Bread'}  confidence:0.6666666666666666
# Rule:{'Bread', 'Alfajores', 'Brownie', 'Hot chocolate'}-->{'Tea'}  confidence:1.0
# Rule:{'Bread', 'Brownie', 'Tea', 'Hot chocolate'}-->{'Alfajores'}  confidence:1.0
# Rule:{'Bread', 'Alfajores', 'Tea', 'Hot chocolate'}-->{'Brownie'}  confidence:0.6666666666666666
# Rule:{'Cake', 'Medialuna', 'Muffin'}-->{'Bread', 'Coffee'}  confidence:1.0
# Rule:{'Cake', 'Coffee', 'Medialuna', 'Muffin'}-->{'Bread'}  confidence:1.0
# Rule:{'Bread', 'Cake', 'Medialuna', 'Muffin'}-->{'Coffee'}  confidence:1.0
# Rule:{'Sandwich', 'Medialuna', 'Muffin'}-->{'Bread', 'Coffee'}  confidence:0.6666666666666666
# Rule:{'Sandwich', 'Coffee', 'Medialuna', 'Muffin'}-->{'Bread'}  confidence:1.0
# Rule:{'Bread', 'Sandwich', 'Medialuna', 'Muffin'}-->{'Coffee'}  confidence:1.0
# Rule:{'Bread', 'Farm House', 'Medialuna', 'Pastry'}-->{'Coffee'}  confidence:0.6666666666666666
# Rule:{'Bread', 'Coffee', 'Farm House', 'Pastry'}-->{'Medialuna'}  confidence:0.6666666666666666
# Rule:{'Bread', 'Cake', 'Tea', 'Pastry'}-->{'Coffee'}  confidence:0.6
# Rule:{'Bread', 'Sandwich', 'Tea', 'Medialuna'}-->{'Coffee'}  confidence:1.0
# Rule:{'Sandwich', 'Tea', 'Coffee', 'Medialuna'}-->{'Bread'}  confidence:0.6
# Rule:{'Tiffin', 'Sandwich', 'Medialuna'}-->{'Bread', 'Coffee'}  confidence:1.0
# Rule:{'Bread', 'Medialuna', 'Tiffin'}-->{'Sandwich', 'Coffee'}  confidence:1.0
# Rule:{'Bread', 'Sandwich', 'Medialuna', 'Tiffin'}-->{'Coffee'}  confidence:1.0
# Rule:{'Tiffin', 'Sandwich', 'Coffee', 'Medialuna'}-->{'Bread'}  confidence:1.0
# Rule:{'Bread', 'Sandwich', 'Coffee', 'Tiffin'}-->{'Medialuna'}  confidence:0.6666666666666666
# Rule:{'Bread', 'Coffee', 'Medialuna', 'Tiffin'}-->{'Sandwich'}  confidence:1.0
# Rule:{'Tiffin', 'Cake', 'Tea'}-->{'Bread', 'Coffee'}  confidence:1.0
# Rule:{'Bread', 'Cake', 'Tea', 'Tiffin'}-->{'Coffee'}  confidence:1.0
# Rule:{'Tiffin', 'Cake', 'Tea', 'Coffee'}-->{'Bread'}  confidence:1.0
# Rule:{'Alfajores', 'Tea', 'Coffee', 'Brownie'}-->{'Bread'}  confidence:1.0
# Rule:{'Tiffin', 'Tea', 'Jammie Dodgers'}-->{'Bread', 'Coffee'}  confidence:0.6666666666666666
# Rule:{'Bread', 'Tea', 'Jammie Dodgers', 'Tiffin'}-->{'Coffee'}  confidence:0.6666666666666666
# Rule:{'Tiffin', 'Tea', 'Coffee', 'Jammie Dodgers'}-->{'Bread'}  confidence:1.0
# Rule:{'Bread', 'Coffee', 'Jammie Dodgers', 'Tiffin'}-->{'Tea'}  confidence:0.6666666666666666
# Rule:{'Bread', 'Chicken Stew', 'Tiffin'}-->{'Tea', 'Coffee'}  confidence:0.6666666666666666
# Rule:{'Tiffin', 'Coffee', 'Chicken Stew'}-->{'Bread', 'Tea'}  confidence:1.0
# Rule:{'Tiffin', 'Tea', 'Chicken Stew'}-->{'Bread', 'Coffee'}  confidence:1.0
# Rule:{'Bread', 'Chicken Stew', 'Tea', 'Tiffin'}-->{'Coffee'}  confidence:1.0
# Rule:{'Tiffin', 'Tea', 'Coffee', 'Chicken Stew'}-->{'Bread'}  confidence:1.0
# Rule:{'Bread', 'Chicken Stew', 'Coffee', 'Tiffin'}-->{'Tea'}  confidence:1.0
# Rule:{'Bread', 'Tea', 'Coffee', 'Chicken Stew'}-->{'Tiffin'}  confidence:0.6666666666666666
# Rule:{'Truffles', 'Crisps'}-->{'Bread', 'Coffee', 'Juice'}  confidence:0.6666666666666666
# Rule:{'Bread', 'Truffles', 'Crisps'}-->{'Coffee', 'Juice'}  confidence:1.0
# Rule:{'Truffles', 'Crisps', 'Coffee'}-->{'Bread', 'Juice'}  confidence:1.0
# Rule:{'Truffles', 'Crisps', 'Juice'}-->{'Bread', 'Coffee'}  confidence:1.0
# Rule:{'Bread', 'Crisps', 'Juice'}-->{'Truffles', 'Coffee'}  confidence:0.6666666666666666
# Rule:{'Bread', 'Crisps', 'Coffee'}-->{'Truffles', 'Juice'}  confidence:0.6666666666666666
# Rule:{'Bread', 'Truffles', 'Crisps', 'Juice'}-->{'Coffee'}  confidence:1.0
# Rule:{'Truffles', 'Crisps', 'Coffee', 'Juice'}-->{'Bread'}  confidence:1.0
# Rule:{'Bread', 'Truffles', 'Crisps', 'Coffee'}-->{'Juice'}  confidence:1.0
# Rule:{'Bread', 'Crisps', 'Coffee', 'Juice'}-->{'Truffles'}  confidence:1.0
# Rule:{'Bread', 'Truffles', 'Coffee', 'Juice'}-->{'Crisps'}  confidence:0.6666666666666666
# Rule:{'Extra Salami or Feta', 'Salad', 'Cake'}-->{'Bread', 'Coffee'}  confidence:0.6666666666666666
# Rule:{'Bread', 'Extra Salami or Feta', 'Cake'}-->{'Salad', 'Coffee'}  confidence:0.6666666666666666
# Rule:{'Bread', 'Salad', 'Cake'}-->{'Extra Salami or Feta', 'Coffee'}  confidence:1.0
# Rule:{'Bread', 'Extra Salami or Feta', 'Salad', 'Cake'}-->{'Coffee'}  confidence:1.0
# Rule:{'Extra Salami or Feta', 'Salad', 'Cake', 'Coffee'}-->{'Bread'}  confidence:0.6666666666666666
# Rule:{'Bread', 'Extra Salami or Feta', 'Cake', 'Coffee'}-->{'Salad'}  confidence:1.0
# Rule:{'Bread', 'Salad', 'Cake', 'Coffee'}-->{'Extra Salami or Feta'}  confidence:1.0
# Rule:{'Bread', 'Brownie', 'Toast'}-->{'Cake', 'Tea'}  confidence:0.6666666666666666
# Rule:{'Brownie', 'Cake', 'Toast'}-->{'Bread', 'Tea'}  confidence:1.0
# Rule:{'Bread', 'Brownie', 'Cake', 'Toast'}-->{'Tea'}  confidence:1.0
# Rule:{'Brownie', 'Cake', 'Tea', 'Toast'}-->{'Bread'}  confidence:1.0
# Rule:{'Bread', 'Brownie', 'Tea', 'Toast'}-->{'Cake'}  confidence:0.6666666666666666
# Rule:{'Bread', 'Brownie', 'Cake', 'Tea'}-->{'Toast'}  confidence:0.6666666666666666
# Rule:{'Alfajores', 'Sandwich', 'Hot chocolate'}-->{'Coffee', 'Cookies'}  confidence:0.6666666666666666
# Rule:{'Alfajores', 'Sandwich', 'Coffee', 'Cookies'}-->{'Hot chocolate'}  confidence:0.6666666666666666
# Rule:{'Alfajores', 'Sandwich', 'Coffee', 'Hot chocolate'}-->{'Cookies'}  confidence:0.6666666666666666
# Rule:{'Alfajores', 'Sandwich', 'Cookies', 'Hot chocolate'}-->{'Coffee'}  confidence:1.0
# Rule:{'Mineral water', 'Alfajores', 'Tea'}-->{'Coffee', 'Cookies'}  confidence:0.6666666666666666
# Rule:{'Mineral water', 'Tea', 'Cookies'}-->{'Alfajores', 'Coffee'}  confidence:1.0
# Rule:{'Mineral water', 'Alfajores', 'Tea', 'Cookies'}-->{'Coffee'}  confidence:1.0
# Rule:{'Mineral water', 'Alfajores', 'Tea', 'Coffee'}-->{'Cookies'}  confidence:0.6666666666666666
# Rule:{'Mineral water', 'Alfajores', 'Coffee', 'Cookies'}-->{'Tea'}  confidence:0.6666666666666666
# Rule:{'Mineral water', 'Tea', 'Coffee', 'Cookies'}-->{'Alfajores'}  confidence:1.0
# Rule:{'Sandwich', 'Tea', 'Cookies', 'Juice'}-->{'Coffee'}  confidence:0.6666666666666666
# Rule:{'Sandwich', 'Tea', 'Coffee', 'Juice'}-->{'Cookies'}  confidence:0.6666666666666666
# Rule:{'Alfajores', 'Tea', 'Cookies'}-->{'Coffee', 'Juice'}  confidence:0.6
# Rule:{'Alfajores', 'Tea', 'Cookies', 'Juice'}-->{'Coffee'}  confidence:0.75
# Rule:{'Alfajores', 'Tea', 'Coffee', 'Juice'}-->{'Cookies'}  confidence:1.0
# Rule:{'Alfajores', 'Tea', 'Coffee', 'Cookies'}-->{'Juice'}  confidence:0.75
# Rule:{'Tea', 'Coffee', 'Cookies', 'Juice'}-->{'Alfajores'}  confidence:0.75
# Rule:{'Cake', 'Soup', 'Cookies'}-->{'Tea', 'Coffee'}  confidence:1.0
# Rule:{'Soup', 'Cake', 'Tea', 'Cookies'}-->{'Coffee'}  confidence:1.0
# Rule:{'Cake', 'Soup', 'Coffee', 'Cookies'}-->{'Tea'}  confidence:1.0
# Rule:{'Soup', 'Tea', 'Coffee', 'Cookies'}-->{'Cake'}  confidence:1.0
# Rule:{'Sandwich', 'Soup', 'Cookies'}-->{'Tea', 'Coffee'}  confidence:1.0
# Rule:{'Soup', 'Sandwich', 'Tea', 'Cookies'}-->{'Coffee'}  confidence:1.0
# Rule:{'Sandwich', 'Soup', 'Coffee', 'Cookies'}-->{'Tea'}  confidence:1.0
# Rule:{'Soup', 'Tea', 'Coffee', 'Cookies'}-->{'Sandwich'}  confidence:1.0
# Rule:{'Cake', 'Sandwich', 'Cookies'}-->{'Tea', 'Coffee'}  confidence:1.0
# Rule:{'Sandwich', 'Cake', 'Tea', 'Cookies'}-->{'Coffee'}  confidence:1.0
# Rule:{'Cake', 'Sandwich', 'Coffee', 'Cookies'}-->{'Tea'}  confidence:1.0
# Rule:{'Cake', 'Sandwich', 'Cookies'}-->{'Soup', 'Coffee'}  confidence:0.6666666666666666
# Rule:{'Sandwich', 'Soup', 'Cookies'}-->{'Cake', 'Coffee'}  confidence:1.0
# Rule:{'Cake', 'Soup', 'Cookies'}-->{'Sandwich', 'Coffee'}  confidence:1.0
# Rule:{'Sandwich', 'Cake', 'Soup', 'Cookies'}-->{'Coffee'}  confidence:1.0
# Rule:{'Cake', 'Sandwich', 'Coffee', 'Cookies'}-->{'Soup'}  confidence:0.6666666666666666
# Rule:{'Sandwich', 'Soup', 'Coffee', 'Cookies'}-->{'Cake'}  confidence:1.0
# Rule:{'Cake', 'Soup', 'Coffee', 'Cookies'}-->{'Sandwich'}  confidence:1.0
# Rule:{'Cake', 'Sandwich', 'Cookies'}-->{'Soup', 'Tea'}  confidence:0.6666666666666666
# Rule:{'Sandwich', 'Soup', 'Cookies'}-->{'Cake', 'Tea'}  confidence:1.0
# Rule:{'Cake', 'Soup', 'Cookies'}-->{'Sandwich', 'Tea'}  confidence:1.0
# Rule:{'Sandwich', 'Cake', 'Soup', 'Cookies'}-->{'Tea'}  confidence:1.0
# Rule:{'Sandwich', 'Cake', 'Tea', 'Cookies'}-->{'Soup'}  confidence:0.6666666666666666
# Rule:{'Soup', 'Sandwich', 'Tea', 'Cookies'}-->{'Cake'}  confidence:1.0
# Rule:{'Soup', 'Cake', 'Tea', 'Cookies'}-->{'Sandwich'}  confidence:1.0
# Rule:{'Farm House', 'Medialuna', 'Hot chocolate'}-->{'Pastry', 'Coffee'}  confidence:1.0
# Rule:{'Pastry', 'Farm House', 'Hot chocolate'}-->{'Coffee', 'Medialuna'}  confidence:1.0
# Rule:{'Farm House', 'Medialuna', 'Coffee', 'Hot chocolate'}-->{'Pastry'}  confidence:1.0
# Rule:{'Pastry', 'Farm House', 'Medialuna', 'Hot chocolate'}-->{'Coffee'}  confidence:1.0
# Rule:{'Pastry', 'Farm House', 'Coffee', 'Hot chocolate'}-->{'Medialuna'}  confidence:1.0
# Rule:{'Medialuna', 'Tea', 'Hot chocolate', 'Cake'}-->{'Coffee'}  confidence:0.6666666666666666
# Rule:{'Medialuna', 'Tea', 'Coffee', 'Hot chocolate'}-->{'Cake'}  confidence:1.0
# Rule:{'Alfajores', 'Sandwich', 'Hot chocolate'}-->{'Tea', 'Coffee'}  confidence:0.6666666666666666
# Rule:{'Alfajores', 'Sandwich', 'Tea', 'Hot chocolate'}-->{'Coffee'}  confidence:1.0
# Rule:{'Alfajores', 'Sandwich', 'Tea', 'Coffee'}-->{'Hot chocolate'}  confidence:0.6666666666666666
# Rule:{'Alfajores', 'Sandwich', 'Coffee', 'Hot chocolate'}-->{'Tea'}  confidence:0.6666666666666666
# Rule:{'Toast', 'Cake', 'Sandwich'}-->{'Coffee', 'Hot chocolate'}  confidence:0.6666666666666666
# Rule:{'Toast', 'Cake', 'Sandwich', 'Hot chocolate'}-->{'Coffee'}  confidence:1.0
# Rule:{'Toast', 'Cake', 'Sandwich', 'Coffee'}-->{'Hot chocolate'}  confidence:1.0
# Rule:{'Toast', 'Sandwich', 'Coffee', 'Hot chocolate'}-->{'Cake'}  confidence:0.6666666666666666
# Rule:{'Juice', 'Tea', 'Cake', 'Muffin'}-->{'Coffee'}  confidence:1.0
# Rule:{'Pastry', 'Alfajores', 'Tiffin'}-->{'Tea', 'Coffee'}  confidence:1.0
# Rule:{'Tiffin', 'Alfajores', 'Tea'}-->{'Pastry', 'Coffee'}  confidence:0.6666666666666666
# Rule:{'Pastry', 'Coffee', 'Tiffin'}-->{'Alfajores', 'Tea'}  confidence:0.6666666666666666
# Rule:{'Pastry', 'Alfajores', 'Tea', 'Tiffin'}-->{'Coffee'}  confidence:1.0
# Rule:{'Tiffin', 'Alfajores', 'Tea', 'Coffee'}-->{'Pastry'}  confidence:1.0
# Rule:{'Pastry', 'Alfajores', 'Coffee', 'Tiffin'}-->{'Tea'}  confidence:1.0
# Rule:{'Pastry', 'Tea', 'Coffee', 'Tiffin'}-->{'Alfajores'}  confidence:0.6666666666666666
# Rule:{'Farm House', 'Cake', 'Medialuna'}-->{'Tea', 'Coffee'}  confidence:1.0
# Rule:{'Cake', 'Tea', 'Farm House'}-->{'Coffee', 'Medialuna'}  confidence:0.6666666666666666
# Rule:{'Cake', 'Tea', 'Coffee', 'Farm House'}-->{'Medialuna'}  confidence:1.0
# Rule:{'Farm House', 'Cake', 'Tea', 'Medialuna'}-->{'Coffee'}  confidence:1.0
# Rule:{'Farm House', 'Cake', 'Coffee', 'Medialuna'}-->{'Tea'}  confidence:1.0
# Rule:{'Cake', 'Scone', 'Medialuna'}-->{'Tea', 'Coffee'}  confidence:0.6666666666666666
# Rule:{'Scone', 'Cake', 'Tea', 'Medialuna'}-->{'Coffee'}  confidence:1.0
# Rule:{'Cake', 'Scone', 'Coffee', 'Medialuna'}-->{'Tea'}  confidence:1.0
# Rule:{'Scone', 'Tea', 'Coffee', 'Medialuna'}-->{'Cake'}  confidence:0.6666666666666666
# Rule:{'Soup', 'Sandwich', 'Cake', 'Tea'}-->{'Coffee'}  confidence:1.0
# Rule:{'Truffles', 'Coke', 'Juice'}-->{'Sandwich', 'Coffee'}  confidence:0.6666666666666666
# Rule:{'Truffles', 'Coke', 'Sandwich', 'Juice'}-->{'Coffee'}  confidence:1.0
# Rule:{'Truffles', 'Coke', 'Coffee', 'Juice'}-->{'Sandwich'}  confidence:0.6666666666666666
# Rule:{'Chicken Stew', 'Coke', 'Sandwich', 'Juice'}-->{'Coffee'}  confidence:1.0
# Rule:{'Chicken Stew', 'Sandwich', 'Coffee', 'Juice'}-->{'Coke'}  confidence:0.6666666666666666
# Rule:{'Chicken Stew', 'Coke', 'Coffee', 'Juice'}-->{'Sandwich'}  confidence:0.6666666666666666
# Rule:{'Spanish Brunch', 'Extra Salami or Feta', 'Juice'}-->{'Salad', 'Coffee'}  confidence:1.0
# Rule:{'Spanish Brunch', 'Salad', 'Extra Salami or Feta'}-->{'Coffee', 'Juice'}  confidence:0.6666666666666666
# Rule:{'Salad', 'Extra Salami or Feta', 'Juice'}-->{'Spanish Brunch', 'Coffee'}  confidence:0.6666666666666666
# Rule:{'Spanish Brunch', 'Salad', 'Juice'}-->{'Extra Salami or Feta', 'Coffee'}  confidence:1.0
# Rule:{'Spanish Brunch', 'Salad', 'Extra Salami or Feta', 'Coffee'}-->{'Juice'}  confidence:0.6666666666666666
# Rule:{'Spanish Brunch', 'Salad', 'Extra Salami or Feta', 'Juice'}-->{'Coffee'}  confidence:1.0
# Rule:{'Spanish Brunch', 'Extra Salami or Feta', 'Coffee', 'Juice'}-->{'Salad'}  confidence:1.0
# Rule:{'Salad', 'Extra Salami or Feta', 'Coffee', 'Juice'}-->{'Spanish Brunch'}  confidence:0.6666666666666666
# Rule:{'Spanish Brunch', 'Salad', 'Coffee', 'Juice'}-->{'Extra Salami or Feta'}  confidence:1.0
# Rule:{'Chicken Stew', 'Salad', 'Coffee'}-->{'Truffles', 'Cake'}  confidence:0.6666666666666666
# Rule:{'Chicken Stew', 'Salad', 'Cake'}-->{'Truffles', 'Coffee'}  confidence:1.0
# Rule:{'Truffles', 'Salad', 'Chicken Stew'}-->{'Cake', 'Coffee'}  confidence:0.6666666666666666
# Rule:{'Truffles', 'Cake', 'Chicken Stew'}-->{'Salad', 'Coffee'}  confidence:0.6666666666666666
# Rule:{'Truffles', 'Salad', 'Cake'}-->{'Chicken Stew', 'Coffee'}  confidence:1.0
# Rule:{'Truffles', 'Salad', 'Coffee', 'Chicken Stew'}-->{'Cake'}  confidence:1.0
# Rule:{'Truffles', 'Salad', 'Cake', 'Chicken Stew'}-->{'Coffee'}  confidence:1.0
# Rule:{'Chicken Stew', 'Salad', 'Cake', 'Coffee'}-->{'Truffles'}  confidence:1.0
# Rule:{'Truffles', 'Cake', 'Coffee', 'Chicken Stew'}-->{'Salad'}  confidence:1.0
# Rule:{'Truffles', 'Salad', 'Cake', 'Coffee'}-->{'Chicken Stew'}  confidence:1.0
# Rule:{'Truffles', 'Coke', 'Chicken Stew'}-->{'Sandwich', 'Coffee'}  confidence:0.6666666666666666
# Rule:{'Truffles', 'Sandwich', 'Chicken Stew'}-->{'Coke', 'Coffee'}  confidence:0.6666666666666666
# Rule:{'Truffles', 'Sandwich', 'Coffee', 'Chicken Stew'}-->{'Coke'}  confidence:1.0
# Rule:{'Truffles', 'Coke', 'Sandwich', 'Chicken Stew'}-->{'Coffee'}  confidence:1.0
# Rule:{'Truffles', 'Coke', 'Coffee', 'Chicken Stew'}-->{'Sandwich'}  confidence:0.6666666666666666
