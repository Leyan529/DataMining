# %%
import ML
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
ML.showAllVariables()
# %matplotlib inline

# from fastai.imports import *
# from fastai.structured import *
import matplotlib.pyplot as plt
# Input data files are available in the "../input/" directory.
# For example, running this (by clicking run or pressing Shift+Enter) will list the files in the input directory
import os
# Out:
# D:\Program\Anaconda3\envs\tensorflow\lib\site-packages\h5py\__init__.py:34: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters

# %%
# Any results you write to the current directory are saved as output.

bakery_data=pd.read_csv("BreadBasket_DMS.csv")

bakery_data['Date Time']=bakery_data['Date']+" "+bakery_data['Time']

bakery_data=bakery_data.drop(['Date','Time'],axis=1)

# bakery_data['TID'] = bakery_data.index
# bakery_data.set_index(bakery_data['TID'],inplace=True)

bakery_data = bakery_data.drop(['Date Time'],axis=1)
bakery_data.Item.count()
# Out:
# 21293

# %%
bakery_data = bakery_data[~bakery_data['Item'].str.contains('NONE')]
bakery_data
# Out:
#        Transaction                  Item
# 0                1                 Bread
# 1                2          Scandinavian
# 2                2          Scandinavian
# 3                3         Hot chocolate
# 4                3                   Jam
# 5                3               Cookies
# 6                4                Muffin
# 7                5                Coffee
# 8                5                Pastry
# 9                5                 Bread
# 10               6             Medialuna
# 11               6                Pastry
# 12               6                Muffin
# 13               7             Medialuna
# 14               7                Pastry
# 15               7                Coffee
# 16               7                   Tea
# 17               8                Pastry
# 18               8                 Bread
# 19               9                 Bread
# 20               9                Muffin
# 21              10          Scandinavian
# 22              10             Medialuna
# 23              11                 Bread
# 24              11             Medialuna
# 25              11                 Bread
# 27              12                   Jam
# 28              12                Coffee
# 29              12               Tartine
# 30              12                Pastry
# ...            ...                   ...
# 21262         9670            Farm House
# 21263         9671                 Bread
# 21264         9672                Coffee
# 21265         9672               Cookies
# 21267         9672  Extra Salami or Feta
# 21268         9673        Spanish Brunch
# 21269         9673                Coffee
# 21270         9673                 Bread
# 21271         9674                Coffee
# 21272         9676             Smoothies
# 21273         9676              Sandwich
# 21274         9677          Tacos/Fajita
# 21275         9677                  Coke
# 21276         9678                Coffee
# 21277         9678          Tacos/Fajita
# 21278         9678                 Toast
# 21279         9679                 Bread
# 21280         9679        Spanish Brunch
# 21281         9680                 Bread
# 21282         9681              Truffles
# 21283         9681                   Tea
# 21284         9681        Spanish Brunch
# 21285         9681      Christmas common
# 21286         9682                Muffin
# 21287         9682          Tacos/Fajita
# 21288         9682                Coffee
# 21289         9682                   Tea
# 21290         9683                Coffee
# 21291         9683                Pastry
# 21292         9684             Smoothies
#
# [20507 rows x 2 columns]

# %%
tdl = []
for i in range(1,bakery_data.Transaction.count()+1):
    tdf = bakery_data[bakery_data.Transaction == i]
    l = set()
    for j in range(0,tdf.Transaction.count()):
        l.add(tdf.Item.iloc[j])
    if len(l)>0:
        tdl.append(list(l))
    else:
        tdl.append(None)
        
col = ['items']
TDB = pd.DataFrame({"items":tdl},columns=col)
TDB = TDB.dropna()
TDB
# Out:
#                                                   items
# 0                                               [Bread]
# 1                                        [Scandinavian]
# 2                         [Jam, Hot chocolate, Cookies]
# 3                                              [Muffin]
# 4                               [Bread, Pastry, Coffee]
# 5                           [Pastry, Medialuna, Muffin]
# 6                      [Pastry, Medialuna, Tea, Coffee]
# 7                                       [Pastry, Bread]
# 8                                       [Muffin, Bread]
# 9                             [Scandinavian, Medialuna]
# 10                                   [Medialuna, Bread]
# 11                  [Jam, Pastry, Tea, Coffee, Tartine]
# 12                              [Basket, Coffee, Bread]
# 13                           [Pastry, Medialuna, Bread]
# 14                        [Mineral water, Scandinavian]
# 15                           [Medialuna, Coffee, Bread]
# 16                                      [Hot chocolate]
# 17                                         [Farm House]
# 18                                  [Farm House, Bread]
# 19                                   [Medialuna, Bread]
# 20                           [Bread, Medialuna, Coffee]
# 21                                                [Jam]
# 22                               [Scandinavian, Muffin]
# 23                                              [Bread]
# 24                                       [Scandinavian]
# 25                                              [Fudge]
# 26                                       [Scandinavian]
# 27                                      [Bread, Coffee]
# 28                                         [Jam, Bread]
# 29                                              [Bread]
# ...                                                 ...
# 9650                                   [Pastry, Coffee]
# 9651                                         [Baguette]
# 9652                                     [Cake, Coffee]
# 9653  [Half slice Monster , Hot chocolate, My-5 Frui...
# 9654                                              [Tea]
# 9655                                    [Toast, Coffee]
# 9656                                           [Coffee]
# 9657     [Spanish Brunch, Extra Salami or Feta, Coffee]
# 9658                                 [Cake, Juice, Tea]
# 9659                                            [Bread]
# 9663                                    [Bread, Coffee]
# 9664                    [Spanish Brunch, Juice, Coffee]
# 9665                                           [Coffee]
# 9666                                  [Sandwich, Bread]
# 9667                                       [Bread, Tea]
# 9668                                       [Farm House]
# 9669                                       [Farm House]
# 9670                                            [Bread]
# 9671            [Cookies, Extra Salami or Feta, Coffee]
# 9672                    [Spanish Brunch, Bread, Coffee]
# 9673                                           [Coffee]
# 9675                              [Smoothies, Sandwich]
# 9676                               [Tacos/Fajita, Coke]
# 9677                      [Tacos/Fajita, Toast, Coffee]
# 9678                            [Spanish Brunch, Bread]
# 9679                                            [Bread]
# 9680  [Truffles, Spanish Brunch, Christmas common, Tea]
# 9681                [Tacos/Fajita, Muffin, Tea, Coffee]
# 9682                                   [Pastry, Coffee]
# 9683                                        [Smoothies]
#
# [9465 rows x 1 columns]

# %%
def loadDataSet():    
    return TDB['items'].tolist()

# %%
class Item:
	elements = []
	supp = 0.0

	def __init__(self, elements, supp=0.0):
		self.elements = elements
		self.supp = supp

	def __str__(self):
		returnstr = '[ '
		for e in self.elements:
			returnstr += e + ','
		returnstr += ' ]' + ' (support :%.3f)\t' % (self.supp)
		return returnstr

	def getSubset(self, k, size):
		subset = []
		if k == 1:
			for i in range(size):
				subset.append([self.elements[i]])
			return subset
		else:
			i = size - 1
			while i >= k - 1:
				myset = self.getSubset(k - 1, i)
				j = 0
				while j < len(myset):
					# Attention a+=b  a=a+b
					myset[j] += [self.elements[i]]  # Why Elements change here?
					j += 1
				subset += (myset)
				i -= 1
			return subset

	def lastDiff(self, items):
		length = len(self.elements)
		if length != len(items.elements):  # length should be the same
			return False  # 兩邊長度要一樣才能進行混種
		if self.elements == items:  # if all the same,return false
			return False  # 兩邊內容若完全一樣不行進行混種
		return self.elements[0:length - 1] == items.elements[0:length - 1]

	# 兩邊內容最後一個元素以外的元素必須完全相同才能進行混種

	def setSupport(self, supp):
		self.supp = supp

	def join(self, items):
		temp = copy.copy(self.elements)
		temp.insert(len(self.elements), items.elements[len(items.elements) - 1])
		it = Item(temp, 0.0)
		return it


class C:
	'''candidate '''
	elements = []
	k = 0  # order

	def __init__(self, elements, k):
		self.elements = elements
		self.k = k

	def isEmpty(self):
		if len(self.elements) == 0:
			return True
		return False

	# get the same order of itemsets whose support is at lease the threshold
	def getL(self, threshold):  # 計算L2~Lk的function
		items = []
		for item in self.elements:
			if item.supp >= threshold:
				items.append(copy.copy(item))
		if len(items) == 0:
			return L([], self.k)
		return L(copy.deepcopy(items), self.k)

	def __str__(self):
		returnstr = str(self.k) + '-itemset:' + str(len(self.elements)) + ' \r\n{ '
		for e in self.elements:
			if True == isinstance(e, Item):
				returnstr += e.__str__()
		returnstr += ' }'
		return returnstr


class L:
	'''store all the  1-itemsets,2-itemsets,...k-itemsets'''
	items = []  # all the item in order K
	k = 0

	def __init__(self, items, k):
		self.items = items
		self.k = k

	def has_inFrequentItemsets(self, item):
		#        return False
		#        #先不优化
		subs = item.getSubset(self.k, len(item.elements))  # 取出候選item的subsets集合 ex:{ABC} ->{AB,AC,BC}
		for each in subs:  # 依序取出每個subset
			flag = False  # 代表目前subset是否為FrequentItemset
			for i in self.items:  # 依序從Lk中取出每個items (Lk中都是FrequentItemset)
				if i.elements == each:
					flag = True  # 是，則直接判斷下一個subset
					break
			if flag == False:
				return True  # 發現有subset為inFrequentItemset，則該候選item為inFrequentItemset

		return False  # 全部的subset皆為FrequentItemset，候選item不在inFrequentItemset中

	def aprioriGen(self):  # Generate Ck
		length = len(self.items)
		result = []  # store Ck
		for i in range(length):
			for j in range(i + 1, length):
				if self.items[i].lastDiff(self.items[j]):  # 若符合混種條件
					item = self.items[i].join(self.items[j])  # 將Lk中的items交配混種，得k階候選item
					if False == self.has_inFrequentItemsets(item):
						# 用Apriori性质：任一频繁项集的所有非空子集也必须是频繁的，
						# 反之，如果某个候选的非空子集不是频繁的，那么该候选肯定不是频繁的，从而可以将其从CK中删除。
						result.append(item)
		if (len(result) == 0):
			return C([], self.k + 1)
		return C(result, self.k + 1)  # 回傳提升一階後的k & Ck

	def __str__(self):
		returnstr = "\r\n" + str(self.k) + '-itemsets :' + str(len(self.items)) + "\r\n{"
		for item in self.items:
			returnstr += item.__str__()
		returnstr += '}'
		return returnstr


class LS:
	'''store from L1-itemset to Lk-itemset'''
	values = {}  # L1,L2,Lk

	def get(self, k):
		return self.values[k]

	def size(self):
		return len(self.values)

	def put(self, l, k):
		self.values[k] = l

	def isEmpty(self):
		return self.size() == 0

	def __str__(self):
		returnstr = '-----result--------\r\n'
		for l in self.values:
			returnstr += self.values[l].__str__()
		return returnstr


class Rule:
	confidence = .0
	str_rule = ''

	def __init__(self, confidence, str_rule):
		self.confidence = confidence
		self.str_rule = str_rule

	def __str__(self):
		return 'Rule:' + self.str_rule + '  confidence:' + str(self.confidence)


class Apriori:
	def __init__(self, min_supp=0.07):
		#         inputfile = open(datafile,"r")
		self.data = []
		self.size = 0
		self.min_supp = min_supp
		#         for line in inputfile.readlines():
		#             linearray = re.compile("[\d]+").findall(line)
		#             self.data.append(linearray)
		self.data = loadDataSet()
		self.size = len(self.data)

	def findFrequent1Itemsets(self):
		totalItemsets = []  # store all the item from transaction
		for temp in self.data:
			totalItemsets.extend(temp)
		items = []  # store the 1-itemset s

		while len(totalItemsets) > 0:
			item = totalItemsets[0]  # get unique item from itemset
			count = 0
			j = 0
			while j < len(totalItemsets):  # calc item count
				if (item == totalItemsets[j]):
					count += 1
					totalItemsets.remove(item)  # remove the first occurence
				else:
					j += 1
			t_supp = count / self.size  # calc unique item support

			if t_supp >= self.min_supp:
				items.append(Item([item], t_supp))  # 1-itemset ([item1,...,item_n],support)

		temp = L(copy.deepcopy(items), 1)  # show info from 1-itemset
		return temp

	def ralationRules(self, maxSequence, min_confidence):
		# maxSequence : Lk中的所有itemsets
		ruls = []  # 存放所有的關聯式規則
		for each in maxSequence:
			for i in range(len(each.elements) - 1):  # real subsets
				subsets = each.getSubset(i + 1, len(each.elements))  # 對於每一個itemset計算出 (2^k)-2 個subset ,ex:k=4 14個subset
				for subset in subsets:  # 從subsets集合中取出每一個subset
					count = 0
					for tran_item in self.data:
						flag = False  # 標記subset中的每個元素都在源中出現
						for ele in subset:  # 從每一個subset中取出元素ele判斷是否在來源transaction中出現過
							if ele not in tran_item:
								flag = True
								break
						if flag == False:
							count += 1  # subset出現在原始資料集中，計數值+1
					confidence = (each.supp * self.size) / count  # 計算當前Lk itemset的信心值
					# confidence = (Lk itemset出現次數) / (subset出現次數)
					if confidence >= min_confidence:  # confidence/the number of the frequent pattern
						# 計算由Lk itemSet 所衍伸出來的關聯式規則
						# set(each.elements) - set(subset) Lk itemset與subset的差集 (代表衍伸會購買的物品)
						str_rule = str(set(subset)) + '-->' + str(set(each.elements) - set(subset))
						rule = Rule(confidence, str_rule)
						ruls.append(rule)  # 加入一條新的關聯規則
		return ruls

	def do(self):
		ls = LS()
		oneitemset = self.findFrequent1Itemsets()
		ls.put(oneitemset, 1)  # ls add L1 itemset
		k = 2
		while False == ls.isEmpty():  # if Lk itemset is not empty : do-loop
			cand = ls.get(k - 1).aprioriGen()  # pick L(k-1) to generate Ck
			if cand.isEmpty():
				break  # if Ck is empty : break
			for each in cand.elements:  # 針對Ck裡每個item，從原來的itemset中找出符合規則的item
				count = 0
				for each_src in self.data:  # 判斷原先data set中的關聯
					if len(each_src) < len(each.elements):  # pass 掉原先資料長度不夠的itemset
						pass
					else:
						# 不是必須連續 相等才滿足條件，只要元素都在裡面即可
						flag = True
						for just_one_e in each.elements:  # 針對Ck裡每個item，檢查是否存在於原先data set中
							flag = just_one_e in each_src
							if flag == False:  # 只要有一个不在，即退出
								break
						if flag == True:  # 當前候選事件都在的話，計數
							count += 1

				supp = count / self.size  # 計算當前候選itemset的support
				each.setSupport(supp)
			ls.put(cand.getL(a.min_supp), k)  # 以當前候選itemset為參數，計算Lk，並放入Lk set
			k += 1
		return ls

# %%
def getFinalRule(ls):  #列印最後規則
	final_Lk = ls.get(ls.size())  # 取出最後的Lk
	print(finalLk)
	rules = a.ralationRules(final_Lk.items, min_confidence=0.5)
	for rule in rules:
		print(rule)

def getAllRule(ls): #列印全部規則
	for i in range(1, ls.size()):
		Lk = ls.get(i)
		rules = a.ralationRules(Lk.items, min_confidence=0.5)
		for rule in rules:
			print(rule)

# %%
import time,copy
starttime = time.time()
a = Apriori(min_supp=0.001)
ls = a.do()
print(ls)
endtime = time.time()
print("It takes %d milliseconds to find the above  patterns" % ((endtime - starttime) * 1000))
print()
# getFinalRule(ls)
getAllRule(ls)
# Out:
# -----result--------
#
# 1-itemsets :57
# {[ Bread, ] (support :0.327)	[ Scandinavian, ] (support :0.029)	[ Jam, ] (support :0.015)	[ Hot chocolate, ] (support :0.058)	[ Cookies, ] (support :0.054)	[ Muffin, ] (support :0.038)	[ Pastry, ] (support :0.086)	[ Coffee, ] (support :0.478)	[ Medialuna, ] (support :0.062)	[ Tea, ] (support :0.143)	[ Tartine, ] (support :0.005)	[ Mineral water, ] (support :0.014)	[ Farm House, ] (support :0.039)	[ Fudge, ] (support :0.015)	[ Juice, ] (support :0.039)	[ Ella's Kitchen Pouches, ] (support :0.002)	[ Hearty & Seasonal, ] (support :0.011)	[ Frittata, ] (support :0.009)	[ Soup, ] (support :0.034)	[ Smoothies, ] (support :0.008)	[ Pick and Mix Bowls, ] (support :0.001)	[ Cake, ] (support :0.104)	[ Mighty Protein, ] (support :0.001)	[ Coke, ] (support :0.019)	[ My-5 Fruit Shoot, ] (support :0.002)	[ Focaccia, ] (support :0.006)	[ Sandwich, ] (support :0.072)	[ Alfajores, ] (support :0.036)	[ Eggs, ] (support :0.003)	[ Brownie, ] (support :0.040)	[ Dulce de Leche, ] (support :0.001)	[ Granola, ] (support :0.003)	[ Keeping It Local, ] (support :0.007)	[ Art Tray, ] (support :0.004)	[ Truffles, ] (support :0.020)	[ Kids biscuit, ] (support :0.001)	[ Jammie Dodgers, ] (support :0.013)	[ Tiffin, ] (support :0.015)	[ The Nomad, ] (support :0.006)	[ Bakewell, ] (support :0.005)	[ Toast, ] (support :0.034)	[ Scone, ] (support :0.035)	[ Vegan mincepie, ] (support :0.005)	[ Crisps, ] (support :0.001)	[ Afternoon with the baker, ] (support :0.005)	[ Salad, ] (support :0.010)	[ Chicken Stew, ] (support :0.013)	[ Spanish Brunch, ] (support :0.018)	[ Extra Salami or Feta, ] (support :0.004)	[ Duck egg, ] (support :0.001)	[ Baguette, ] (support :0.016)	[ Valentine's card, ] (support :0.001)	[ Tshirt, ] (support :0.002)	[ Vegan Feast, ] (support :0.002)	[ Postcard, ] (support :0.001)	[ Christmas common, ] (support :0.001)	[ Tacos/Fajita, ] (support :0.001)	}
# 2-itemsets :243
# {[ Bread,Scandinavian, ] (support :0.007)	[ Bread,Jam, ] (support :0.005)	[ Bread,Hot chocolate, ] (support :0.013)	[ Bread,Cookies, ] (support :0.014)	[ Bread,Muffin, ] (support :0.008)	[ Bread,Pastry, ] (support :0.029)	[ Bread,Coffee, ] (support :0.090)	[ Bread,Medialuna, ] (support :0.017)	[ Bread,Tea, ] (support :0.028)	[ Bread,Mineral water, ] (support :0.003)	[ Bread,Farm House, ] (support :0.005)	[ Bread,Fudge, ] (support :0.003)	[ Bread,Juice, ] (support :0.007)	[ Bread,Hearty & Seasonal, ] (support :0.003)	[ Bread,Frittata, ] (support :0.003)	[ Bread,Soup, ] (support :0.007)	[ Bread,Smoothies, ] (support :0.002)	[ Bread,Cake, ] (support :0.023)	[ Bread,Coke, ] (support :0.002)	[ Bread,Focaccia, ] (support :0.002)	[ Bread,Sandwich, ] (support :0.017)	[ Bread,Alfajores, ] (support :0.010)	[ Bread,Eggs, ] (support :0.001)	[ Bread,Brownie, ] (support :0.011)	[ Bread,Keeping It Local, ] (support :0.002)	[ Bread,Truffles, ] (support :0.005)	[ Bread,Jammie Dodgers, ] (support :0.005)	[ Bread,Tiffin, ] (support :0.005)	[ Bread,The Nomad, ] (support :0.002)	[ Bread,Bakewell, ] (support :0.001)	[ Bread,Toast, ] (support :0.008)	[ Bread,Scone, ] (support :0.009)	[ Bread,Vegan mincepie, ] (support :0.001)	[ Bread,Salad, ] (support :0.002)	[ Bread,Chicken Stew, ] (support :0.003)	[ Bread,Spanish Brunch, ] (support :0.005)	[ Bread,Extra Salami or Feta, ] (support :0.001)	[ Bread,Baguette, ] (support :0.003)	[ Scandinavian,Muffin, ] (support :0.001)	[ Scandinavian,Pastry, ] (support :0.001)	[ Scandinavian,Coffee, ] (support :0.005)	[ Scandinavian,Medialuna, ] (support :0.001)	[ Scandinavian,Farm House, ] (support :0.002)	[ Scandinavian,Cake, ] (support :0.001)	[ Scandinavian,Alfajores, ] (support :0.001)	[ Jam,Pastry, ] (support :0.001)	[ Jam,Coffee, ] (support :0.004)	[ Jam,Tea, ] (support :0.001)	[ Jam,Fudge, ] (support :0.003)	[ Hot chocolate,Cookies, ] (support :0.006)	[ Hot chocolate,Muffin, ] (support :0.004)	[ Hot chocolate,Pastry, ] (support :0.006)	[ Hot chocolate,Coffee, ] (support :0.030)	[ Hot chocolate,Medialuna, ] (support :0.005)	[ Hot chocolate,Tea, ] (support :0.008)	[ Hot chocolate,Juice, ] (support :0.002)	[ Hot chocolate,Cake, ] (support :0.011)	[ Hot chocolate,Sandwich, ] (support :0.004)	[ Hot chocolate,Alfajores, ] (support :0.004)	[ Hot chocolate,Brownie, ] (support :0.004)	[ Hot chocolate,Jammie Dodgers, ] (support :0.001)	[ Hot chocolate,Tiffin, ] (support :0.001)	[ Hot chocolate,Toast, ] (support :0.003)	[ Hot chocolate,Scone, ] (support :0.003)	[ Cookies,Muffin, ] (support :0.002)	[ Cookies,Pastry, ] (support :0.003)	[ Cookies,Coffee, ] (support :0.028)	[ Cookies,Medialuna, ] (support :0.003)	[ Cookies,Tea, ] (support :0.010)	[ Cookies,Mineral water, ] (support :0.001)	[ Cookies,Farm House, ] (support :0.001)	[ Cookies,Juice, ] (support :0.006)	[ Cookies,Soup, ] (support :0.001)	[ Cookies,Cake, ] (support :0.007)	[ Cookies,Sandwich, ] (support :0.003)	[ Cookies,Alfajores, ] (support :0.002)	[ Cookies,Brownie, ] (support :0.003)	[ Cookies,Jammie Dodgers, ] (support :0.001)	[ Cookies,Tiffin, ] (support :0.001)	[ Cookies,Toast, ] (support :0.002)	[ Cookies,Scone, ] (support :0.002)	[ Muffin,Pastry, ] (support :0.003)	[ Muffin,Coffee, ] (support :0.019)	[ Muffin,Medialuna, ] (support :0.002)	[ Muffin,Tea, ] (support :0.007)	[ Muffin,Juice, ] (support :0.003)	[ Muffin,Soup, ] (support :0.001)	[ Muffin,Cake, ] (support :0.005)	[ Muffin,Sandwich, ] (support :0.002)	[ Muffin,Alfajores, ] (support :0.002)	[ Muffin,Brownie, ] (support :0.002)	[ Pastry,Coffee, ] (support :0.048)	[ Pastry,Medialuna, ] (support :0.009)	[ Pastry,Tea, ] (support :0.010)	[ Pastry,Farm House, ] (support :0.003)	[ Pastry,Juice, ] (support :0.002)	[ Pastry,Cake, ] (support :0.005)	[ Pastry,Sandwich, ] (support :0.001)	[ Pastry,Alfajores, ] (support :0.003)	[ Pastry,Brownie, ] (support :0.002)	[ Pastry,Truffles, ] (support :0.002)	[ Pastry,Toast, ] (support :0.002)	[ Pastry,Scone, ] (support :0.002)	[ Coffee,Medialuna, ] (support :0.035)	[  ...
# 3-itemsets :167
# {[ Bread,Scandinavian,Coffee, ] (support :0.001)	[ Bread,Jam,Coffee, ] (support :0.001)	[ Bread,Hot chocolate,Cookies, ] (support :0.001)	[ Bread,Hot chocolate,Muffin, ] (support :0.001)	[ Bread,Hot chocolate,Pastry, ] (support :0.002)	[ Bread,Hot chocolate,Coffee, ] (support :0.006)	[ Bread,Hot chocolate,Medialuna, ] (support :0.001)	[ Bread,Hot chocolate,Tea, ] (support :0.001)	[ Bread,Hot chocolate,Cake, ] (support :0.002)	[ Bread,Hot chocolate,Scone, ] (support :0.001)	[ Bread,Cookies,Coffee, ] (support :0.005)	[ Bread,Cookies,Tea, ] (support :0.001)	[ Bread,Cookies,Juice, ] (support :0.001)	[ Bread,Cookies,Cake, ] (support :0.002)	[ Bread,Muffin,Coffee, ] (support :0.002)	[ Bread,Pastry,Coffee, ] (support :0.011)	[ Bread,Pastry,Medialuna, ] (support :0.002)	[ Bread,Pastry,Tea, ] (support :0.002)	[ Bread,Pastry,Cake, ] (support :0.002)	[ Bread,Coffee,Medialuna, ] (support :0.007)	[ Bread,Coffee,Tea, ] (support :0.007)	[ Bread,Coffee,Mineral water, ] (support :0.001)	[ Bread,Coffee,Farm House, ] (support :0.001)	[ Bread,Coffee,Juice, ] (support :0.003)	[ Bread,Coffee,Hearty & Seasonal, ] (support :0.001)	[ Bread,Coffee,Frittata, ] (support :0.001)	[ Bread,Coffee,Soup, ] (support :0.002)	[ Bread,Coffee,Smoothies, ] (support :0.001)	[ Bread,Coffee,Cake, ] (support :0.010)	[ Bread,Coffee,Sandwich, ] (support :0.007)	[ Bread,Coffee,Alfajores, ] (support :0.004)	[ Bread,Coffee,Brownie, ] (support :0.004)	[ Bread,Coffee,Keeping It Local, ] (support :0.001)	[ Bread,Coffee,Truffles, ] (support :0.002)	[ Bread,Coffee,Jammie Dodgers, ] (support :0.002)	[ Bread,Coffee,Tiffin, ] (support :0.002)	[ Bread,Coffee,Toast, ] (support :0.004)	[ Bread,Coffee,Scone, ] (support :0.003)	[ Bread,Coffee,Salad, ] (support :0.001)	[ Bread,Coffee,Spanish Brunch, ] (support :0.002)	[ Bread,Medialuna,Tea, ] (support :0.002)	[ Bread,Medialuna,Alfajores, ] (support :0.001)	[ Bread,Tea,Soup, ] (support :0.002)	[ Bread,Tea,Cake, ] (support :0.005)	[ Bread,Tea,Sandwich, ] (support :0.003)	[ Bread,Tea,Alfajores, ] (support :0.002)	[ Bread,Tea,Brownie, ] (support :0.002)	[ Bread,Tea,Jammie Dodgers, ] (support :0.001)	[ Bread,Tea,Tiffin, ] (support :0.001)	[ Bread,Tea,Toast, ] (support :0.001)	[ Bread,Tea,Scone, ] (support :0.001)	[ Bread,Juice,Cake, ] (support :0.002)	[ Bread,Juice,Sandwich, ] (support :0.001)	[ Bread,Soup,Cake, ] (support :0.001)	[ Bread,Soup,Sandwich, ] (support :0.001)	[ Bread,Cake,Sandwich, ] (support :0.002)	[ Bread,Cake,Jammie Dodgers, ] (support :0.002)	[ Bread,Alfajores,Brownie, ] (support :0.001)	[ Hot chocolate,Cookies,Coffee, ] (support :0.004)	[ Hot chocolate,Muffin,Coffee, ] (support :0.002)	[ Hot chocolate,Pastry,Coffee, ] (support :0.004)	[ Hot chocolate,Coffee,Medialuna, ] (support :0.003)	[ Hot chocolate,Coffee,Tea, ] (support :0.002)	[ Hot chocolate,Coffee,Juice, ] (support :0.001)	[ Hot chocolate,Coffee,Cake, ] (support :0.007)	[ Hot chocolate,Coffee,Sandwich, ] (support :0.003)	[ Hot chocolate,Coffee,Alfajores, ] (support :0.002)	[ Hot chocolate,Coffee,Brownie, ] (support :0.002)	[ Hot chocolate,Coffee,Toast, ] (support :0.001)	[ Hot chocolate,Coffee,Scone, ] (support :0.002)	[ Hot chocolate,Tea,Cake, ] (support :0.002)	[ Hot chocolate,Tea,Alfajores, ] (support :0.001)	[ Cookies,Pastry,Coffee, ] (support :0.002)	[ Cookies,Coffee,Medialuna, ] (support :0.002)	[ Cookies,Coffee,Tea, ] (support :0.004)	[ Cookies,Coffee,Juice, ] (support :0.004)	[ Cookies,Coffee,Cake, ] (support :0.004)	[ Cookies,Coffee,Sandwich, ] (support :0.002)	[ Cookies,Coffee,Alfajores, ] (support :0.002)	[ Cookies,Coffee,Brownie, ] (support :0.002)	[ Cookies,Coffee,Toast, ] (support :0.001)	[ Cookies,Coffee,Scone, ] (support :0.002)	[ Cookies,Tea,Juice, ] (support :0.002)	[ Cookies,Tea,Cake, ] (support :0.001)	[ Cookies,Juice,Cake, ] (support :0.001)	[ Cookies,Juice,Alfajores, ] (support :0.001)	[ Muffin,Pastry,Coffee, ] (support :0.001)	[ Muffin,Coffee,Medialuna, ] (support :0.001)	[ Muffin,Coffee,Tea, ] (support :0.003)	[ Muffin,Coffee,Juice, ] (support ...
# 4-itemsets :4
# {[ Bread,Hot chocolate,Pastry,Coffee, ] (support :0.001)	[ Bread,Pastry,Coffee,Medialuna, ] (support :0.001)	[ Bread,Coffee,Tea,Cake, ] (support :0.001)	[ Coffee,Tea,Cake,Sandwich, ] (support :0.001)	}
# It takes 7827 milliseconds to find the above  patterns
# Rule:{'Eggs'}-->{'Bread'}  confidence:0.5
# Rule:{'Hot chocolate'}-->{'Coffee'}  confidence:0.5072463768115942
# Rule:{'Cookies'}-->{'Coffee'}  confidence:0.5184466019417475
# Rule:{'Pastry'}-->{'Coffee'}  confidence:0.5521472392638037
# Rule:{'Medialuna'}-->{'Coffee'}  confidence:0.5692307692307692
# Rule:{'Tartine'}-->{'Coffee'}  confidence:0.6304347826086957
# Rule:{'Juice'}-->{'Coffee'}  confidence:0.5342465753424658
# Rule:{'Hearty & Seasonal'}-->{'Coffee'}  confidence:0.54
# Rule:{'Frittata'}-->{'Coffee'}  confidence:0.5308641975308642
# Rule:{'Cake'}-->{'Coffee'}  confidence:0.5269582909460834
# Rule:{'Sandwich'}-->{'Coffee'}  confidence:0.5323529411764706
# Rule:{'Alfajores'}-->{'Coffee'}  confidence:0.5406976744186046
# Rule:{'Granola'}-->{'Coffee'}  confidence:0.6071428571428571
# Rule:{'Keeping It Local'}-->{'Coffee'}  confidence:0.8095238095238095
# Rule:{'Art Tray'}-->{'Coffee'}  confidence:0.6842105263157895
# Rule:{'Jammie Dodgers'}-->{'Coffee'}  confidence:0.504
# Rule:{'Tiffin'}-->{'Coffee'}  confidence:0.547945205479452
# Rule:{'The Nomad'}-->{'Coffee'}  confidence:0.5344827586206896
# Rule:{'Bakewell'}-->{'Coffee'}  confidence:0.6041666666666666
# Rule:{'Toast'}-->{'Coffee'}  confidence:0.7044025157232704
# Rule:{'Scone'}-->{'Coffee'}  confidence:0.5229357798165137
# Rule:{'Vegan mincepie'}-->{'Coffee'}  confidence:0.5769230769230769
# Rule:{'Salad'}-->{'Coffee'}  confidence:0.6262626262626263
# Rule:{'Spanish Brunch'}-->{'Coffee'}  confidence:0.5988372093023255
# Rule:{'Extra Salami or Feta'}-->{'Coffee'}  confidence:0.8157894736842105
# Rule:{'Frittata', 'Bread'}-->{'Coffee'}  confidence:0.52
# Rule:{'Smoothies', 'Bread'}-->{'Coffee'}  confidence:0.5217391304347826
# Rule:{'Keeping It Local', 'Bread'}-->{'Coffee'}  confidence:0.5714285714285714
# Rule:{'Salad', 'Bread'}-->{'Coffee'}  confidence:0.5263157894736842
# Rule:{'Spanish Brunch', 'Bread'}-->{'Coffee'}  confidence:0.5111111111111111
# Rule:{'Jammie Dodgers', 'Cake'}-->{'Bread'}  confidence:0.5172413793103449
# Rule:{'Cookies', 'Hot chocolate'}-->{'Coffee'}  confidence:0.6140350877192983
# Rule:{'Hot chocolate', 'Muffin'}-->{'Coffee'}  confidence:0.5294117647058824
# Rule:{'Hot chocolate', 'Pastry'}-->{'Coffee'}  confidence:0.6666666666666666
# Rule:{'Hot chocolate', 'Medialuna'}-->{'Coffee'}  confidence:0.6444444444444445
# Rule:{'Hot chocolate', 'Juice'}-->{'Coffee'}  confidence:0.5714285714285714
# Rule:{'Hot chocolate', 'Cake'}-->{'Coffee'}  confidence:0.6018518518518519
# Rule:{'Hot chocolate', 'Sandwich'}-->{'Coffee'}  confidence:0.5714285714285714
# Rule:{'Hot chocolate', 'Alfajores'}-->{'Coffee'}  confidence:0.5588235294117647
# Rule:{'Hot chocolate', 'Brownie'}-->{'Coffee'}  confidence:0.5897435897435898
# Rule:{'Scone', 'Hot chocolate'}-->{'Coffee'}  confidence:0.6071428571428571
# Rule:{'Cookies', 'Pastry'}-->{'Coffee'}  confidence:0.6071428571428571
# Rule:{'Cookies', 'Medialuna'}-->{'Coffee'}  confidence:0.6666666666666666
# Rule:{'Cookies', 'Juice'}-->{'Coffee'}  confidence:0.603448275862069
# Rule:{'Cookies', 'Cake'}-->{'Coffee'}  confidence:0.5797101449275363
# Rule:{'Cookies', 'Sandwich'}-->{'Coffee'}  confidence:0.5925925925925926
# Rule:{'Cookies', 'Alfajores'}-->{'Coffee'}  confidence:0.6521739130434783
# Rule:{'Cookies', 'Brownie'}-->{'Coffee'}  confidence:0.625
# Rule:{'Cookies', 'Toast'}-->{'Coffee'}  confidence:0.5714285714285714
# Rule:{'Cookies', 'Scone'}-->{'Coffee'}  confidence:0.7894736842105263
# Rule:{'Muffin', 'Medialuna'}-->{'Coffee'}  confidence:0.5789473684210527
# Rule:{'Muffin', 'Sandwich'}-->{'Coffee'}  confidence:0.65
# Rule:{'Pastry', 'Medialuna'}-->{'Coffee'}  confidence:0.5287356321839081
# Rule:{'Pastry', 'Juice'}-->{'Coffee'}  confidence:0.7727272727272727
# Rule:{'Cake', 'Pastry'}-->{'Coffee'}  confidence:0.5306122448979592
# Rule:{'Alfajores', 'Pastry'}-->{'Coffee'}  confidence:0.5161290322580645
# Rule:{'Pastry', 'Toast'}-->{'Coffee'}  confidence:0.8666666666666667
# Rule:{'Medialuna', 'Farm House'}-->{'Coffee'}  confidence:0.5454545454545454
# Rule:{'Medialuna', 'Juice'}-->{'Coffee'}  confidence:0.55
# Rule:{'Cake', 'Medialuna'}-->{'Coffee'}  confidence:0.6857142857142857
# Rule:{'Medialuna', 'Sandwich'}-->{'Coffee'}  confidence:0.65
# Rule:{'Medialuna', 'Brownie'}-->{'Coffee'}  confidence:0.5263157894736842
# Rule:{'Medialuna', 'Toast'}-->{'Coffee'}  confidence:0.6111111111111112
# Rule:{'Keeping It Local', 'Tea'}-->{'Coffee'}  confidence:0.6470588235294118
# Rule:{'Toast', 'Tea'}-->{'Coffee'}  confidence:0.5081967213114754
# Rule:{'Cake', 'Juice'}-->{'Coffee'}  confidence:0.5522388059701493
# Rule:{'Coke', 'Juice'}-->{'Coffee'}  confidence:0.5238095238095238
# Rule:{'Alfajores', 'Juice'}-->{'Coffee'}  confidence:0.5862068965517241
# Rule:{'Brownie', 'Juice'}-->{'Coffee'}  confidence:0.5833333333333334
# Rule:{'Truffles', 'Juice'}-->{'Coffee'}  confidence:0.5789473684210527
# Rule:{'Jammie Dodgers', 'Juice'}-->{'Coffee'}  confidence:0.65
# Rule:{'Toast', 'Juice'}-->{'Coffee'}  confidence:0.6818181818181818
# Rule:{'Scone', 'Juice'}-->{'Coffee'}  confidence:0.631578947368421
# Rule:{'Spanish Brunch', 'Juice'}-->{'Coffee'}  confidence:0.7307692307692307
# Rule:{'Hearty & Seasonal', 'Sandwich'}-->{'Coffee'}  confidence:0.8571428571428571
# Rule:{'Cake', 'Soup'}-->{'Coffee'}  confidence:0.5476190476190477
# Rule:{'Sandwich', 'Soup'}-->{'Coffee'}  confidence:0.6538461538461539
# Rule:{'Cake', 'Smoothies'}-->{'Coffee'}  confidence:0.6666666666666666
# Rule:{'Cake', 'Sandwich'}-->{'Coffee'}  confidence:0.676923076923077
# Rule:{'Cake', 'Alfajores'}-->{'Coffee'}  confidence:0.5641025641025641
# Rule:{'Cake', 'Tiffin'}-->{'Coffee'}  confidence:0.6818181818181818
# Rule:{'Cake', 'Toast'}-->{'Coffee'}  confidence:0.7142857142857143
# Rule:{'Scone', 'Cake'}-->{'Coffee'}  confidence:0.6
# Rule:{'Cake', 'Vegan mincepie'}-->{'Coffee'}  confidence:0.8333333333333334
# Rule:{'Cake', 'Salad'}-->{'Coffee'}  confidence:0.7692307692307693
# Rule:{'Cake', 'Spanish Brunch'}-->{'Coffee'}  confidence:0.5454545454545454
# Rule:{'Alfajores', 'Sandwich'}-->{'Coffee'}  confidence:0.56
# Rule:{'Brownie', 'Sandwich'}-->{'Coffee'}  confidence:0.6363636363636364
# Rule:{'Truffles', 'Sandwich'}-->{'Coffee'}  confidence:0.5555555555555556
# Rule:{'Sandwich', 'Salad'}-->{'Coffee'}  confidence:0.8333333333333334
# Rule:{'Chicken Stew', 'Sandwich'}-->{'Coffee'}  confidence:0.5263157894736842
# Rule:{'Spanish Brunch', 'Sandwich'}-->{'Coffee'}  confidence:0.6666666666666666
# Rule:{'Alfajores', 'Brownie'}-->{'Coffee'}  confidence:0.5185185185185185
# Rule:{'Extra Salami or Feta', 'Salad'}-->{'Coffee'}  confidence:0.875
